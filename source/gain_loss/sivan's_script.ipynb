# %%
# %%time
## %config InlineBackend.figure_formats = ['retina']  # increase resolution on retina screens
import numpy as np
# import scanpy as sc
# import os
import pandas as pd
# import scanpy.external as sce
# import math

# sc.settings.verbosity = 4                # increase for more output
# sc.settings.set_figure_params(80)        # low pixel number yields small inline figures
# sc.settings.file_format_figures = 'png'  # set this to 'svg' (notebook) or 'pdf' (files) if you want vector graphics
# sc.settings.savefigs = False             # set to True if you want to save figures to `./figs/`

# print('Running Scanpy version', sc.__version__, 'on')
# sc.logging.print_memory_usage()

# use_first_n_samples = 0
# full_sparse = False

# %%
df = pd.read_csv(
    './lizard-gainloss-gallus-ref.csv',
    index_col='Gene'
)

# list_of_csv = [list(row) for row in df.values]

# print(list_of_csv)
# list_of_csv

df.drop('Unnamed: 941', inplace=True, axis=1)
# Out:
# C:\Users\Noam\AppData\Local\Temp\ipykernel_14700\2823048573.py:1: DtypeWarning: Columns (119,173,197,325,367,439,475,549,715,717,787,897,905) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df
# Out:
#                    Acanthochromis polyacanthus-change  \
# Gene
# ENSGALG00000055105                                  0
# ENSGALG00000052114                                  0
# ENSGALG00000052319                                  0
# ENSGALG00000047350                                  0
# ENSGALG00000049559                                  0
# ...                                               ...
# ENSGALG00000042478                                  -
# ENSGALG00000036229                                  -
# ENSGALG00000029500                                  -
# ENSGALG00000032079                                  -
# ENSGALG00000037838                                  -
#
#                     Acanthochromis polyacanthus-count Acanthomorphata-change  \
# Gene
# ENSGALG00000055105                                  0                      -
# ENSGALG00000052114                                  1                      0
# ...

# %%
clmn = list(df)
a = -1
b = 0
print(df.iloc[a, b])
col = df.columns[b]

print(col)

gene_name = []
change = []
count = []
header_name_animal = []
print("xxxxxx")

for p, row in df.iterrows():
    x=1
    while(x<len(row)):
        n=df.iloc[p,x]
        #print(n)
        if(str(n)!="0"):
            print(n)
            change.append(n)
            print(n+1)
            count.append(n+1)
            col = df.columns[x]
            #change.insert(0, col)
            header_name_animal.append(col)
            print(col)
            c=str(df.iloc[p,0])
            print(c)
            gene_name.append(c)
        x=x+2

df1 = pd.DataFrame (gene_name)
#df1=pd.DataFrame(gene_name)
df2=pd.DataFrame(change)
df3=pd.DataFrame(count)
print(header_name_animal)

# %%
df1.rename(columns=df.iloc[3]

# %%
dataframe = {}
dataframe['gene_name'] = gene_name
dataframe['change'] = change
dataframe['count'] = count

# %%
new = pd.DataFrame.from_dict(dataframe)

# %%
pd.concate(df1, df2, how ="right")

vertical_concat
#pd.merge(df1, df2, on = "fruit", how = "right")

# %%
df2 = pd.DataFrame()
df2.concat(gene_name, lsuffix="_left", rsuffix="_right").shape

# %%
clmn = list(df)
k=0
m=len(clmn)
for i in clmn:
    print(i)
    m=len(clmn)
    while(m>0):
        for k in range(len(df)):
            j=df.iloc[i,k]
            #j=df[i][k]
            print(j)
            k=k+1
            if(str(j)!="0"):
                print(j)
        m=m-1

#for i in range(len(df)):
#    print(df.iloc[i, 0], df.iloc[i, 2])

# %%
for i in clmn:
    print(i)
    m=len(clmn)
    while(m>0):
        while(k<len(clmn)):
            j=df[i][k]
            print(j)
            k=k+1
            if(str(j)!="0"):
                print(j)
        m=m-1
        
 #i=df[i][j]
  #      j=j+1
   #     print(j)
    #    print(i)
          
  # print(df["Name"].str.startswith('S'))

# %%
 i=df[i][j]
    j=j+1
    print(i)
    print(j)
    #print(df[i][0:])

# %%
for i in range(len(df)):
    for j in df.iteritems():
        if (i!="0"):
            print(i,j)
            j=j+2
    #if (i!="0"):
       # print(df.iloc[i, 0], df.iloc[i, 2])

# %%
df = pd.read_csv(r"C:\Users\TzachiHNB4\Desktop\lizard-gainloss-gallus-ref.csv\test_list.csv", delimiter=',')


inputm = []

for row in df:
    inputm.append(row)

# %%
inputfile = open(r"C:\Users\TzachiHNB4\Desktop\lizard-gainloss-gallus-ref.csv\test_list.csv")
with open(r"C:\Users\TzachiHNB4\Desktop\lizard-gainloss-gallus-ref.csv\test_list.csv") as inputfile:
    reader = csv.reader(inputfile)
    inputm = list(reader)

# %%
df_test_list = pd.DataFrame(list(list_of_csv))

# %%
##pango data frame
#df_marker_genes = pd.DataFrame(pango_genes,columns =['pango_marker_gene_names'])
#df_cell_type = pd.DataFrame(cell_type,columns =['cell_type'])

# %%
df_test_list = pd.DataFrame(list(zip(pango_genes, cell_type)),
               columns =['gene', 'cell_type'])
df_pango

# %%
clusters = pd.read_excel(r"C:\Users\TzachiHNB4\Downloads\new_genome_clusters_kd2.xlsx", sheet_name='new_genome_clusters_kd2')

cluster_list=clusters['cluster'].to_list()
gene_list=clusters['gene'].to_list()

# %%
df_kd_clusters = pd.DataFrame(list(zip(gene_list, cluster_list)),
               columns =['gene', 'cluster'])
df_kd_clusters

# %%
df3 = pd.merge(df_kd_clusters, df_pango, how='inner', left_on='gene', right_on='gene')
df3

# %%
df3.to_excel(r"C:\Users\TzachiHNB4\Downloads\pango_markers_to clusters_kd2.xlsx", index = False)

# %% [raw]
# for n in pango_genes:
#     if n in gene_list:
#        # print(n,gene_list.index(n),pango_genes.index(n))
#         x=gene_list.index(n)
#         y=pango_genes.index(n)
#        #print(y)
#         m=cluster_list[x]
#        # print(m)
#         q=cell_type[y]
#         #print(q)
#         marker_gene.append(n)
#         the_cluster.append(m)
#         cell_types.append(q)

# %%
nicknames= pango['nicknames'].to_list()

# %%
nicknames_split= []
number_list=[]
n=0
for x in nicknames:    
    if type(x)==str:
        if "|" in x:
            xx = x.split("|",-1)
            nicknames_split.append(xx)
            n=n+1
            number_list.append(n)
        else:
            nicknames_split.append(x)
            n=n+1
            number_list.append(n)

# %%
print(nicknames_split)
number_list

# %%
nicknames_split_list=[]
y=0
split_index=[]

for i in nicknames_split:
    if type(i)==str:
        nicknames_split_list.append(i)
        y=y+1
        split_index.append(y)
    elif type(i)==list:
        m=len(i)
        y=y+1
        while m>=1:         
            split_index.append(y) 
            m=m-1
        nicknames_split_list+=i
nicknames_split_list
#split_index

# %%
df_nickname_index = pd.DataFrame(list(zip(nicknames_split_list,split_index)),
               columns =['gene', 'index'])
df_nickname_index

# %%
df4 = pd.merge(df_kd_clusters, df_nickname_index, how='inner', left_on='gene', right_on='gene')
df4

# %%
df4.sort_values(by=['index'])

# %%
clusters = pd.read_excel(r"C:\Users\TzachiHNB4\Downloads\marker_genes_ctrl_low_and_muti.xlsx", sheet_name='marker_genes_ctrl_low_and_muti')

cluster_list=clusters['cluster'].to_list()
gene_list=clusters['gene'].to_list()

# %%
print("Largest element is:", max(cluster_list))

# %%
print(cluster_list[2])

# %%
cell_types=[]
marker_gene=[]
the_cluster=[]

nickname_genes=[]
the_cluster_nickname=[]
cell_types_nickname=[]

# %%
#0st 
z=0
print(len(gene_list))
for n in pango_genes:
    while z<=len(gene_list):
        if n==gene_list[z]:
            # print(n,gene_list.index(n),pango_genes.index(n))
            x=gene_list.index(n)
            y=pango_genes.index(n)
            #print(y)
            m=cluster_list[x]
            # print(m)
            q=cell_type[y]
            #print(q)
            marker_gene.append(n)
            the_cluster.append(m)
            cell_types.append(q)
        z=z+1

# %% [markdown]
# #0st?????????
# z=0
# print(len(gene_list))
# for n in pango_genes:
#     while z<270:
#         if n==gene_list[z]:
#             print(n,gene_list.index(n),pango_genes.index(n))
#             x=gene_list.index(n)
#             y=pango_genes.index(n)
#             #print(y)
#             m=cluster_list[x]
#             # print(m)
#             q=cell_type[y]
#             #print(q)
#             marker_gene.append(n)
#             the_cluster.append(m)
#             cell_types.append(q)
#         z=z+1
#         print(z)
#     print(n)

# %%
q=0
print(gene_list[q])

# %% [raw]
# #1st
#
# for n in pango_genes:
#     if n in gene_list:
#        # print(n,gene_list.index(n),pango_genes.index(n))
#         x=gene_list.index(n)
#         y=pango_genes.index(n)
#        #print(y)
#         m=cluster_list[x]
#        # print(m)
#         q=cell_type[y]
#         #print(q)
#         marker_gene.append(n)
#         the_cluster.append(m)
#         cell_types.append(q)

# %%
#2nd nicknames
for n in nicknames_split_list:
    if n in gene_list:
        print(n)
       # print(n,gene_list.index(n),pango_genes.index(n))
        x=gene_list.index(n)
        print(x)
        y=nickname_genes.index(n)
       #print(y)
        m=the_cluster_nickname[x]
       # print(m)
        q=cell_type[y]
        #print(q)
        marker_gene.append(n)
        the_cluster_nickname.append(m)
        cell_types_nickname.append(q)

# %%
df_marker_genes = pd.DataFrame(marker_gene,columns =['marker_gene_names'])
df_the_cluster = pd.DataFrame(marker_gene,columns =['No_of_cluster'])
df_cell_types = pd.DataFrame(marker_gene,columns =['cell_types'])

# %%
df = pd.DataFrame(list(zip(marker_gene, the_cluster, cell_types)),
               columns =['marker_gene_names', 'No_of_cluster', 'cell_types'])
df

# %%
df.to_excel(r"C:\Users\TzachiHNB4\Downloads\pango_markers_to clusters_all_of_chicken2.xlsx", index = False)
