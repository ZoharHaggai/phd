# %% [markdown]
# # QC for chicken A2 new genome
# No lps data and pic data, need to understand what is the problem

# %% [markdown]
# ## Imports

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import os
import bbknn
from pathlib import Path

# %% [markdown]
# ## Single cell settings

# %%
sc.settings.verbosity = 4
sc.settings.set_figure_params(80)
sc.settings._file_format_figs = 'pdf'
sc.settings.savefigs = False
use_first_n_samples = 0
full_sparse = False
# Out:
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_22424\3661074169.py:2: FutureWarning: The specified parameters ('scanpy',) are no longer positional. Please specify them like `scanpy=80`
#   sc.settings.set_figure_params(80)

# %% [markdown]
# ## QC workflow

# %% [markdown]
# ### Reading the control data separately from the other treatments

# %%
adatas = []

data_names = ['control_lps','control_pic']
main_path = '/Code/data/single_cell/animals/chicken/ca2/new_genome/control'
paths = ['\\control_lps','\\control_pic']    #...etc - Folders with matrix, features and barcodes gz files.
for path in paths:
    adata = sc.read_10x_mtx(main_path + path, var_names='gene_symbols', cache=False)    # use gene symbols for the variable names (variables-axis index)
    sc.logging.print_memory_usage()
    print(adata.shape)
    adatas.append(adata)
# Out:
#     reading \Code\data\single_cell\animals\chicken\ca2\new_genome\control\control_lps\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.27 GB, difference +0.27 GB
# (164, 30108)
#     reading \Code\data\single_cell\animals\chicken\ca2\new_genome\control\control_pic\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.35 GB, difference +0.07 GB
# (3846, 30108)

# %%
adata_control = adatas[0].concatenate(adatas[1], batch_categories = data_names, batch_key='treatment')
# Out:
# c:\Python\Python310\lib\site-packages\anndata\_core\anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(

# %%
adata_control.obs['treatment'] = 'control'
adata_control.obs
# Out:
#                                treatment
# AAAGGTAGTAGCTTGT-1-control_lps   control
# AACACACGTATGTCTG-1-control_lps   control
# AACCCAAAGATAACAC-1-control_lps   control
# AACCTTTGTTGACTAC-1-control_lps   control
# AACGTCATCTTAGCAG-1-control_lps   control
# ...                                  ...
# TTTGGTTTCACCTGTC-1-control_pic   control
# TTTGGTTTCGCTGACG-1-control_pic   control
# TTTGGTTTCTGCTTAT-1-control_pic   control
# TTTGTTGCAGAGATGC-1-control_pic   control
# TTTGTTGGTGTTATCG-1-control_pic   control
#
# [4010 rows x 1 columns]

# %%
adata_control.obs.index = [x.split('-control')[0] for x in adata_control.obs.index]
adata_control.obs.index
# Out:
# Index(['AAAGGTAGTAGCTTGT-1', 'AACACACGTATGTCTG-1', 'AACCCAAAGATAACAC-1',
#        'AACCTTTGTTGACTAC-1', 'AACGTCATCTTAGCAG-1', 'AACTTCTCACATGACT-1',
#        'AAGACAACAGGGATAC-1', 'AAGACTCTCAGTGTTG-1', 'AAGTCGTTCCGACAGC-1',
#        'AAGTGAAAGGTGCCAA-1',
#        ...
#        'TTTGGAGCACCTCGTT-1', 'TTTGGAGGTACGACTT-1', 'TTTGGAGTCTTTCTAG-1',
#        'TTTGGTTGTTCCAGGC-1', 'TTTGGTTTCAAATAGG-1', 'TTTGGTTTCACCTGTC-1',
#        'TTTGGTTTCGCTGACG-1', 'TTTGGTTTCTGCTTAT-1', 'TTTGTTGCAGAGATGC-1',
#        'TTTGTTGGTGTTATCG-1'],
#       dtype='object', length=4010)

# %%
adata_control
# Out:
# AnnData object with n_obs × n_vars = 4010 × 30108
#     obs: 'treatment'
#     var: 'gene_ids', 'feature_types'

# %%
adatas = [adata_control]
adata_control.obs_names_make_unique()

# %% [markdown]
# ### Reading the treatments data and adding the control data

# %%
data_names = ['lps','pic']
main_path = '/Code/data/single_cell/animals/chicken/ca2/new_genome'
paths = ['\\lps','\\pic']
for path in paths:
    adata = sc.read_10x_mtx(main_path + path, var_names='gene_symbols', cache=False)
    sc.logging.print_memory_usage()
    print(adata.shape)
    adatas.append(adata_control)
# Out:
#     reading \Code\data\single_cell\animals\chicken\ca2\new_genome\lps\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.34 GB, difference -0.01 GB
# (88, 30108)
#     reading \Code\data\single_cell\animals\chicken\ca2\new_genome\pic\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.37 GB, difference +0.03 GB
# (1626, 30108)

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 4010 × 30108
#      obs: 'treatment'
#      var: 'gene_ids', 'feature_types',
#  AnnData object with n_obs × n_vars = 4010 × 30108
#      obs: 'treatment'
#      var: 'gene_ids', 'feature_types',
#  AnnData object with n_obs × n_vars = 4010 × 30108
#      obs: 'treatment'
#      var: 'gene_ids', 'feature_types']

# %%
adata_control.obs
# Out:
#                    treatment
# AAAGGTAGTAGCTTGT-1   control
# AACACACGTATGTCTG-1   control
# AACCCAAAGATAACAC-1   control
# AACCTTTGTTGACTAC-1   control
# AACGTCATCTTAGCAG-1   control
# ...                      ...
# TTTGGTTTCACCTGTC-1   control
# TTTGGTTTCGCTGACG-1   control
# TTTGGTTTCTGCTTAT-1   control
# TTTGTTGCAGAGATGC-1   control
# TTTGTTGGTGTTATCG-1   control
#
# [4010 rows x 1 columns]

# %% [markdown]
# ### New adata with all treatments

# %%
adata_all_treatments = adata_control.concatenate([adatas[1], adatas[2]], batch_categories = ['control', 'lps', 'pic'])
adata_all_treatments
# Out:
# c:\Python\Python310\lib\site-packages\anndata\_core\anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# AnnData object with n_obs × n_vars = 12030 × 30108
#     obs: 'treatment', 'batch'
#     var: 'gene_ids', 'feature_types'

# %%
adata_all_treatments.obs['treatment'] = adata_all_treatments.obs['treatment'].map({'control': 'control','lps': 'lps', 'pic': 'pic'})

# %%
adata_all_treatments.obs
# Out:
#                            treatment    batch
# AAAGGTAGTAGCTTGT-1-control   control  control
# AACACACGTATGTCTG-1-control   control  control
# AACCCAAAGATAACAC-1-control   control  control
# AACCTTTGTTGACTAC-1-control   control  control
# AACGTCATCTTAGCAG-1-control   control  control
# ...                              ...      ...
# TTTGGTTTCACCTGTC-1-pic       control      pic
# TTTGGTTTCGCTGACG-1-pic       control      pic
# TTTGGTTTCTGCTTAT-1-pic       control      pic
# TTTGTTGCAGAGATGC-1-pic       control      pic
# TTTGTTGGTGTTATCG-1-pic       control      pic
#
# [12030 rows x 2 columns]

# %%
adata_all_treatments.var
# Out:
#                               gene_ids    feature_types
# SPRY2               ENSGALG00010000711  Gene Expression
# PCDH20              ENSGALG00010000715  Gene Expression
# NDFIP2              ENSGALG00010000717  Gene Expression
# RBM26               ENSGALG00010000720  Gene Expression
# OBI1                ENSGALG00010000724  Gene Expression
# ...                                ...              ...
# ENSGALG00010000306  ENSGALG00010000306  Gene Expression
# ENSGALG00010000351  ENSGALG00010000351  Gene Expression
# ENSGALG00010000363  ENSGALG00010000363  Gene Expression
# ENSGALG00010000495  ENSGALG00010000495  Gene Expression
# ENSGALG00010000377  ENSGALG00010000377  Gene Expression
#
# [30108 rows x 2 columns]

# %%
genes = pd.read_csv('/Code/data/single_cell/animals/eggnog_croc_chic_komo_turt.csv')
genes.dropna(subset = ['chicken 110 gene id'], inplace=True)

genes_dict = dict(zip(genes['chicken 110 gene id'].astype('str'), genes.eggnog_name.astype('str'))) #change the column name to fit the animal

dict_multi, dict_uni = {}, {}
for d in genes_dict:
    if len(d.split(',')) != 1:
        dict_multi[d] = genes_dict[d]
    else:
        dict_uni[d] =  genes_dict[d]

multi_result_dict = {}

for key_str, value in dict_multi.items():
    # Convert the string key to a set
    key_set = set(key_str.strip("{}").replace("'", "").split(", "))

    # Iterate through the elements in the set and create individual keys
    for element in key_set:
        multi_result_dict[element] = value

genes_dict = {**dict_uni, **multi_result_dict}

genes_dict
# Out:
# {'ENSGALG00010022774': 'A1CF',
#  'ENSGALG00010012867': 'CYB5R3',
#  'ENSGALG00010024560': 'A4GNT',
#  'ENSGALG00010024389': 'AAAS',
#  'ENSGALG00010020928': 'AACS',
#  'ENSGALG00010001708': 'AADAC',
#  'ENSGALG00010008325': 'AADAT',
#  'ENSGALG00010008768': 'AAED1',
#  'ENSGALG00010018150': 'AAGAB',
#  'ENSGALG00010017516': 'AAK1',
#  'ENSGALG00010002039': 'AAMDC',
#  'ENSGALG00010019223': 'AAMP',
#  'ENSGALG00010029400': 'AANAT',
#  'ENSGALG00010024639': 'AAR2',
#  'ENSGALG00010021722': 'AARS',
#  'ENSGALG00010018354': 'AARS2',
#  'ENSGALG00010014902': 'AASDH',
#  'ENSGALG00010005177': 'AASDHPPT',
#  'ENSGALG00010001234': 'AASS',
#  'ENSGALG00010029352': 'AATF',
#  'ENSGALG00010029542': 'AATK',
#  'ENSGALG00010017337': 'ABAT',
#  'ENSGALG00010014122': 'ABCA1',
#  'ENSGALG00010011949': 'ABCA12',
#  'ENSGALG00010000626': 'ABCA13',
#  'ENSGALG00010028002': 'ABCA2',
#  'ENSGALG00010018864': 'ABCA3',
#  'ENSGALG00010021143': 'ABCA4',
#  'ENSGALG00010029418': 'ABCA5',
#  'ENSGALG00010029417': 'ABCA6',
#  'ENSGALG00010027974': 'ABCA7',
#  'ENSGALG00010029409': 'ABCA9',
#  'ENSGALG00010009554': 'ABCB10',
#  'ENSGALG00010024309': 'ABCB11',
#  'ENSGALG00010003061': 'ABCB5',
#  'ENSGALG00010021465': 'ABCB6',
#  'ENSGALG00010013464': 'ABCB7',
#  'ENSGALG00010027169': 'ABCB8',
#  'ENSGALG00010024943': 'ABCB9',
#  'ENSGALG00010020745': 'ABCC1',
#  'ENSGALG00010007633': 'ABCC10',
#  'ENSGALG00010007741': 'ABCC13',
#  'ENSGALG00010022211': 'ABCC2',
#  'ENSGALG00010029290': 'ABCC3',
#  'ENSGALG00010005402': 'ABCC4',
#  'ENSGALG00010017985': 'ABCC5',
#  'ENSGALG00010020803': 'ABCC6',
#  'ENSGALG00010023276': 'ABCC8',
#  'ENSGALG00010013156': 'ABCC9',
#  'ENSGALG00010008148': 'ABCD2',
#  'ENSGALG00010020934': 'ABCD3',
#  'ENSGALG00010006311': 'ABCD4',
#  'ENSGALG00010006353': 'ABCE1',
#  'ENSGALG00010025442': 'ABCF2',
#  'ENSGALG00010018008': 'ABCF3',
#  'ENSGALG00010011104': 'ABCG1',
#  'ENSGALG00010020622': 'ABCG2',
#  'ENSGALG00010024172': 'ABCG4',
#  'ENSGALG00010020352': 'ABCG5',
#  'ENSGALG00010020360': 'ABCG8',
#  'ENSGALG00010004487': 'ABHD10',
#  'ENSGALG00010029606': 'ABHD11',
#  'ENSGALG00010018399': 'ABHD12',
#  'ENSGALG00010019430': 'ABHD12B',
#  'ENSGALG00010014965': 'ABHD13',
#  'ENSGALG00010027538': 'ABHD14A',
#  'ENSGALG00010027931': 'ABHD17A',
#  'ENSGALG00010014176': 'ABHD17B',
#  'ENSGALG00010019778': 'ABHD17C',
#  'ENSGALG00010020147': 'ABHD2',
#  'ENSGALG00010005109': 'ABHD3',
#  'ENSGALG00010016335': 'ABHD5',
#  'ENSGALG00010027118': 'ABHD6',
#  'ENSGALG00010028588': 'ABHD8',
#  'ENSGALG00010022079': 'ABI2',
#  'ENSGALG00010024497': 'ABI3',
#  'ENSGALG00010005860': 'ABI3BP',
#  'ENSGALG00010027607': 'ABL1',
#  'ENSGALG00010011049': 'ABL2',
#  'ENSGALG00010022454': 'ABLIM1',
#  'ENSGALG00010009653': 'ABLIM2',
#  'ENSGALG00010012297': 'ABLIM3',
#  'ENSGALG00010029718': 'ABR',
#  'ENSGALG00010013191': 'ABRA',
#  'ENSGALG00010005975': 'ABRACL',
#  'ENSGALG00010026982': 'ABTB1',
#  'ENSGALG00010024886': 'ABTB2',
#  'ENSGALG00010026485': 'ACAA1',
#  'ENSGALG00010010463': 'ACAA2',
#  'ENSGALG00010029360': 'ACACA',
#  'ENSGALG00010021490': 'ACACB',
#  'ENSGALG00010018920': 'ACAD11',
#  'ENSGALG00010025379': 'ACAD8',
#  'ENSGALG00010027965': 'ACAD9',
#  'ENSGALG00010011424': 'ACADL',
#  'ENSGALG00010022862': 'ACADS',
#  'ENSGALG00010001811': 'ACADSB',
#  'ENSGALG00010020175': 'ACAN',
#  'ENSGALG00010002136': 'ACAP1',
#  'ENSGALG00010017500': 'ACAP2',
#  'ENSGALG00010018308': 'ACAP3',
#  'ENSGALG00010004890': 'ACAT1',
#  'ENSGALG00010004446': 'ACAT2',
#  'ENSGALG00010017524': 'ACBD3',
#  'ENSGALG00010023857': 'ACBD4',
#  'ENSGALG00010005349': 'ACBD5',
#  'ENSGALG00010010849': 'ACBD6',
#  'ENSGALG00010002661': 'ACBD7',
#  'ENSGALG00010019670': 'ACCS',
#  'ENSGALG00010023369': 'ACE',
#  'ENSGALG00010001524': 'ACE2',
#  'ENSGALG00010028570': 'ACER1',
#  'ENSGALG00010016314': 'ACER2',
#  'ENSGALG00010002211': 'ACER3',
#  'ENSGALG00010000453': 'ACHE',
#  'ENSGALG00010003882': 'ACIN1',
#  'ENSGALG00010011358': 'ACJ6',
#  'ENSGALG00010012429': 'ACKR3',
#  'ENSGALG00010018943': 'ACKR4',
#  'ENSGALG00010022919': 'ACLY',
#  'ENSGALG00010019550': 'ACMSD',
#  'ENSGALG00010002838': 'ACN9',
#  'ENSGALG00010009676': 'ACO1',
#  'ENSGALG00010012720': 'ACO2',
#  'ENSGALG00010025520': 'ACOT11',
#  'ENSGALG00010006588': 'ACOT12',
#  'ENSGALG00010008033': 'ACOT13',
#  'ENSGALG00010020898': 'ACOT4',
#  'ENSGALG00010019141': 'ACOT7',
#  'ENSGALG00010015932': 'ACOT8',
#  'ENSGALG00010003193': 'ACOT9',
#  'ENSGALG00010029755': 'ACOX1',
#  'ENSGALG00010020920': 'ACOX2',
#  'ENSGALG00010009294': 'ACOX3',
#  'ENSGALG00010003833': 'ACP1',
#  'ENSGALG00010022727': 'ACP2',
#  'ENSGALG00010003260': 'ACP5',
#  'ENSGALG00010018641': 'ACPP',
#  'ENSGALG00010021614': 'ACRBP',
#  'ENSGALG00010016923': 'ACRC',
#  'ENSGALG00010024274': 'ACSBG1',
#  'ENSGALG00010028562': 'ACSBG2',
#  'ENSGALG00010029650': 'ACSF2',
#  'ENSGALG00010007944': 'ACSF3',
#  'ENSGALG00010007007': 'ACSL1',
#  'ENSGALG00010025705': 'ACSL3',
#  'ENSGALG00010015540': 'ACSL4',
#  'ENSGALG00010019785': 'ACSL5',
#  'ENSGALG00010016127': 'ACSL6',
#  'ENSGALG00010017967': 'ACSM3',
#  'ENSGALG00010016390': 'ACSM4',
#  'ENSGALG00010016399': 'ACSM5',
#  'ENSGALG00010023439': 'ACSS2',
#  'ENSGALG00010012337': 'ACSS3',
#  'ENSGALG00010010295': 'ACTA1',
#  'ENSGALG00010022071': 'ACTC1',
#  'ENSGALG00010021232': 'ACTB',
#  'ENSGALG00010020613': 'ACTG2',
#  'ENSGALG00010010419': 'ACTL10',
#  'ENSGALG00010018172': 'ACTL6A',
#  'ENSGALG00010020389': 'ACTN1',
#  'ENSGALG00010009118': 'ACTN2',
#  'ENSGALG00010009277': 'ACTN4',
#  'ENSGALG00010018561': 'ACTR1A',
#  'ENSGALG00010016276': 'ACTR2',
#  'ENSGALG00010019319': 'ACTR3',
#  'ENSGALG00010027153': 'ACTR3B',
#  'ENSGALG00010023731': 'ACTR5',
#  'ENSGALG00010011496': 'ACTR6',
#  'ENSGALG00010027864': 'ACTR8',
#  'ENSGALG00010019660': 'ACTRT2',
#  'ENSGALG00010010745': 'ACVR1',
#  'ENSGALG00010022190': 'ACVR1B',
#  'ENSGALG00010010638': 'ACVR1C',
#  'ENSGALG00010009474': 'ACVR2A',
#  'ENSGALG00010027103': 'ACVR2B',
#  'ENSGALG00010022215': 'ACVRL1',
#  'ENSGALG00010027529': 'ACY1',
#  'ENSGALG00010006128': 'ACYP1',
#  'ENSGALG00010016916': 'ACYP2',
#  'ENSGALG00010024286': 'ADA',
#  'ENSGALG00010004235': 'ADAD1',
#  'ENSGALG00010024897': 'ADAL',
#  'ENSGALG00010025336': 'ADAM10',
#  'ENSGALG00010021782': 'ADAM11',
#  'ENSGALG00010002570': 'ADAM12',
#  'ENSGALG00010003348': 'ADAM17',
#  'ENSGALG00010015002': 'ADAM19',
#  'ENSGALG00010001774': 'ADAM20',
#  'ENSGALG00010004242': 'ADAM22',
#  'ENSGALG00010019012': 'ADAM28',
#  'ENSGALG00010018068': 'ADAM33',
#  'ENSGALG00010020013': 'ADAM8',
#  'ENSGALG00010017571': 'ADAM9',
#  'ENSGALG00010010659': 'ADAMTS1',
#  'ENSGALG00010028549': 'ADAMTS10',
#  'ENSGALG00010013174': 'ADAMTS12',
#  'ENSGALG00010028869': 'ADAMTS13',
#  'ENSGALG00010020285': 'ADAMTS14',
#  'ENSGALG00010022967': 'ADAMTS15',
#  'ENSGALG00010018887': 'ADAMTS17',
#  'ENSGALG00010007698': 'ADAMTS18',
#  'ENSGALG00010009683': 'ADAMTS19',
#  'ENSGALG00010015111': 'ADAMTS2',
#  'ENSGALG00010001858': 'ADAMTS20',
#  'ENSGALG00010004385': 'ADAMTS3',
#  'ENSGALG00010027561': 'ADAMTS4',
#  'ENSGALG00010010712': 'ADAMTS5',
#  'ENSGALG00010012188': 'ADAMTS6',
#  'ENSGALG00010016209': 'ADAMTS7',
#  'ENSGALG00010022959': 'ADAMTS8',
#  'ENSGALG00010020246': 'ADAMTS9',
#  'ENSGALG00010016043': 'ADAMTSL1',
#  'ENSGALG00010016874': 'ADAMTSL3',
#  'ENSGALG00010027448': 'ADAMTSL5',
#  'ENSGALG00010029597': 'ADAP2',
#  'ENSGALG00010027916': 'ADAR',
#  'ENSGALG00010013527': 'ADARB1',
#  'ENSGALG00010004275': 'ADARB2',
#  'ENSGALG00010008864': 'ADAT1',
#  'ENSGALG00010005712': 'ADAT2',
#  'ENSGALG00010004999': 'ADCK1',
#  'ENSGALG00010013393': 'ADCK2',
#  'ENSGALG00010018033': 'ADCK3',
#  'ENSGALG00010008108': 'ADCK5',
#  'ENSGALG00010008388': 'ADCY1',
#  'ENSGALG00010000808': 'ADCY2',
#  'ENSGALG00010010724': 'ADCY3',
#  'ENSGALG00010018531': 'ADCY5',
#  'ENSGALG00010022807': 'ADCY6',
#  'ENSGALG00010024074': 'ADCY7',
#  'ENSGALG00010007962': 'ADCY8',
#  'ENSGALG00010016544': 'ADCY9',
#  'ENSGALG00010004036': 'ADCYAP1',
#  'ENSGALG00010027355': 'ADCYAP1R1',
#  'ENSGALG00010016011': 'ADD1',
#  'ENSGALG00010019291': 'ADD2',
#  'ENSGALG00010020211': 'ADD3',
#  'ENSGALG00010005391': 'ADGB',
#  'ENSGALG00010021966': 'ADGRA1',
#  'ENSGALG00010004716': 'ADH6',
#  'ENSGALG00010006035': 'ADH7',
#  'ENSGALG00010002884': 'ADHFE1',
#  'ENSGALG00010003471': 'ADI1',
#  'ENSGALG00010025618': 'ADIPOQ',
#  'ENSGALG00010024810': 'ADIPOR1',
#  'ENSGALG00010013910': 'ADIPOR2',
#  'ENSGALG00010010541': 'ADIRF',
#  'ENSGALG00010022429': 'ADK',
#  'ENSGALG00010028497': 'ADMP',
#  'ENSGALG00010014260': 'ADNP',
#  'ENSGALG00010008011': 'ADNP2',
#  'ENSGALG00010024589': 'ADORA1',
#  'ENSGALG00010026448': 'ADORA2A',
#  'ENSGALG00010029723': 'ADORA2B',
#  'ENSGALG00010027577': 'ADORA3',
#  'ENSGALG00010021594': 'ADPGK',
#  'ENSGALG00010014488': 'ADPRHL1',
#  'ENSGALG00010018267': 'ADPRHL2',
#  'ENSGALG00010029563': 'ADPRM',
#  'ENSGALG00010018356': 'ADRA1A',
#  'ENSGALG00010009333': 'ADRA1B',
#  'ENSGALG00010016428': 'ADRA1D',
#  'ENSGALG00010019738': 'ADRA2A',
#  'ENSGALG00010020111': 'ADRA2B',
#  'ENSGALG00010016648': 'ADRA2C',
#  'ENSGALG00010022411': 'ADRB1',
#  'ENSGALG00010012314': 'ADRB2',
#  'ENSGALG00010017438': 'ADRB3',
#  'ENSGALG00010023175': 'ADRBK1',
#  'ENSGALG00010021212': 'MYO18B',
#  'ENSGALG00010022954': 'ADRM1',
#  'ENSGALG00010013095': 'ADSL',
#  'ENSGALG00010008285': 'ADSS',
#  'ENSGALG00010017318': 'ADSSL1',
#  'ENSGALG00010010626': 'ADTRP',
#  'ENSGALG00010019072': 'AEBP1',
#  'ENSGALG00010013791': 'AEBP2',
#  'ENSGALG00010015900': 'AEN',
#  'ENSGALG00010027173': 'AES',
#  'ENSGALG00010009608': 'AFAP1',
#  'ENSGALG00010011745': 'AFAP1L1',
#  'ENSGALG00010022436': 'AFAP1L2',
#  'ENSGALG00010004505': 'AFF1',
#  'ENSGALG00010013206': 'AFF2',
#  'ENSGALG00010015886': 'AFF3',
#  'ENSGALG00010013737': 'AFF4',
#  'ENSGALG00010001199': 'AFG3L2',
#  'ENSGALG00010029330': 'AFMID',
#  'ENSGALG00010017141': 'AFTPH',
#  'ENSGALG00010004457': 'AGA',
#  'ENSGALG00010012571': 'AGAP1',
#  'ENSGALG00010024966': 'AGAP3',
#  'ENSGALG00010020345': 'AGBL1',
#  'ENSGALG00010021737': 'AGBL2',
#  'ENSGALG00010027088': 'AGBL4',
#  'ENSGALG00010009089': 'AGBL5',
#  'ENSGALG00010023830': 'AGFG1',
#  'ENSGALG00010010457': 'AGGF1',
#  'ENSGALG00010013561': 'AGK',
#  'ENSGALG00010024024': 'AGL',
#  'ENSGALG00010020903': 'AGMAT',
#  'ENSGALG00010004109': 'AGMO',
#  'ENSGALG00010001674': 'AGO',
#  'ENSGALG00010014990': 'AGO1',
#  'ENSGALG00010009068': 'AGO2',
#  'ENSGALG00010014949': 'AGO3',
#  'ENSGALG00010015009': 'AGO4',
#  'ENSGALG00010011961': 'AGPAT3',
#  'ENSGALG00010006227': 'AGPAT4',
#  'ENSGALG00010002239': 'AGPAT5',
#  'ENSGALG00010018071': 'AGPAT6',
#  'ENSGALG00010024011': 'AGPS',
#  'ENSGALG00010004377': 'AGR2',
#  'ENSGALG00010004391': 'AGR3',
#  'ENSGALG00010021766': 'AGRN',
#  'ENSGALG00010021641': 'AGRP',
#  'ENSGALG00010007759': 'AGT',
#  'ENSGALG00010008636': 'AGTPBP1',
#  'ENSGALG00010017056': 'AGTR1',
#  'ENSGALG00010018860': 'AGTR2',
#  'ENSGALG00010017615': 'AGTRAP',
#  'ENSGALG00010024959': 'AGXT',
#  'ENSGALG00010013296': 'AGXT2',
#  'ENSGALG00010010125': 'AHCTF1',
#  'ENSGALG00010024732': 'AHCY',
#  'ENSGALG00010024459': 'AHCYL1',
#  'ENSGALG00010005511': 'AHCYL2',
#  'ENSGALG00010016852': 'AHDC1',
#  'ENSGALG00010005462': 'AHI1',
#  'ENSGALG00010004433': 'AHR',
#  'ENSGALG00010014105': 'AHR-1',
#  'ENSGALG00010013824': 'AHR2',
#  'ENSGALG00010008251': 'AHRR',
#  'ENSGALG00010005335': 'AHSA1',
#  'ENSGALG00010019287': 'AHSA2',
#  'ENSGALG00010016067': 'AHSG',
#  'ENSGALG00010022690': 'AICDA',
#  'ENSGALG00010016831': 'AIDA',
#  'ENSGALG00010027654': 'AIF1L',
#  'ENSGALG00010016598': 'AIFM1',
#  'ENSGALG00010020750': 'AIFM2',
#  'ENSGALG00010005748': 'AIG1',
#  'ENSGALG00010013160': 'AIM1',
#  'ENSGALG00010016744': 'AIM1L',
#  'ENSGALG00010006049': 'AIMP1',
#  'ENSGALG00010022042': 'AIP',
#  'ENSGALG00010016021': 'AIPL1',
#  'ENSGALG00010019630': 'AJAP1',
#  'ENSGALG00010028082': 'AK1',
#  'ENSGALG00010017707': 'AK2',
#  'ENSGALG00010011143': 'AK3',
#  'ENSGALG00010024132': 'AK4',
#  'ENSGALG00010022373': 'AK5',
#  'ENSGALG00010007322': 'AK6',
#  'ENSGALG00010015663': 'AK7',
#  'ENSGALG00010028800': 'AK8',
#  'ENSGALG00010014124': 'AK9',
#  'ENSGALG00010029522': 'AKAP1',
#  'ENSGALG00010029753': 'AKAP10',
#  'ENSGALG00010003271': 'AKAP11',
#  'ENSGALG00010005704': 'AKAP12',
#  'ENSGALG00010020117': 'AKAP13',
#  'ENSGALG00010012929': 'AKAP14',
#  'ENSGALG00010006957': 'AKAP2',
#  'ENSGALG00010017576': 'AKAP5',
#  'ENSGALG00010005763': 'AKAP6',
#  'ENSGALG00010003875': 'AKAP8',
#  'ENSGALG00010003865': 'AKAP8L',
#  'ENSGALG00010004841': 'AKAP9',
#  'ENSGALG00010003674': 'AKIRIN2',
#  'ENSGALG00010028894': 'AKNA',
#  'ENSGALG00010012089': 'AKNAD1',
#  'ENSGALG00010026213': 'AKR1A1',
#  'ENSGALG00010013501': 'AKR1B10',
#  'ENSGALG00010013290': 'AKR1D1',
#  'ENSGALG00010020576': 'AKR7A2',
#  'ENSGALG00010017364': 'AKT1',
#  'ENSGALG00010008377': 'AKT2',
#  'ENSGALG00010008323': 'AKT3',
#  'ENSGALG00010021747': 'AKTIP',
#  'ENSGALG00010027937': 'HDHD3',
#  'ENSGALG00010027410': 'ALAS1',
#  'ENSGALG00010005070': 'ALB',
#  'ENSGALG00010005150': 'ALCAM',
#  'ENSGALG00010001692': 'ALDH18A1',
#  'ENSGALG00010014104': 'ALDH1A1',
#  'ENSGALG00010023060': 'ALDH1A2',
#  'ENSGALG00010019001': 'ALDH1A3',
#  'ENSGALG00010011657': 'ALDH1L2',
#  'ENSGALG00010025886': 'ALDH2',
#  'ENSGALG00010029759': 'ALDH3A2',
#  'ENSGALG00010020467': 'ALDH4A1',
#  'ENSGALG00010008001': 'ALDH5A1',
#  'ENSGALG00010006580': 'ALDH6A1',
#  'ENSGALG00010001156': 'ALDH7A1',
#  'ENSGALG00010006336': 'ALDH8A1',
#  'ENSGALG00010010635': 'ALDH9A1',
#  'ENSGALG00010005583': 'ALDOB',
#  'ENSGALG00010029203': 'ALDOC',
#  'ENSGALG00010018713': 'ALG1',
#  'ENSGALG00010008183': 'ALG10',
#  'ENSGALG00010002449': 'ALG11',
#  'ENSGALG00010009003': 'ALG12',
#  'ENSGALG00010020991': 'ALG14',
#  'ENSGALG00010007603': 'ALG2',
#  'ENSGALG00010006310': 'ALG5',
#  'ENSGALG00010024192': 'ALG6',
#  'ENSGALG00010001938': 'ALG8',
#  'ENSGALG00010022986': 'ALG9',
#  'ENSGALG00010017563': 'ALK',
#  'ENSGALG00010004944': 'ALKBH1',
#  'ENSGALG00010021476': 'ALKBH2',
#  'ENSGALG00010019592': 'ALKBH3',
#  'ENSGALG00010029309': 'ALKBH4',
#  'ENSGALG00010017713': 'ALKBH5',
#  'ENSGALG00010004717': 'ALKBH8',
#  'ENSGALG00010018087': 'ALMS1',
#  'ENSGALG00010023818': 'ALOX5',
#  'ENSGALG00010006942': 'ALOX5AP',
#  'ENSGALG00010022261': 'ALOXE3',
#  'ENSGALG00010017681': 'ALPI',
#  'ENSGALG00010004039': 'ALPK1',
#  'ENSGALG00010010330': 'ALPK2',
#  'ENSGALG00010022253': 'ALPK3',
#  'ENSGALG00010021115': 'ALPL',
#  'ENSGALG00010025055': 'ALS2',
#  'ENSGALG00010024904': 'ALS2CL',
#  'ENSGALG00010011243': 'ALX1',
#  'ENSGALG00010024483': 'ALX3',
#  'ENSGALG00010019838': 'ALX4',
#  'ENSGALG00010029361': 'ALYREF',
#  'ENSGALG00010013203': 'AMACR',
#  'ENSGALG00010028475': 'AMBP',
#  'ENSGALG00010023866': 'AMBRA1',
#  'ENSGALG00010013814': 'AMD1',
#  'ENSGALG00010011876': 'AMDHD1',
#  'ENSGALG00010017468': 'AMDHD2',
#  'ENSGALG00010013356': 'AMER1',
#  'ENSGALG00010006024': 'AMER2',
#  'ENSGALG00010024264': 'AMER3',
#  'ENSGALG00010024413': 'AMFR',
#  'ENSGALG00010027880': 'AMH',
#  'ENSGALG00010014109': 'AMIGO2',
#  'ENSGALG00010028208': 'AMIGO3',
#  'ENSGALG00010015507': 'AMMECR1',
#  'ENSGALG00010024119': 'AMMECR1L',
#  'ENSGALG00010015137': 'AMN',
#  'ENSGALG00010010734': 'AMN1',
#  'ENSGALG00010013897': 'AMOT',
#  'ENSGALG00010008453': 'AMOTL1',
#  'ENSGALG00010024678': 'AMOTL2',
#  'ENSGALG00010025504': 'AMPD1',
#  'ENSGALG00010027923': 'AMPD2',
#  'ENSGALG00010021085': 'AMPD3',
#  'ENSGALG00010017970': 'AMPH',
#  'ENSGALG00010020112': 'AMZ1',
#  'ENSGALG00010017890': 'ANAPC1',
#  'ENSGALG00010006323': 'ANAPC10',
#  'ENSGALG00010021549': 'ANAPC16',
#  'ENSGALG00010027876': 'ANAPC2',
#  'ENSGALG00010010933': 'ANAPC4',
#  'ENSGALG00010025256': 'ANAPC5',
#  'ENSGALG00010025116': 'ANAPC7',
#  'ENSGALG00010005220': 'ANGEL1',
#  'ENSGALG00010019183': 'ANGEL2',
#  'ENSGALG00010011001': 'ANGPT1',
#  'ENSGALG00010029535': 'ANGPT1L',
#  'ENSGALG00010002288': 'ANGPT2',
#  'ENSGALG00010013755': 'ANGPT4',
#  'ENSGALG00010011271': 'ANGPTL1',
#  'ENSGALG00010028700': 'ANGPTL2',
#  'ENSGALG00010023885': 'ANGPTL3',
#  'ENSGALG00010027751': 'ANGPTL4',
#  'ENSGALG00010007937': 'ANGPTL5',
#  'ENSGALG00010021784': 'ANGPTL7',
#  'ENSGALG00010018193': 'ANK1',
#  'ENSGALG00010003978': 'ANK2',
#  'ENSGALG00010009679': 'ANK3',
#  'ENSGALG00010019185': 'ANKDD1A',
#  'ENSGALG00010010962': 'ANKDD1B',
#  'ENSGALG00010018334': 'ANKEF1',
#  'ENSGALG00010029163': 'ANKFY1',
#  'ENSGALG00010000722': 'ANKH',
#  'ENSGALG00010008618': 'EIF4EBP3',
#  'ENSGALG00010004891': 'ANKIB1',
#  'ENSGALG00010024932': 'ANKK1',
#  'ENSGALG00010028587': 'ANKLE1',
#  'ENSGALG00010021088': 'ANKLE2',
#  'ENSGALG00010028026': 'ANKMY1',
#  'ENSGALG00010004355': 'ANKMY2',
#  'ENSGALG00010011774': 'ANKRA2',
#  'ENSGALG00010020507': 'ANKRD1',
#  'ENSGALG00010013110': 'ANKRD10',
#  'ENSGALG00010007975': 'ANKRD11',
#  'ENSGALG00010001845': 'ANKRD12',
#  'ENSGALG00010021810': 'ANKRD13A',
#  'ENSGALG00010029699': 'ANKRD13B',
#  'ENSGALG00010024205': 'ANKRD13D',
#  'ENSGALG00010006670': 'ANKRD16',
#  'ENSGALG00010004443': 'ANKRD17',
#  'ENSGALG00010020642': 'ANKRD2',
#  'ENSGALG00010021999': 'ANKRD22',
#  'ENSGALG00010027220': 'ANKRD24',
#  'ENSGALG00010024806': 'ANKRD27',
#  'ENSGALG00010002134': 'ANKRD28',
#  'ENSGALG00010004902': 'ANKRD29',
#  'ENSGALG00010011059': 'ANKRD31',
#  'ENSGALG00010013327': 'ANKRD32',
#  'ENSGALG00010000786': 'ANKRD33B',
#  'ENSGALG00010020450': 'ANKRD39',
#  'ENSGALG00010029287': 'ANKRD40',
#  'ENSGALG00010008005': 'ANKRD42',
#  'ENSGALG00010010988': 'ANKRD44',
#  'ENSGALG00010011401': 'ANKRD46',
#  'ENSGALG00010008492': 'ANKRD49',
#  'ENSGALG00010004095': 'ANKRD50',
#  'ENSGALG00010024919': 'ANKRD52',
#  'ENSGALG00010010620': 'ANKRD54',
#  'ENSGALG00010012961': 'ANKRD55',
#  'ENSGALG00010003364': 'ANKRD6',
#  'ENSGALG00010021771': 'ANKRD61',
#  'ENSGALG00010001443': 'ANKRD7',
#  'ENSGALG00010008299': 'ANKRD66',
#  'ENSGALG00010017304': 'ANKRD9',
#  'ENSGALG00010026001': 'ANKS1A',
#  'ENSGALG00010016454': 'ANKS3',
#  'ENSGALG00010017092': 'ANKS4B',
#  'ENSGALG00010007910': 'ANKS6',
#  'ENSGALG00010021434': 'ANKZF1',
#  'ENSGALG00010016788': 'ANLN',
#  'ENSGALG00010025538': 'ANO1',
#  'ENSGALG00010016347': 'ANO10',
#  'ENSGALG00010019617': 'ANO3',
#  'ENSGALG00010011601': 'ANO4',
#  'ENSGALG00010020315': 'ANO5',
#  'ENSGALG00010013784': 'ANO6',
#  'ENSGALG00010028601': 'ANO8',
#  'ENSGALG00010017558': 'ANP32A',
#  'ENSGALG00010028543': 'ANP32B',
#  'ENSGALG00010028507': 'ANP32E',
#  'ENSGALG00010015905': 'ANPEP',
#  'ENSGALG00010017671': 'ANTXR1',
#  'ENSGALG00010003189': 'ANTXR2',
#  'ENSGALG00010020927': 'ANTXRL',
#  'ENSGALG00010014114': 'ANXA1',
#  'ENSGALG00010008049': 'ANXA10',
#  'ENSGALG00010008971': 'ANXA11',
#  'ENSGALG00010008286': 'ANXA13',
#  'ENSGALG00010024693': 'ANXA2',
#  'ENSGALG00010005260': 'ANXA5',
#  'ENSGALG00010014824': 'ANXA6',
#  'ENSGALG00010021248': 'ANXA7',
#  'ENSGALG00010020918': 'ANXA8',
#  'ENSGALG00010016766': 'AOAH',
#  'ENSGALG00010027191': 'AOC1',
#  'ENSGALG00010004079': 'AP1AR',
#  'ENSGALG00010000323': 'AP1B1',
#  'ENSGALG00010008426': 'AP1G1',
#  'ENSGALG00010027946': 'AP1M1',
#  'ENSGALG00010001510': 'AP1S2',
#  'ENSGALG00010025932': 'AP1S3',
#  'ENSGALG00010024250': 'AP2A2',
#  'ENSGALG00010029626': 'AP2B1',
#  'ENSGALG00010019023': 'AP2M1',
#  'ENSGALG00010010816': 'AP2S1',
#  'ENSGALG00010012751': 'AP3B1',
#  'ENSGALG00010023384': 'AP3B2',
#  'ENSGALG00010027897': 'AP3D1',
#  'ENSGALG00010022452': 'AP3M1',
#  'ENSGALG00010017920': 'AP3M2',
#  'ENSGALG00010009103': 'AP3S1',
#  'ENSGALG00010015942': 'AP3S2',
#  'ENSGALG00010027402': 'AP4B1',
#  'ENSGALG00010022573': 'AP4E1',
#  'ENSGALG00010005535': 'AP4S1',
#  'ENSGALG00010017201': 'AP5M1',
#  'ENSGALG00010021146': 'AP5Z1',
#  'ENSGALG00010010618': 'APAF1',
#  'ENSGALG00010014837': 'APBA1',
#  'ENSGALG00010024814': 'APBA2',
#  'ENSGALG00010028103': 'APBA3',
#  'ENSGALG00010001605': 'APBB1',
#  'ENSGALG00010005408': 'APBB1IP',
#  'ENSGALG00010015636': 'APBB2',
#  'ENSGALG00010008333': 'APC',
#  'ENSGALG00010001754': 'APCDD1',
#  'ENSGALG00010014777': 'APCDD1L',
#  'ENSGALG00010027303': 'APEH',
#  'ENSGALG00010007985': 'APELA',
#  'ENSGALG00010021048': 'API5',
#  'ENSGALG00010024945': 'APIP',
#  'ENSGALG00010016736': 'APITD1',
#  'ENSGALG00010017867': 'APLF',
#  'ENSGALG00010014943': 'APLN',
#  'ENSGALG00010026507': 'APLNR',
#  'ENSGALG00010023571': 'APLP2',
#  'ENSGALG00010018892': 'APMAP',
#  'ENSGALG00010024773': 'APOA1',
#  'ENSGALG00010028088': 'APOA1BP',
#  'ENSGALG00010024750': 'APOA4',
#  'ENSGALG00010007977': 'APOB',
#  'ENSGALG00010027623': 'APOBEC2',
#  'ENSGALG00010011540': 'APOBEC4',
#  'ENSGALG00010024759': 'APOC3',
#  'ENSGALG00010017424': 'APOD',
#  'ENSGALG00010024983': 'APOF',
#  'ENSGALG00010029213': 'APOH',
#  'ENSGALG00010009659': 'APOLD1',
#  'ENSGALG00010003125': 'APOO',
#  'ENSGALG00010018310': 'APOOL',
#  'ENSGALG00010015916': 'APOPT1',
#  'ENSGALG00010004359': 'APOV1',
#  'ENSGALG00010010915': 'APP',
#  'ENSGALG00010029199': 'APPBP2',
#  'ENSGALG00010027052': 'APPL1',
#  'ENSGALG00010011605': 'APPL2',
#  'ENSGALG00010007899': 'APRT',
#  'ENSGALG00010008141': 'APTX',
#  'ENSGALG00010027337': 'AQP1',
#  'ENSGALG00010027878': 'AQP10',
#  'ENSGALG00010002090': 'AQP11',
#  'ENSGALG00010024730': 'AQP12B',
#  'ENSGALG00010025593': 'AQP2',
#  'ENSGALG00010010572': 'AQP3',
#  'ENSGALG00010005544': 'AQP4',
#  'ENSGALG00010025615': 'AQP5',
#  'ENSGALG00010011486': 'AQP7',
#  'ENSGALG00010018335': 'AQP8',
#  'ENSGALG00010023054': 'AQP9',
#  'ENSGALG00010005436': 'AQR',
#  'ENSGALG00010016880': 'AR',
#  'ENSGALG00010014705': 'ARAP2',
#  'ENSGALG00010011564': 'ARAP3',
#  'ENSGALG00010007950': 'ARC',
#  'ENSGALG00010023798': 'ARCN1',
#  'ENSGALG00010003223': 'AREG',
#  'ENSGALG00010005981': 'AREL1',
#  'ENSGALG00010026097': 'ARF1',
#  'ENSGALG00010027077': 'ARF4',
#  'ENSGALG00010006288': 'ARF5',
#  'ENSGALG00010019204': 'ARF6',
#  'ENSGALG00010023048': 'ARFGAP1',
#  'ENSGALG00010022838': 'ARFGAP2',
#  'ENSGALG00010012147': 'ARFGAP3',
#  'ENSGALG00010004187': 'ARFGEF1',
#  'ENSGALG00010023997': 'ARFGEF2',
#  'ENSGALG00010007663': 'ARFIP1',
#  'ENSGALG00010001627': 'ARFIP2',
#  'ENSGALG00010024960': 'ARFRP1',
#  'ENSGALG00010019912': 'ARG2',
#  'ENSGALG00010015016': 'ARGLU1',
#  'ENSGALG00010022997': 'ARHGAP1',
#  'ENSGALG00010006682': 'ARHGAP10',
#  'ENSGALG00010021647': 'ARHGAP11A',
#  'ENSGALG00010005757': 'ARHGAP12',
#  'ENSGALG00010009373': 'ARHGAP15',
#  'ENSGALG00010018276': 'ARHGAP17',
#  'ENSGALG00010006066': 'ARHGAP18',
#  'ENSGALG00010020759': 'ARHGAP19',
#  'ENSGALG00010005350': 'ARHGAP20',
#  'ENSGALG00010005159': 'ARHGAP21',
#  'ENSGALG00010020520': 'ARHGAP22',
#  'ENSGALG00010003878': 'ARHGAP24',
#  'ENSGALG00010020323': 'ARHGAP25',
#  'ENSGALG00010016732': 'ARHGAP26',
#  'ENSGALG00010023551': 'ARHGAP27',
#  'ENSGALG00010002017': 'ARHGAP28',
#  'ENSGALG00010021139': 'ARHGAP29',
#  'ENSGALG00010028486': 'ARHGAP30',
#  'ENSGALG00010025574': 'ARHGAP31',
#  'ENSGALG00010023453': 'ARHGAP32',
#  'ENSGALG00010009020': 'ARHGAP35',
#  'ENSGALG00010019125': 'ARHGAP36',
#  'ENSGALG00010023712': 'ARHGAP40',
#  'ENSGALG00010008218': 'ARHGAP42',
#  'ENSGALG00010029930': 'ARHGAP44',
#  'ENSGALG00010005714': 'ARHGAP5',
#  'ENSGALG00010001966': 'ARHGAP6',
#  'ENSGALG00010013376': 'ARHGAP8',
#  'ENSGALG00010029357': 'ARHGDIA',
#  'ENSGALG00010012059': 'ARHGDIB',
#  'ENSGALG00010016919': 'ARHGDIG',
#  'ENSGALG00010001896': 'ARHGEF10',
#  'ENSGALG00010018502': 'ARHGEF10L',
#  'ENSGALG00010027826': 'ARHGEF11',
#  'ENSGALG00010025907': 'ARHGEF12',
#  'ENSGALG00010021459': 'ARHGEF16',
#  'ENSGALG00010027244': 'ARHGEF18',
#  'ENSGALG00010001469': 'ARHGEF26',
#  'ENSGALG00010011724': 'ARHGEF28',
#  'ENSGALG00010027027': 'ARHGEF3',
#  'ENSGALG00010017218': 'ARHGEF33',
#  'ENSGALG00010008217': 'ARHGEF37',
#  'ENSGALG00010006243': 'ARHGEF38',
#  'ENSGALG00010012334': 'ARHGEF39',
#  'ENSGALG00010024234': 'ARHGEF4',
#  'ENSGALG00010024614': 'ARHGEF5',
#  'ENSGALG00010015866': 'ARHGEF6',
#  'ENSGALG00010013080': 'ARHGEF7',
#  'ENSGALG00010012034': 'ARHGEF9',
#  'ENSGALG00010014301': 'ARID1A',
#  'ENSGALG00010004101': 'ARID1B',
#  'ENSGALG00010013878': 'ARID2',
#  'ENSGALG00010021147': 'ARID3B',
#  'ENSGALG00010017384': 'ARID4B',
#  'ENSGALG00010020597': 'ARID5A',
#  'ENSGALG00010009502': 'ARID5B',
#  'ENSGALG00010021577': 'ARIH1',
#  'ENSGALG00010020732': 'ARIH2',
#  'ENSGALG00010011692': 'ARL1',
#  'ENSGALG00010014305': 'ARL10',
#  'ENSGALG00010004070': 'ARL11',
#  'ENSGALG00010006273': 'ARL13B',
#  'ENSGALG00010001163': 'ARL14',
#  'ENSGALG00010022978': 'ARL14EP',
#  'ENSGALG00010009084': 'ARL14EPL',
#  'ENSGALG00010014992': 'ARL15',
#  'ENSGALG00010029346': 'ARL16',
#  'ENSGALG00010018685': 'ARL3',
#  'ENSGALG00010004029': 'ARL4A',
#  'ENSGALG00010012744': 'ARL4C',
#  'ENSGALG00010010205': 'ARL5A',
#  'ENSGALG00010006028': 'ARL5B',
#  'ENSGALG00010007110': 'CRYBG3',
#  'ENSGALG00010020916': 'ARL6IP1',
#  'ENSGALG00010024893': 'ARL6IP4',
#  'ENSGALG00010020070': 'ARL6IP5',
#  'ENSGALG00010021730': 'ARL8B',
#  'ENSGALG00010001647': 'ARL8BL',
#  'ENSGALG00010003743': 'ARL9',
#  'ENSGALG00010003121': 'ARMC1',
#  'ENSGALG00010009616': 'ARMC10',
#  'ENSGALG00010014288': 'ARMC2',
#  'ENSGALG00010004231': 'ARMC3',
#  'ENSGALG00010005299': 'ARMC4',
#  'ENSGALG00010028150': 'ARMC6',
#  'ENSGALG00010029694': 'ARMC7',
#  'ENSGALG00010022644': 'ARMC8',
#  'ENSGALG00010015477': 'ARMC9',
#  'ENSGALG00010028764': 'ARNT',
#  'ENSGALG00010019789': 'ARNT2',
#  'ENSGALG00010021726': 'ARNTL',
#  'ENSGALG00010012985': 'ARNTL2',
#  'ENSGALG00010021325': 'ARPC1A',
#  'ENSGALG00010021362': 'ARPC1B',
#  'ENSGALG00010019233': 'ARPC2',
#  'ENSGALG00010025102': 'ARPC3',
#  'ENSGALG00010021599': 'ARPC4',
#  'ENSGALG00010011530': 'ARPC5',
#  'ENSGALG00010028106': 'ARPC5L',
#  'ENSGALG00010020887': 'ARPP19',
#  'ENSGALG00010018378': 'ARPP21',
#  'ENSGALG00010017690': 'ARR3',
#  'ENSGALG00010028743': 'ARRDC1',
#  'ENSGALG00010027232': 'ARRDC2',
#  'ENSGALG00010012830': 'ARRDC3',
#  'ENSGALG00010018623': 'ARRDC4',
#  'ENSGALG00010007425': 'ARSA',
#  'ENSGALG00010013306': 'ARSB',
#  'ENSGALG00010029391': 'ARSG',
#  'ENSGALG00010013531': 'ARSI',
#  'ENSGALG00010003768': 'ARSJ',
#  'ENSGALG00010013117': 'ARSK',
#  'ENSGALG00010012098': 'ART4',
#  'ENSGALG00010021384': 'ARTN',
#  'ENSGALG00010007809': 'ARV1',
#  'ENSGALG00010024616': 'ARVCF',
#  'ENSGALG00010002079': 'ARX',
#  'ENSGALG00010018229': 'AS3MT',
#  'ENSGALG00010015695': 'ASAH1',
#  'ENSGALG00010003242': 'ASAP2',
#  'ENSGALG00010016556': 'ASAP3',
#  'ENSGALG00010013494': 'ASB1',
#  'ENSGALG00010024823': 'ASB10',
#  'ENSGALG00010001427': 'ASB11',
#  'ENSGALG00010013382': 'ASB12',
#  'ENSGALG00010006838': 'ASB13',
#  'ENSGALG00010027059': 'ASB14',
#  'ENSGALG00010001699': 'ASB15',
#  'ENSGALG00010012474': 'ASB18',
#  'ENSGALG00010016987': 'ASB2',
#  'ENSGALG00010016972': 'ASB3',
#  'ENSGALG00010002928': 'ASB4',
#  'ENSGALG00010003412': 'ASB5',
#  'ENSGALG00010028010': 'ASB6',
#  'ENSGALG00010018961': 'ASB7',
#  'ENSGALG00010024553': 'ASB8',
#  'ENSGALG00010001461': 'ASB9',
#  'ENSGALG00010021645': 'ASCC1',
#  'ENSGALG00010000376': 'ASCC2',
#  'ENSGALG00010015140': 'ASCC3',
#  'ENSGALG00010011057': 'ASCL1',
#  'ENSGALG00010024569': 'ASCL2',
#  'ENSGALG00010020586': 'C11ORF16',
#  'ENSGALG00010015080': 'ASF1A',
#  'ENSGALG00010028392': 'ASH1L',
#  'ENSGALG00010017774': 'ASH2L',
#  'ENSGALG00010023231': 'ASIC1',
#  'ENSGALG00010022691': 'ASIC2',
#  'ENSGALG00010027167': 'ASIC3',
#  'ENSGALG00010018361': 'ASIC4',
#  'ENSGALG00010008140': 'ASIC5',
#  'ENSGALG00010024739': 'ASIP',
#  'ENSGALG00010029665': 'ASL',
#  'ENSGALG00010001536': 'ASMT',
#  'ENSGALG00010001807': 'ASMTL',
#  'ENSGALG00010003382': 'ASNS',
#  'ENSGALG00010012943': 'ASNSD1',
#  'ENSGALG00010029749': 'ASPA',
#  'ENSGALG00010000571': 'ASPDH',
#  'ENSGALG00010016159': 'ASPG',
#  'ENSGALG00010003960': 'ASPH',
#  'ENSGALG00010023510': 'ASPHD2',
#  'ENSGALG00010010358': 'ASPM',
#  'ENSGALG00010027201': 'ASPN',
#  'ENSGALG00010029177': 'ASPSCR1',
#  'ENSGALG00010002463': 'ASRGL1',
#  'ENSGALG00010027383': 'ASS1',
#  'ENSGALG00010018497': 'ASTE1',
#  'ENSGALG00010021777': 'ASTL',
#  'ENSGALG00010010430': 'ASTN1',
#  'ENSGALG00010028903': 'ASTN2',
#  'ENSGALG00010014728': 'ASUN',
#  'ENSGALG00010013352': 'ASXL1',
#  'ENSGALG00010009383': 'ASXL2',
#  'ENSGALG00010005309': 'ASXL3',
#  'ENSGALG00010001207': 'ASZ1',
#  'ENSGALG00010022685': 'ATAD1',
#  'ENSGALG00010008023': 'ATAD2',
#  'ENSGALG00010009695': 'ATAD2B',
#  'ENSGALG00010017714': 'ATAD3A',
#  'ENSGALG00010029596': 'ATAD5',
#  'ENSGALG00010027831': 'ATCAY',
#  'ENSGALG00010001426': 'ATE1',
#  'ENSGALG00010022397': 'ATF1',
#  'ENSGALG00010022485': 'ATF2',
#  'ENSGALG00010019307': 'ATF3',
#  'ENSGALG00010012407': 'ATF4',
#  'ENSGALG00010012932': 'ATF6',
#  'ENSGALG00010024238': 'ATF7',
#  'ENSGALG00010011144': 'ATF7IP',
#  'ENSGALG00010006223': 'ATG10',
#  'ENSGALG00010025496': 'ATG101',
#  'ENSGALG00010009120': 'ATG12',
#  'ENSGALG00010023064': 'ATG13',
#  'ENSGALG00010018501': 'ATG14',
#  'ENSGALG00010023002': 'ATG16L1',
#  'ENSGALG00010015614': 'ATG2B',
#  'ENSGALG00010005261': 'ATG3',
#  'ENSGALG00010015782': 'ATG4A',
#  'ENSGALG00010024918': 'ATG4B',
#  'ENSGALG00010024179': 'ATG4C',
#  'ENSGALG00010013247': 'ATG5',
#  'ENSGALG00010027247': 'ATG7',
#  'ENSGALG00010021444': 'ATG9A',
#  'ENSGALG00010027171': 'ATG9B',
#  'ENSGALG00010020839': 'ATHL1',
#  'ENSGALG00010011965': 'ATIC',
#  'ENSGALG00010019334': 'ATL1',
#  'ENSGALG00010016994': 'ATL2',
#  'ENSGALG00010004824': 'ATM',
#  'ENSGALG00010007862': 'ATMIN',
#  'ENSGALG00010022922': 'ATOH7',
#  'ENSGALG00010017718': 'ATOH8',
#  'ENSGALG00010014319': 'ATOX1',
#  'ENSGALG00010015992': 'ATP10A',
#  'ENSGALG00010010035': 'ATP10B',
#  'ENSGALG00010013459': 'ATP10D',
#  'ENSGALG00010013263': 'ATP11A',
#  'ENSGALG00010016588': 'ATP11B',
#  'ENSGALG00010017534': 'ATP11C',
#  'ENSGALG00010025507': 'ATP12A',
#  'ENSGALG00010002581': 'ATP13A1',
#  'ENSGALG00010020399': 'ATP13A2',
#  'ENSGALG00010014411': 'ATP13A3',
#  'ENSGALG00010013759': 'ATP13A4',
#  'ENSGALG00010013786': 'ATP13A5',
#  'ENSGALG00010025292': 'ATP1A1',
#  'ENSGALG00010005362': 'ATP1B1',
#  'ENSGALG00010023940': 'ATP1B3',
#  'ENSGALG00010012759': 'ATP1B4',
#  'ENSGALG00010025130': 'ATP2A2',
#  'ENSGALG00010029576': 'ATP2A3',
#  'ENSGALG00010013285': 'ATP2B1',
#  'ENSGALG00010027231': 'ATP2B2',
#  'ENSGALG00010027490': 'ATP2B4',
#  'ENSGALG00010018485': 'ATP2C1',
#  'ENSGALG00010014454': 'ATP4B',
#  'ENSGALG00010025098': 'ATP5B',
#  'ENSGALG00010005283': 'ATP5C1',
#  'ENSGALG00010028021': 'ATP5D',
#  'ENSGALG00010016303': 'ATP5E',
#  'ENSGALG00010027569': 'ATP5F1',
#  'ENSGALG00010026305': 'ATP5G1',
#  'ENSGALG00010022734': 'ATP5G2',
#  'ENSGALG00010022456': 'ATP5G3',
#  'ENSGALG00010029685': 'ATP5H',
#  'ENSGALG00010013446': 'ATP5I',
#  'ENSGALG00010010855': 'ATP5J',
#  'ENSGALG00010021454': 'ATP5J2',
#  'ENSGALG00010024259': 'ATP5L',
#  'ENSGALG00010012606': 'ATP5O',
#  'ENSGALG00010019266': 'ATP5S',
#  'ENSGALG00010000023': 'ATP6',
#  'ENSGALG00010001712': 'ATP6AP1',
#  'ENSGALG00010006121': 'ATP6AP1L',
#  'ENSGALG00010002546': 'ATP6AP2',
#  'ENSGALG00010021196': 'ATP6V0A1',
#  'ENSGALG00010024681': 'ATP6V0A2',
#  'ENSGALG00010013224': 'ATP6V0A4',
#  'ENSGALG00010024527': 'ATP6V0B',
#  'ENSGALG00010017476': 'ATP6V0C',
#  'ENSGALG00010021637': 'ATP6V0D1',
#  'ENSGALG00010013339': 'ATP6V0D2',
#  'ENSGALG00010009228': 'ATP6V0E1',
#  'ENSGALG00010022234': 'COX15',
#  'ENSGALG00010018495': 'ATP6V1B1',
#  'ENSGALG00010017694': 'ATP6V1B2',
#  'ENSGALG00010010906': 'ATP6V1C1',
#  'ENSGALG00010002590': 'ATP6V1C2',
#  'ENSGALG00010020015': 'ATP6V1D',
#  'ENSGALG00010012315': 'ATP6V1E1',
#  'ENSGALG00010028896': 'ATP6V1G1',
#  'ENSGALG00010012371': 'ATP6V1G3',
#  'ENSGALG00010004370': 'ATP6V1H',
#  'ENSGALG00010013678': 'ATP7A',
#  'ENSGALG00010002435': 'ATP7B',
#  'ENSGALG00010000022': 'ATP8',
#  'ENSGALG00010005935': 'ATP8A1',
#  'ENSGALG00010010975': 'ATP8B1',
#  'ENSGALG00010027883': 'ATP8B2',
#  'ENSGALG00010028435': 'ATP8B3',
#  'ENSGALG00010009223': 'ATP8B5',
#  'ENSGALG00010015362': 'ATP9A',
#  'ENSGALG00010007319': 'ATP9B',
#  'ENSGALG00010022867': 'ATPAF1',
#  'ENSGALG00010017589': 'ATPAF2',
#  'ENSGALG00010015749': 'ATR',
#  'ENSGALG00010009227': 'ATRAID',
#  'ENSGALG00010027185': 'ATRIP',
#  'ENSGALG00010018021': 'ATRN',
#  'ENSGALG00010022603': 'ATRNL1',
#  'ENSGALG00010013614': 'ATRX',
#  'ENSGALG00010011126': 'ATXN1',
#  'ENSGALG00010012329': 'ATXN10',
#  'ENSGALG00010008397': 'ATXN1L',
#  'ENSGALG00010025805': 'ATXN2',
#  'ENSGALG00010015300': 'ATXN3',
#  'ENSGALG00010020152': 'ATXN7',
#  'ENSGALG00010010216': 'ATXN7L1',
#  'ENSGALG00010009396': 'AUH',
#  'ENSGALG00010005366': 'AUP1',
#  'ENSGALG00010013249': 'AURKA',
#  'ENSGALG00010029371': 'AUTS2',
#  'ENSGALG00010007863': 'AVBD1',
#  'ENSGALG00010011448': 'AVBD10',
#  'ENSGALG00010011435': 'AVBD11',
#  'ENSGALG00010011392': 'AVBD13',
#  'ENSGALG00010007881': 'AVBD14',
#  'ENSGALG00010007870': 'AVBD3',
#  'ENSGALG00010007875': 'AVBD4',
#  'ENSGALG00010011870': 'AVBD6',
#  'ENSGALG00010011455': 'AVBD8',
#  'ENSGALG00010011980': 'AVBD9',
#  'ENSGALG00010011634': 'AVD',
#  'ENSGALG00010021111': 'AVEN',
#  'ENSGALG00010019356': 'AVL9',
#  'ENSGALG00010016587': 'AVP',
#  'ENSGALG00010011713': 'AVPR1A',
#  'ENSGALG00010027091': 'AVPR1B',
#  'ENSGALG00010001751': 'AVPR2',
#  'ENSGALG00010012856': 'AVR2',
#  'ENSGALG00010017632': 'AWAT2',
#  'ENSGALG00010010956': 'AXDND1',
#  'ENSGALG00010016911': 'AXIN1',
#  'ENSGALG00010029221': 'AXIN2',
#  'ENSGALG00010002622': 'AZI2',
#  'ENSGALG00010012061': 'AZIN1',
#  'ENSGALG00010017727': 'AZIN2',
#  'ENSGALG00010023281': 'B2M',
#  'ENSGALG00010001161': 'B3GALNT1',
#  'ENSGALG00010009439': 'B3GALNT2',
#  'ENSGALG00010025486': 'B3GALT1',
#  'ENSGALG00010012618': 'B3GALT2',
#  'ENSGALG00010013492': 'B3GALT5',
#  'ENSGALG00010006903': 'B3GALTL',
#  'ENSGALG00010025417': 'B3GAT1',
#  'ENSGALG00010001633': 'B3GAT2',
#  'ENSGALG00010017838': 'B3GNT2',
#  'ENSGALG00010027611': 'B3GNT3',
#  'ENSGALG00010025445': 'B3GNT4',
#  'ENSGALG00010016431': 'B3GNT5',
#  'ENSGALG00010015563': 'B3GNT7',
#  'ENSGALG00010024434': 'B3GNT9',
#  'ENSGALG00010029413': 'B3GNTL1',
#  'ENSGALG00010012274': 'B4GALNT3',
#  'ENSGALG00010009486': 'B4GALT1',
#  'ENSGALG00010021400': 'B4GALT2',
#  'ENSGALG00010025523': 'B4GALT4',
#  ...}

# %%
adata_all_treatments.obs
# Out:
#                            treatment    batch
# AAAGGTAGTAGCTTGT-1-control   control  control
# AACACACGTATGTCTG-1-control   control  control
# AACCCAAAGATAACAC-1-control   control  control
# AACCTTTGTTGACTAC-1-control   control  control
# AACGTCATCTTAGCAG-1-control   control  control
# ...                              ...      ...
# TTTGGTTTCACCTGTC-1-pic       control      pic
# TTTGGTTTCGCTGACG-1-pic       control      pic
# TTTGGTTTCTGCTTAT-1-pic       control      pic
# TTTGTTGCAGAGATGC-1-pic       control      pic
# TTTGTTGGTGTTATCG-1-pic       control      pic
#
# [12030 rows x 2 columns]

# %%
adata_all_treatments.var
# Out:
#                               gene_ids    feature_types
# SPRY2               ENSGALG00010000711  Gene Expression
# PCDH20              ENSGALG00010000715  Gene Expression
# NDFIP2              ENSGALG00010000717  Gene Expression
# RBM26               ENSGALG00010000720  Gene Expression
# OBI1                ENSGALG00010000724  Gene Expression
# ...                                ...              ...
# ENSGALG00010000306  ENSGALG00010000306  Gene Expression
# ENSGALG00010000351  ENSGALG00010000351  Gene Expression
# ENSGALG00010000363  ENSGALG00010000363  Gene Expression
# ENSGALG00010000495  ENSGALG00010000495  Gene Expression
# ENSGALG00010000377  ENSGALG00010000377  Gene Expression
#
# [30108 rows x 2 columns]

# %%
adata_all_treatments.var.set_index('gene_ids', inplace=True) 
adata_all_treatments.var['gene_ids'] = adata.var.index

adata_all_treatments.var.drop(columns='feature_types', inplace=True)
adata_all_treatments.var.rename(genes_dict, inplace=True)

# %%
# Get a Series of variable (gene) names
var_names_series = pd.Series(adata_all_treatments.var_names)

# Identify duplicate variable names
duplicate_var_names = var_names_series[var_names_series.duplicated(keep='first')]

# Iterate through duplicates and add suffixes to make them unique from the first occurrence
for duplicate_name in duplicate_var_names:
    count = 1
    indices = var_names_series[var_names_series == duplicate_name].index
    for idx in indices:
        var_names_series[idx] = f'{duplicate_name}_{count}'
        count += 1

# Update the AnnData object with the unique variable names
adata_all_treatments.var_names = var_names_series.values

adata_all_treatments.var_names
# Out:
# Index(['SPRY2', 'PCDH20', 'NDFIP2', 'RBM26', 'RNF219', 'POU4F1', 'EDNRB',
#        'SLAIN1', 'SCEL', 'ENSGALG00010000762',
#        ...
#        'ENSGALG00010000070', 'POLD1', 'ENSGALG00010000446',
#        'ENSGALG00010001431', 'ENSGALG00010000482', 'DENND4B',
#        'ENSGALG00010000351', 'ENSGALG00010000363', 'ENSGALG00010000495',
#        'SNRPA'],
#       dtype='object', length=30108)

# %% [markdown]
# ## Genes and cells filtration

# %% [markdown]
# ### Highly expressed genes ( = top 20 genes)

# %%
sc.pl.highest_expr_genes(adata_all_treatments, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
sc.pp.filter_cells(adata_all_treatments, min_genes=100) 
sc.pp.filter_genes(adata_all_treatments, min_cells=3)
print(adata_all_treatments.shape)
# Out:
# filtered out 54 cells that have less than 100 genes expressed
# filtered out 13215 genes that are detected in less than 3 cells
# (11976, 16893)

# %% [markdown]
# ### Mitochondrial QC and general measures
# Check if genes are annotated as mt by running:
# - GENES= list(adata.var.index[adata.var.index.str.startswith('mt-'.upper())])
# - GENES
#
# In case the genes are not annotated as 'MT-'' (Like in bats), run:
#
# - dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2'...etc}
# - adata.var.rename(dict_replace, inplace = True)

# %%
dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2','COX3':'MT-COX3','ND1':'MT-ND1-1','ND1':'MT-ND1-2','ND2':'MT-ND2',
                'ND3':'MT-ND3','ND4':'MT-ND4','ND5':'MT-ND5','ND6':'MT-ND6','ND4L-1':'MT-ND4L','ATP6':'MT-ATP6','ATP8':'MT-ATP8',
                'CYTB':'MT-CYTB'}
adata_all_treatments.var.rename(dict_replace, inplace=True)

# %%
adata_all_treatments.var['MT'] = adata_all_treatments.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'MT'
sc.pp.calculate_qc_metrics(adata_all_treatments, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pp.calculate_qc_metrics(adata_all_treatments, percent_top=None, log1p=False, inplace=True)

# %% [markdown]
# ### Scatter plots of QC metrics

# %%
sc.pl.scatter(adata_all_treatments, x='total_counts', y='n_genes_by_counts', color='treatment')
sc.pl.scatter(adata_all_treatments, x='total_counts', y='pct_counts_MT', color='treatment')
sc.pl.scatter(adata_all_treatments, x='total_counts', y='n_genes', color='treatment', save=True)
# Out:
# WARNING: saving figure to file figures\scatter.pdf

# %%
adata_all_treatments = adata_all_treatments[adata_all_treatments.obs.pct_counts_MT < 20] 
adata_all_treatments = adata_all_treatments[adata_all_treatments.obs.total_counts < 5000, :] # If filtering outliers (<0.1% of cells)

# %% [markdown]
# ## Doublet analysis and filtering

# %%
import scrublet as scr

def scrub(adatas, adata_all_treatments, adata_all_treatments_names):  # based on raw individual samples. 
    print('Before scrublet: ', adata.shape[0])
    doub_index = []
    barcodes = []
    for data,name in zip(adatas, adata_all_treatments_names):
        data.raw = data
        sc.pp.normalize_total(data, target_sum=1e4)
        sc.pp.log1p(data)
        scrub = scr.Scrublet(data.raw.X)
        data.obs['doublet_scores'], data.obs['predicted_doublets'] = scrub.scrub_doublets()
        scrub.plot_histogram()
        print('Doublets' + name + ' :', data.obs[data.obs['doublet_scores'] > 0.25].shape[0])
        barcodes = data.obs[data.obs['doublet_scores'] < 0.25].index.to_list()
        for barcode in barcodes:
            doub_index.append(barcode + '-' + name)

    adata_all_treatments = adata_all_treatments[adata_all_treatments.obs.index.isin(doub_index)]
    print('After scrublet: ', adata_all_treatments.shape[0])
    return adata_all_treatments

# %%
adata_all_treatments = scrub(adatas, adata_all_treatments, data_names)

# %% [markdown]
# ## Cell cycle scoring
#
# download Cell cycle txt: https://github.com/scverse/scanpy_usage/blob/master/180209_cell_cycle/data/regev_lab_cell_cycle_genes.txt

# %%
cell_cycle_genes = [x.strip() for x in open(r'/Code/data/single_cell/animals/regev_lab_cell_cycle_genes.txt')]

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]
s_genes = [x for x in s_genes if x in adata.var_names]
g2m_genes = [x for x in g2m_genes if x in adata.var_names]

# %%
adata.var_names

# %%
g2m_genes

# %%
matching_values = adata.var_names.isin(cell_cycle_genes)

matching_values

# %%
cell_cycle_adata = adata.copy()

sc.pp.normalize_per_cell(cell_cycle_adata, counts_per_cell_after=1e4)
sc.pp.log1p(cell_cycle_adata)
sc.pp.scale(cell_cycle_adata)
sc.tl.score_genes_cell_cycle(cell_cycle_adata, s_genes=s_genes, g2m_genes=g2m_genes)
adata_cc_genes = cell_cycle_adata[:, cell_cycle_genes].copy()
sc.tl.pca(adata_cc_genes)
sc.pl.pca_scatter(adata_cc_genes, color='phase', save=True)
adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()
adata.obs['G2M_score'] = cell_cycle_adata.obs['G2M_score'].copy()
adata.obs['phase'] = cell_cycle_adata.obs['phase'].copy()

# %%
adata

# %%
adata.var

# %% [markdown]
# ## Saving adata

# %%
# adata.write(r'/Code/data/single_cell/animals/chicken/ca2/new_genome/''chicken_a2_after_qc.h5ad')

# %% [markdown]
# ## Preparing files to be opened in R studio

# %%
# Preparing files to be opened in R studio

matrix_dense = adata.X.toarray()

# Create a DataFrame from the dense array with observation names as index and variable names as columns
matrix_df = pd.DataFrame(matrix_dense, index=adata.obs_names, columns=adata.var_names)

# Save the DataFrame to a CSV file
matrix_df.to_csv(r'/Code/data/single_cell/animals/chicken/ca1/new_genome/''matrix_new.csv')
print('matrix file is transformed')

#save obs as scv
adata.obs.to_csv(r'/Code/data/single_cell/animals/chicken/ca1/new_genome/''obs_new.csv')
print('obs file is transformed')

# Save variable data to a CSV file
adata.var.to_csv(r'/Code/data/single_cell/animals/chicken/ca1/new_genome/''var_new.csv')
print('var file is transformed')
