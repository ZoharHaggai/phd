# %% [markdown]
# ## Imports

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import os
import bbknn
from pathlib import Path

# %% [markdown]
# ## Single cell settings

# %%
sc.settings.verbosity = 4
sc.settings.set_figure_params(80)
sc.settings._file_format_figs = 'pdf'
sc.settings.savefigs = False
use_first_n_samples = 0
full_sparse = False
# Out:
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_26328\3661074169.py:2: FutureWarning: The specified parameters ('scanpy',) are no longer positional. Please specify them like `scanpy=80`
#   sc.settings.set_figure_params(80)

# %% [markdown]
# ## Basic QC workflow

# %%
adatas = []
data_names = ['control','lf','lps','pic']
main_path = '/Code/data/single_cell/animals/frog/frog_2/laevis/'
paths = ['\\control','\\lf','\\lps','\\pic']    #...etc - Folders with matrix, features and barcodes gz files.
for path in paths:
    adata = sc.read_10x_mtx(main_path + path, var_names='gene_symbols', cache=False)    # use gene symbols for the variable names (variables-axis index)
    sc.logging.print_memory_usage()
    print(adata.shape)
    adatas.append(adata)
# Out:
#     reading \Code\data\single_cell\animals\frog\frog_2\laevis\control\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.55 GB, difference +0.55 GB
# (10390, 42755)
#     reading \Code\data\single_cell\animals\frog\frog_2\laevis\lf\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.91 GB, difference +0.35 GB
# (12342, 42755)
#     reading \Code\data\single_cell\animals\frog\frog_2\laevis\lps\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.92 GB, difference +0.01 GB
# (12245, 42755)
#     reading \Code\data\single_cell\animals\frog\frog_2\laevis\pic\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 1.14 GB, difference +0.23 GB
# (7985, 42755)

# %%
adata = adatas[0].concatenate(adatas[1:], batch_categories=data_names, batch_key='treatment')

# adata
# Out:
# c:\Python\Python310\lib\site-packages\anndata\_core\anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(

# %%
genes = pd.read_csv('/Code/data/single_cell/animals/frog_annotations_trinotate.csv')
genes.dropna(subset = ['gene_id'], inplace=True)

genes_dict = dict(zip(genes['gene_id'].astype('str'), genes.eggnog_name.astype('str'))) #change the column name to fit the animal

dict_multi, dict_uni = {}, {}
for d in genes_dict:
    if len(d.split(',')) != 1:
        dict_multi[d] = genes_dict[d]
    else:
        dict_uni[d] =  genes_dict[d]

multi_result_dict = {}

for key_str, value in dict_multi.items():
    # Convert the string key to a set
    key_set = set(key_str.strip("{}").replace("'", "").split(", "))

    # Iterate through the elements in the set and create individual keys
    for element in key_set:
        multi_result_dict[element] = value

genes_dict = {**dict_uni, **multi_result_dict}

genes_dict
# Out:
# {'LOC121396124': 'ACSL5',
#  'LOC121396047': 'V2R26',
#  'hspa1a.S': 'HSP7C',
#  'lin37.S': 'LIN37',
#  'LOC108697211': 'PSD1',
#  'LOC108697161': 'OR8H3',
#  'hes3.S': 'HES3',
#  'cox6b1.S': 'CX6B1',
#  'LOC108703381': 'TIM23',
#  'LOC108697459': 'IFIT5',
#  'LOC108705111': 'CD22',
#  'LOC108697170': 'OR5V1',
#  'cblc.S': 'CBL',
#  'tmem88.S': 'TMM88',
#  'wapl.S': 'WAPL',
#  'slk.S': 'SLK',
#  'hes5.3.S': 'HES5',
#  'LOC108697913': 'PKN2',
#  'LOC121396138': 'TNIK',
#  'LOC121396464': 'SCN2B',
#  'ski.S': 'SKI',
#  'zranb1.S': 'ZRN1B',
#  'LOC108697264': 'DHDH',
#  'masp2.S': 'MASP2',
#  'clstn3.S': 'CSTN3',
#  'LOC121396221': 'KPCD',
#  'mcu.S': 'MCU',
#  'LOC108697620': 'TNIK',
#  'prxl2a.S': 'PXL2A',
#  'emg1.S': 'NEP1',
#  'LOC121396287': 'UN5BB',
#  'tspan4.S': 'TSN4',
#  'LOC108697505': 'ZSWM8',
#  'mfsd13a.S': 'MF13A',
#  'hes5.7.S': 'HES5',
#  'LOC108697458': 'IFIT5',
#  'LOC108697295': 'TMEM139',
#  'uros.S': 'HEM4',
#  'LOC108697935': 'AATC',
#  'icmt.S': 'ICMT',
#  'MGC154351': 'LAAT1',
#  'bcl2l12.S': 'B2L12',
#  'ndufa3.S': 'NDUA3',
#  'kiaa2013.S': 'K2013',
#  'papss2.S': 'PAPS2',
#  'nppa.S': 'ANF',
#  'pdcd4.S': 'PDCD4',
#  'chst3.S': 'CHST3',
#  'LOC121396326': 'DUS29',
#  'zbtb17.S': 'ZBT17',
#  'vwa1.S': 'VWA1',
#  'znf365.S': 'ZN365',
#  'LOC108697275': 'PHC2',
#  'kcnc1.S': 'KCNC1',
#  'LOC108697267': 'AP2A1',
#  'ethe1.S': 'ETHE1',
#  'abraxas2.S': 'ABRX2',
#  'gpam.S': 'GPAT1',
#  'acap3.S': 'ACAP3',
#  'megf6.S': 'MEGF6',
#  'prmt1.S': 'ANM1A',
#  'LOC121396181': 'FFAR3',
#  'LOC121396467': 'SIDT2',
#  'LOC108697859': 'PADI1',
#  'LOC108697713': 'ZN570',
#  'h2ax.S': 'H2AX',
#  'LOC121396044': 'muc3a',
#  'pdlim1.S': 'PDLI1',
#  'oga.S': 'OGA',
#  'LOC121393094': 'ZSWM9',
#  'hells.S': 'HELLS',
#  'hectd2.S': 'HECD2',
#  'LOC108697190': 'RHG19',
#  'LOC108697845': 'SVBP',
#  'nkx2-3.S': 'NKX23',
#  'panx3.S': 'PANX3',
#  'LOC108697162': 'OR8H1',
#  'blnk.S': 'BLNK',
#  'scaf1.S': 'SFR19',
#  'nkx6-2.S': 'NKX62',
#  'ift46.S': 'IFT46',
#  'ankrd2.S': 'ANKR2',
#  'ddx6.S': 'DDX6',
#  'robo3.S': 'ROBO2',
#  'kras.S': 'RASK',
#  'tmem254l.S': 'TM254',
#  'LOC121396344': 'HARB1',
#  'ccdc106.S': 'CC106',
#  'casz1.S': 'CASZ1',
#  'LOC108697213': 'ZSWM8',
#  'LOC108697163': 'O5AR1',
#  'LOC108705112': 'CD22',
#  'LOC108705262': 'SRBS1',
#  'mttp.2.S': 'MTP',
#  'LOC108697155': 'OR8H3',
#  'neurog3.S': 'NGN3',
#  'bcl9l.S': 'BCL9L',
#  'LOC108697775': 'SY63',
#  'fbxo6.S': 'FBX6',
#  'LOC121396222': 'KPCD',
#  'cdc42.S': 'CDC42',
#  'cdk11b.S': 'CD11B',
#  'LOC108697149': 'A2MG',
#  'LOC108697235': '5HT3A',
#  'LOC108697176': 'ANK3',
#  'cacng7.S': 'CCG7',
#  'LOC108697756': 'XA1',
#  'chat.S': 'CLAT',
#  'aadacl4.S': 'ADCL4',
#  'LOC108703379': 'CEL2A',
#  'nt5c2.S': '5NTC',
#  'LOC108697619': 'AGRIN',
#  'stt3a.S': 'STT3A',
#  'mad2l2.S': 'MD2L2',
#  'slc22a15.2.S': 'S22FL',
#  'LOC121396101': 'CRAC1',
#  'XB5817455.S': 'HS3S1',
#  'dffb.S': 'DFFB',
#  'samd11.S': 'SAM11',
#  'm6pr.S': 'MPRD',
#  'clcn1.S': 'CLCN1',
#  'ppp1r15b-b': 'PR15B',
#  'kifbp.S': 'KBP',
#  'grid1.S': 'GRID1',
#  'clcf1.S': 'CLCF1',
#  'LOC108697975': 'TR140',
#  'stambpl1.S': 'STALP',
#  'LOC108697196': 'PLCE1',
#  'LOC121396347': 'LIPP',
#  'tacc2.S': 'TACC2',
#  'LOC108697250': 'CMTA1',
#  'LOC121396651': 'GUC2B',
#  'btg5.3.S': 'BTG3',
#  'LOC108697397': 'EXOC6',
#  'itprip.S': 'IPRI',
#  'nat14.S': 'NAT14',
#  'pitx3.S': 'PITX3',
#  'kif20b.S': 'KI20B',
#  'ssrp1.S': 'SSRP1',
#  'scnn1a.S': 'SCNNA',
#  'rasgef1a.S': 'RGF1A',
#  'LOC121396178': 'FPR2',
#  'LOC100191024': 'EPHA2',
#  'tead4.S': 'TEAD1',
#  'tmem147.S': 'TM147',
#  'LOC108703398': 'FA47E',
#  'btg3.S': 'BTG3',
#  'LOC121396183': 'PPBT',
#  'LOC108697721': 'HS30D',
#  'leng8.S': 'LENG8',
#  'LOC108697813': 'TLR13',
#  'usf2.S': 'USF2',
#  'LOC108697179': 'PLPP4',
#  'LOC108697634': 'FAP20',
#  'LOC100505446': 'NECT2',
#  'LOC121396404': 'KPCD',
#  'b3galt6.S': 'B3GT6',
#  'LOC108697146': 'LIPR1',
#  'pknox2.S': 'PKNX2',
#  'rer1.S': 'RER1',
#  'cep104.S': 'CE104',
#  'LOC108703376': 'DS13B',
#  'ecd.S': 'ECD',
#  'cbl.S': 'CBL',
#  'borcs7.S': 'BORC7',
#  'slc66a1.S': 'LAAT1',
#  'prdm2.S': 'PRDM2',
#  'LOC108697787': 'IGSF1',
#  'foxi2.S': 'FXI2A',
#  'LOC108697553': 'F174',
#  'tnnt1.S': 'TNNT1',
#  'ttc34.S': 'TTC34',
#  'cnfn.1.S': 'CNFNB',
#  'dnajb12.S': 'DJB12',
#  'akr7a2.S': 'ARK72',
#  'hes5.8.S': 'HES5',
#  'ddx19b.S': 'DD19A',
#  'hps1.S': 'HPS1',
#  'c11orf53.S': 'OCAT1',
#  'rbm20.S': 'RBM20',
#  'nr1h2.S': 'NR1H2',
#  'aicda.S': 'AICDA',
#  'entpd1.S': 'ENTP1',
#  'pde6c.S': 'PDE6C',
#  'sdhd.S': 'DHSDA',
#  'LOC121396213': 'PEO1',
#  'arhgef1.S': 'ARHG1',
#  'LOC108705688': 'CRAC1',
#  'cadm4.S': 'CADM4',
#  'ppa2.S': 'IPYR',
#  'zbtb40.S': 'ZBT40',
#  'LOC121396365': 'T132A',
#  'LOC121396016': 'AEDO',
#  'LOC108705107': 'PINLYP',
#  'bub3.S': 'BUB3',
#  'chuk.S': 'IKKA',
#  'supv3l1.S': 'SUV3',
#  'npffr1.1.S': 'NPFF1',
#  'pnkp.S': 'PNKP',
#  'igsf21.S': 'IGS21',
#  'ttyh1.S': 'TTY1B',
#  'h2ax.2.S': 'H2AX',
#  'chd5.S': 'CHD5',
#  'LOC108697510': 'CODA1',
#  'LOC108697199': 'IFIT5',
#  'LOC121396176': 'CML1',
#  'med25.S': 'MED25',
#  'rpl27a.S': 'RL27A',
#  'erf.S': 'ERF',
#  'LOC108697784': 'PHLA2',
#  'LOC108705380': 'FEL',
#  'LOC121396352': 'A2ML1',
#  'styk1.S': 'STYK1',
#  'kmt5c.S': 'KMT5C',
#  'cda.S': 'CDD',
#  'LOC108695933': 'C3AR',
#  'fam83e.S': 'FA83E',
#  'LOC121396053': 'XA1',
#  'LOC121396267': 'TNIK',
#  'c1orf159.S': 'CA159',
#  'vax1.S': 'VAX1A',
#  'morn4.S': 'MORN4',
#  'plekhg5.S': 'PKHG5',
#  'necap1.S': 'NECP1',
#  'LOC121396136': 'F135A',
#  'prpf31.S': 'PRP31',
#  'LOC108697723': 'ZSWM9',
#  'rnf223.S': 'RN223',
#  'LOC108697305': 'ARHG5',
#  'LOC108697326': 'CASP2',
#  'pcbd1.L': 'PHS',
#  'emc10.S': 'EMC10',
#  'rps19.S': 'RS19',
#  'dna2.S': 'DNA2',
#  'axin2.S': 'AXNR',
#  'kdelr1.S': 'ER21A',
#  'LOC121396190': 'A2MG',
#  'p3h3.S': 'P3H3',
#  'zfp91.S': 'ZFP91',
#  'LOC108706078': 'TR140',
#  'trnau1ap.S': 'TSAP1',
#  'ventx2.1.S': 'VEX1',
#  'kcnj1.S': 'KCNJ1',
#  'LOC108697140': 'TRY1',
#  'cyp26c1.S': 'CP26C',
#  'pten.S': 'PTEN',
#  'tfam.S': 'TFAM',
#  'spa17.S': 'SP17',
#  'LOC121396094': 'COPD',
#  'rnf207.S': 'RN207',
#  'aplp2.S': 'APLP2',
#  'LOC108697181': 'MGMT',
#  'LOC108705227': 'G6PT1',
#  'nkx3-3.S': 'ZAX',
#  'LOC108697652': 'TNFRSF4',
#  'p4ha1.S': 'P4HA1',
#  'cacng8.S': 'CCG8',
#  'phldb3.S': 'PHLB3',
#  'fli1.S': 'FLI1',
#  'slc35a3.2.S': 'S35A3',
#  'LOC108697464': 'DNMBP',
#  'anapc16.S': 'APC16',
#  'usp5.S': 'UBP5',
#  'LOC121396170': 'FPR2',
#  'slc17a7.S': 'VGLU1',
#  'LOC443585': 'MYH10',
#  'LOC121396459': 'ATP5L',
#  'LOC108697867': 'KLD7A',
#  'zfand4.S': 'ZFAN4',
#  'upk1a.S': 'UPK1A',
#  'cd3g.S': 'CD3G',
#  'LOC121396161': 'TR140',
#  'LOC121396211': 'KPCD',
#  'LOC108697856': 'MINT',
#  'LOC108697495': 'ZSWM8',
#  'LOC101027275': 'MBL2',
#  'LOC121396458': 'ATP5L',
#  'ncam1.S': 'NCA11',
#  'cpn1.S': 'CBPN',
#  'LOC108697245': 'LRC38',
#  'LOC108697674': 'CCD27',
#  'hp1bp3.S': 'HP1B3',
#  'LOC108697923': 'OPSO',
#  'plod1.S': 'PLOD1',
#  'vwa2.S': 'VWA2',
#  'LOC108697287': 'KMT2B',
#  'ubr4.S': 'UBR4',
#  'LOC108697411': 'RRP5',
#  'LOC108697221': 'CABP2',
#  'LOC108697259': 'SHAN1',
#  'rps9': 'RS9',
#  'fxyd2.S': 'ATNG',
#  'afap1l2.S': 'AF1L2',
#  'ddi2.S': 'DDI2',
#  'ascl2.S': 'ASCL1',
#  'LOC108697808': 'BRSK1',
#  'LOC108697225': 'ASTRB',
#  'ccnj.S': 'CCNJ',
#  'LOC121396152': 'COPD',
#  'tmco4.S': 'TMCO4',
#  'tyrobp.S': 'TYROBP',
#  'mib2.S': 'MIB2',
#  'LOC108705874': 'FEL',
#  'LOC121396233': 'KPCL',
#  'LOC108704925': 'NXPE4',
#  'LOC108706101': 'FFAR2',
#  'dyrk1a.2.L': 'DYR1A',
#  'LOC121396232': 'KPCL',
#  'LOC121396291': 'HXA4',
#  'ephb2.S': 'EPHB2',
#  'LOC121396017': 'HARB1',
#  'ankrd1.S': 'ANKR1',
#  'vps11.S': 'VPS11',
#  'LOC121396036': 'PNMA2',
#  'znf628.S': 'ZN628',
#  'cnot3.S': 'CNOT3',
#  'LOC108705550': 'SIG12',
#  'LOC121396177': 'CML1',
#  'LOC121396215': 'RHG19',
#  'LOC108697860': 'F131C',
#  'ldb1.S': 'LDB1',
#  'ppp2r1a.S': '2AAA',
#  'LOC121396583': 'PINLYP',
#  'ube2m.S': 'UBC12',
#  'LOC108697530': 'CEFIP',
#  'snx19.S': 'SNX19',
#  'ccdc6.S': 'CCDC6',
#  'LOC108697900': 'PLM',
#  'bnip3.S': 'BNIP3',
#  'aldh16a1.S': 'A16A1',
#  'nosip.S': 'NOSIP',
#  'LOC121396090': 'DIXC1',
#  'LOC108697433': 'PRM1A',
#  'syt15.S': 'SYT15',
#  'MGC78849': 'ZN384',
#  'pex10.S': 'PX10A',
#  'LOC121396603': 'CD22',
#  'il11.S': 'IL11',
#  'LOC121396582': 'LYPD5',
#  'LOC121396406': 'KPCD',
#  'unc5b.S': 'UN5BB',
#  'LOC108697144': 'PLEKHS1',
#  'XB989596.S': 'IFIT5',
#  'haus7.S': 'HAUS7',
#  'siae.S': 'SIAE',
#  'mcam.S': 'MUC18',
#  'LOC108703377': 'PLAC9',
#  'ventx3.2.S': 'VEX1',
#  'sbk3.S': 'SBK1',
#  'ccnl2.S': 'CCNL2',
#  'LOC108697471': 'ZFY27',
#  'kcna7.S': 'KCNA3',
#  'ccser2.S': 'CCSE2',
#  'LOC108697147': 'A2ML1',
#  'gstk1.S': 'GSTK1',
#  'ppp2r2d.S': '2ABD',
#  'camk2g.S': 'KCC2G',
#  'dedd2.S': 'DEDD2',
#  'wnt8b.S': 'WNT8B',
#  'LOC121396174': 'CML1',
#  'cd4.S': 'CD4',
#  'kmt2a.S': 'KMT2A',
#  'LOC121396070': 'COPD',
#  'LOC108697460': 'IFIT5',
#  'kif11.S': 'KI11B',
#  'lgi1.S': 'LGI1',
#  'sgms1.S': 'SMS1',
#  'tex36.S': 'TEX36',
#  'gpr26.S': 'GPR26',
#  'ptprh.S': 'PTPRH',
#  'LOC121396260': 'UBTD1',
#  'edrf1.S': 'EDRF1',
#  'isoc2.S': 'ISOC2',
#  'LOC108697661': 'SAS10',
#  'slc25a28.S': 'MFN2A',
#  'LOC108697549': 'RL21',
#  'tagln.S': 'TAGL',
#  'LOC121396599': 'CD22',
#  'grwd1.S': 'GRWD1',
#  'smg9.S': 'SMG9',
#  'syt5.S': 'SYT1',
#  'tmprss4.S': 'TMPS4',
#  'LOC121396396': 'KPCD',
#  'igsf9b.S': 'TUTLB',
#  'gsk3a.S': 'GSK3A',
#  'LOC108697743': 'TFPT',
#  'psap.S': 'SAP',
#  'LOC121396638': 'CLCKB',
#  'noc2l.S': 'NOC2L',
#  'pex5.S': 'PEX5',
#  'capzb.S': 'CAPZB',
#  'XB5748694.S': 'BORG4',
#  'nfkb2.S': 'NFKB2',
#  'pou2af1.S': 'OBF1',
#  'LOC108697866': 'FBX42',
#  'LOC108697268': 'TRPM4',
#  'mob2.2.S': 'MOB2',
#  'marveld1.S': 'MALD1',
#  'park7.S': 'PARK7',
#  'LOC108697889': 'FCGBP',
#  'snrnp70.S': 'RU17',
#  'LOC121396129': 'KPCD',
#  'LOC108704968': 'PINLYP',
#  'LOC108697536': 'PRP19',
#  'LOC108697925': 'CAHM1',
#  'drd1c.S': 'DRD1C',
#  'arhgef12.S': 'ARHGC',
#  'hes5.5.S': 'HES5',
#  'XB5789557.S': 'NNMT',
#  'LOC108705650': 'STK10',
#  'jakmip3.S': 'JKIP3',
#  'LOC121396292': 'HARB1',
#  'LOC121396400': 'KPCD',
#  'fgfbp3.S': 'FGFP3',
#  'LOC121396231': 'KPCL',
#  'LOC108697941': 'F135A',
#  'ndst2.S': 'NDST2',
#  'col17a1.S': 'COHA1',
#  'LOC108697630': 'PLCH2',
#  'cnnm2.S': 'CNNM2',
#  'LOC121396361': 'O5AR1',
#  'LOC108697590': 'CE164',
#  'LOC121396601': 'PRS6B',
#  'ldb3.S': 'LDB3',
#  'bccip.S': 'BCCIP',
#  'hbox10.S': 'NOBOX',
#  'nrbf2.S': 'NRBF2',
#  'padi4.S': 'PADI1',
#  'LOC100101278': 'HS30D',
#  'myadm.S': 'MYADM',
#  'LOC121396468': 'SIDT2',
#  'LOC108697493': 'PAX2B',
#  'atoh7.S': 'ATO7A',
#  'cep250.S': 'CP250',
#  'LOC121396266': 'LOX5',
#  'dusp11.2.S': 'DUS11',
#  'hmbs.2.S': 'HEM3',
#  'got1.S': 'AATC',
#  'LOC108697472': 'ZMAT4',
#  'xilr2.S': 'IGSF1',
#  'spock2.S': 'TICN2',
#  'LOC121396062': 'SIGLEC10',
#  'otud3.L': 'OTUD3',
#  'fut2.S': 'FUT2',
#  'rps9.S': 'RS9',
#  'epn1.S': 'EPN1',
#  'LOC121396390': 'RHG19',
#  'LOC121396048': 'V2R1',
#  'robo4.S': 'ROBO4',
#  'plekha4.S': 'PKHA7',
#  'wbp1l.S': 'WBP1L',
#  'LOC108697831': 'CPT1A',
#  'ptpn11b.S': 'PTN11',
#  'LOC108697649': 'GOLI4',
#  'LOC121396288': 'PHS',
#  'LOC108697741': 'PP12C',
#  'tomm40.S': 'TOM40',
#  'sncg.S': 'SNCG',
#  'LOC108697662': 'PPIH',
#  'ndufb8.S': 'NDUB8',
#  'fth1.1.S': 'FRIHB',
#  'agmat.S': 'SPEB',
#  'nbl1.S': 'NBL1',
#  'LOC121396273': 'MYOF',
#  'ruvbl2.S': 'RUVB2',
#  'LOC108697648': 'FND10',
#  'nodal.S': 'NOD4A',
#  'atp5mk.S': 'ATPMK',
#  'LOC108705384': 'LIPA3',
#  'cisd1.S': 'CISD1',
#  'LOC108697466': 'MFRN2',
#  'spib.S': 'SPIB',
#  'nkapd1.S': 'NKAP1',
#  'LOC108706245': 'MYOF',
#  'LOC121396049': 'TLR13',
#  'mmel1.S': 'MMEL1',
#  'LOC108697842': 'ARHGJ',
#  'LOC108697699': 'KLH21',
#  'LOC121396098': 'CRAC1',
#  'LOC108697257': 'TRY3',
#  'pkd2l1.S': 'PK2L1',
#  'gapdh.S': 'G3P',
#  'LOC108697908': 'KCNJ5',
#  'esam.S': 'ESAM',
#  'ndnfl2.S': 'NDNF',
#  'lbx1.S': 'LBX1',
#  'btrc.S': 'FBW1A',
#  'oit3.S': 'OIT3',
#  'LOC121396514': 'TNFRSF25',
#  'MGC83948': 'CCND1',
#  'hyou1.S': 'HYOU1',
#  'LOC121393049': 'TSAP1',
#  'avpi1.S': 'AVPI1',
#  'prlhr.S': 'PRLHR',
#  'tprg1l.S': 'TPRGL',
#  'gsg1l.S': 'GSG1L',
#  'LOC121396457': 'ATP5L',
#  'LOC108697869': 'IFFO2',
#  'drd2.S': 'DRD2A',
#  'ventx1.1.S': 'VNT1B',
#  'fez1.S': 'FEZ1',
#  'tmem143.S': 'TM143',
#  'mthfr.S': 'MTHR',
#  'LOC108705521': 'ODP2',
#  'gsto1.S': 'GSTO1',
#  'LOC108697909': 'TRY1',
#  'scn1b.S': 'SCN1B',
#  'fgfr2.S': 'FGFR2',
#  'LOC108697539': 'KDM2A',
#  'LOC108697732': 'ZN865',
#  'gbp6.L': 'GBP6',
#  'trappc4.S': 'TPPC4',
#  'LOC108697288': 'IKBD',
#  'slc37a2.S': 'G6PT3',
#  'sema4g.S': 'SEM4G',
#  'LOC121396630': 'TIRAP',
#  'LOC108697678': 'CA174',
#  'LOC108697502': 'KPCD',
#  'LOC108697991': 'TIP39',
#  'errfi1.S': 'ERRFI',
#  'arl3.S': 'ARL3',
#  'stox1.S': 'STOX1',
#  'LOC108697760': 'AT1A3',
#  'LOC121396046': 'V2R26',
#  'LOC108697683': 'KCAB2',
#  'ate1.S': 'ATE1',
#  'LOC108697469': 'CRAC1',
#  'noc3l.S': 'NOC3L',
#  'LOC108705251': 'IGLO5',
#  'ncoa4.S': 'NCOA4',
#  'moap1.S': 'MOAP1',
#  'cpxm2.S': 'CPXM2',
#  'anxa7.S': 'ANXA7',
#  'gpr153.S': 'GP153',
#  'LOC108697933': 'CENPK',
#  'LOC121396243': 'FFAR4',
#  'LOC108697503': 'KPCD',
#  'trim29.S': 'TRI29',
#  'apoa1.S': 'APOA1',
#  'LOC108705050': 'CML1',
#  'pank4.S': 'PANK4',
#  'fut1.S': 'FUT2',
#  'sorcs3.S': 'SORC3',
#  'dkk1.S': 'DKK1',
#  'ppp3cc.S': 'PP2BB',
#  'sbk2.S': 'SBK2',
#  'prss1.2.S': 'TRY3',
#  'ppp1r3c.1.S': 'PPR3C',
#  'vcl.S': 'VINC',
#  'LOC108697601': 'NECT1',
#  'LOC121396286': 'CJ105',
#  'padi2.S': 'PADI2',
#  'LOC108697361': 'UB2D4',
#  'slc18a3.S': 'VACHA',
#  'bc014685.S': 'T150A',
#  'casp9.S': 'CASP9',
#  'LOC108697330': 'RIMKB',
#  'LOC108697957': 'UBIA1',
#  'LOC121396460': 'ATP5L',
#  'grin2d.S': 'NMDE4',
#  'LOC108697174': 'PCD15',
#  'wnt4.S': 'WNT4',
#  'gpr162.S': 'GP162',
#  'cdhr1.S': 'CDHR1',
#  'ankrd22.S': 'ANR22',
#  'LOC108705728': 'KPCD',
#  'sec23ip.S': 'S23IP',
#  'fam149b1.S': 'F149B',
#  'LOC121396548': 'ELF5',
#  'lag3.S': 'LAG3',
#  'slc6a16.S': 'S6A15',
#  'LOC108697989': 'CXCR3',
#  'cela3a.S': 'CEL3B',
#  'LOC108697972': 'TR140',
#  'vwa5b1.S': 'VW5B1',
#  'lrit2.S': 'LRIT2',
#  'LOC108705523': 'DIXC1',
#  'clmp.S': 'CLMP',
#  'shisa7.S': 'SHSA7',
#  'LOC108697793': 'GALA',
#  'minpp1.S': 'MINP1',
#  'LOC121396379': 'PPBP',
#  'LOC108697599': 'ATP5L',
#  'LOC108697209': 'MSMB',
#  'scn3b.S': 'SCN3B',
#  'cnfn.2.S': 'CNFNB',
#  'cldn19.S': 'CLD19',
#  'LOC108705485': 'GPR33',
#  'LOC108697260': 'CLC11',
#  'atn1.S': 'ATN1',
#  'LOC108705252': 'CEAM1',
#  'loxl4.S': 'LOXL4',
#  'hif1an.S': 'HIF1N',
#  'cd37.S': 'CD37',
#  'fam13c.S': 'FA13C',
#  'acp4.S': 'PPAT',
#  'LOC108697153': 'OR8H3',
#  'lzic.S': 'LZIC',
#  'LOC108697376': 'HMX2',
#  'LOC108697992': 'TM86A',
#  'LOC108697232': 'VSXL2',
#  'LOC108697291': 'TRY4',
#  'LOC108697931': 'ITLN1',
#  'cxcr5.S': 'CXCR5',
#  'alpl.S': 'PPBT',
#  'pla2g2e.S': 'PA2H',
#  'kcnj14.S': 'KCJ14',
#  'hnrnph3.S': 'HNRH3',
#  'ube2j2.S': 'UB2J2',
#  'LOC108697233': 'LAYN',
#  'ctnnbip1.S': 'CNBP1',
#  'ide.S': 'IDE',
#  'herc4.S': 'HERC4',
#  'lin7b.S': 'LIN7B',
#  'LOC121396280': 'TNIK',
#  'atg12.S': 'ATG12',
#  'shoc2.S': 'SHOC2',
#  'tnks2.S': 'TNKS2',
#  'LOC108697425': 'LZTS2',
#  'emp3.S': 'EMP3',
#  'LOC121396617': 'TECTA',
#  'scd.S': 'ACOD',
#  'irf3.S': 'IRF3',
#  'LOC108697603': 'GRIK4',
#  'mki67.S': 'KI67',
#  'pex14.S': 'PEX14',
#  'glb1l2.S': 'GLBL2',
#  'LOC108697348': 'CHD4',
#  'sirt1.S': 'SIR1',
#  'LOC121396432': 'ABCG4',
#  'hepacam.S': 'HECAM',
#  'ccar1.S': 'CCAR1',
#  'phc1.S': 'PHC1',
#  'ssu72.S': 'SSU72',
#  'lsr.S': 'LSR',
#  'LOC108697215': 'KPCD',
#  'LOC108705258': 'MMS19',
#  'znf574.S': 'ZN574',
#  'pank1.S': 'PANK1',
#  'ventx2.2.S': 'VENT1',
#  'LOC108697782': 'IGF3',
#  'apoa4.S': 'APOA4',
#  'LOC108697238': '5HT3A',
#  'LOC108697998': 'PA2BB',
#  'ndufa4.S': 'NDUA4',
#  'lcor.S': 'LCORL',
#  'LOC108697300': 'ADA2A',
#  'LOC108697557': 'DRAXI',
#  'arid5b.S': 'ARI5B',
#  'LOC121396354': 'RET5',
#  'golga7b.S': 'GOG7B',
#  'xcxcra': 'CXCR3',
#  'phb2.S': 'PHB2',
#  'marchf5.S': 'MARH5',
#  'LOC108697386': 'DPYL4',
#  'LOC108697778': 'RRAS2',
#  'LOC108697158': 'O5AR1',
#  'foxj2.S': 'FOXJ2',
#  'dhrs3.S': 'DHRS3',
#  'LOC108697224': 'OBCAM',
#  'reep3.S': 'REP3B',
#  'psmc4.S': 'PRS6B',
#  'LOC108697701': 'VAMP3',
#  'LOC121396195': 'HARB1',
#  'LOC108697145': 'LIPR2',
#  'LOC108697239': 'KCNJ5',
#  'phf13.S': 'PHF13',
#  'lrrc23.S': 'LRC23',
#  'nppb.S': 'ANF',
#  'ipmk.S': 'IPMK',
#  'cdk1.S': 'CDK1A',
#  'rcvrn.2.S': 'VISI',
#  'mfn2.S': 'MFN2',
#  'btg5.1.S': 'BTG3',
#  'c1qtnf12.S': 'ADIPL',
#  'LOC108697343': 'PIANP',
#  'LOC108697746': 'DBP',
#  'rabac1.S': 'PRAF1',
#  'LOC108697159': 'OR8H3',
#  'LOC121396393': 'KPCD',
#  'LOC108697608': 'C11orf63',
#  'LOC108697779': 'KCJ11',
#  'sult2a1.S': 'ST2B1',
#  'XB22063245.S': 'FXYD6',
#  'LOC108703356': 'TBATA',
#  'LOC121396214': 'KCIP2',
#  'gramd1a.S': 'ASTRA',
#  'LOC108697593': 'DSCL1',
#  'LOC121396568': 'TMPO',
#  'hes5.9.S': 'HES5',
#  'h6pd.S': 'G6PE',
#  'LOC121396091': 'DIXC1',
#  'eef1akmt2.S': 'EFMT2',
#  'LOC108697203': 'IFIT5',
#  'LOC121396032': 'C1QT5',
#  'LOC121396543': 'CEA20',
#  'cox15.S': 'COX15',
#  'etfb.L': 'ETFB',
#  'LOC121396175': 'FPRS1',
#  'rere.S': 'RERE',
#  'nucb1.S': 'NUCB1',
#  'tial1.S': 'TIAR',
#  'rps25.S': 'RS25',
#  'tbc1d12.S': 'TBC12',
#  'npm3.S': 'NO29',
#  'LOC108697615': 'NNMT',
#  'sec31b.S': 'SC31B',
#  'ppp2r1b.S': '2AAB',
#  'hes5.4.S': 'HES5',
#  'LOC108697184': 'VEX1',
#  'LOC121396542': 'CEAM5',
#  'anxa11.S': 'ANX11',
#  'LOC108697202': 'IFIT5',
#  'inpp5a.1.S': 'I5P1',
#  'LOC108697799': 'PR15B',
#  'LOC121396373': 'DMBT1',
#  'plekhm2.S': 'PKHM2',
#  'dock1.S': 'DOCK1',
#  'hhex.S': 'HHEX',
#  'prkcz.S': 'KPCZ',
#  'LOC121396357': 'OR8H3',
#  'ret.S': 'RET',
#  'efhd2.S': 'EFHD2',
#  'hinfp.S': 'HINFP',
#  'vdac2.S': 'VDAC2',
#  'rbm42.S': 'RBM42',
#  'bmpr1a.S': 'BMR1A',
#  'LOC121396015': 'MYPOP',
#  'hes4.S': 'HES4A',
#  'osbp.S': 'OSBP1',
#  'plekha1.S': 'PKHA1',
#  'rhobtb1.S': 'RHBT1',
#  'neurl1.S': 'NEUL1',
#  'smc3.S': 'SMC3',
#  'LOC108697814': 'BAIP2',
#  'LOC121396403': 'KPCD',
#  'LOC100036823': 'FRIHB',
#  'nadk.S': 'NADK',
#  'slc29a3.S': 'S29A3',
#  'LOC108697455': 'TLR13',
#  'LOC121396057': 'FPR3',
#  'btg4.S': 'B915',
#  'rpl18.S': 'RL18A',
#  'synpo2l.S': 'SYP2L',
#  'sik3.S': 'SIK3',
#  'ebf3.S': 'COE3',
#  'mrto4.S': 'MRT4',
#  'LOC108697476': 'MMS19',
#  'prl.2.S': 'PRL',
#  'znf362.S': 'ZN362',
#  'LOC108697688': 'RL23A',
#  'LOC108697924': 'CAHM3',
#  'LOC121396066': 'TMPO',
#  'LOC101027296': 'FEL',
#  'slc45a1.S': 'S45A1',
#  'tmprss13.S': 'TMPSD',
#  'LOC108703350': 'NRG3',
#  'LOC108697673': 'TNFRSF9',
#  'sdhb.S': 'SDHB',
#  'b4galt3l2.S': 'B4GT3',
#  'LOC121396089': 'DIXC1',
#  'MGC68875': 'A2ML1',
#  'LOC108697341': 'TPRGL',
#  'cyth1.S': 'CYH2',
#  'LOC108697560': 'DISP3',
#  'LOC108697657': 'ZN316',
#  'sfxn2.S': 'SFXN2',
#  'LOC121396276': 'NRK',
#  'sult2b1.S': 'SUHB',
#  'LOC108697509': 'CODA1',
#  'ablim1.S': 'ABLM1',
#  'tmem45b.S': 'TM45B',
#  'LOC108697666': 'PRDM2',
#  'tnni3.S': 'TNNI3',
#  'LOC108697325': 'A2ML1',
#  'LOC108697306': 'TF7L2',
#  'sar1a.S': 'SAR1A',
#  'taf5.S': 'TAF5',
#  'hmx3.S': 'HMX3',
#  'LOC108697689': 'ESPN',
#  'casp7.S': 'CASP7',
#  'hes5.1.S': 'HES5',
#  'LOC108697863': 'NECP2',
#  'hspa1l.S': 'HSP7C',
#  'LOC108697246': 'muc3a',
#  'tmem254.S': 'TM254',
#  'cuedc2.S': 'CUE2A',
#  'megf8.S': 'MEGF8',
#  'LOC108697903': 'FXYD3',
#  'LOC108705628': 'CRAC1',
#  'arhgap33.S': 'RHG33',
#  'LOC121396360': 'O5AR1',
#  'LOC108697739': 'SACS',
#  'LOC108697201': 'IFIT5',
#  'LOC108706106': 'VSIG10L',
#  'LOC108705634': 'GBP7',
#  'slit1.S': 'SLIT1',
#  'LOC108697862': 'ZBT17',
#  'LOC108697283': '5HT6R',
#  'glud1.S': 'DHE3',
#  'fgf8.S': 'FGF8',
#  'LOC100126637': 'FEL',
#  'actr1a.S': 'ACTZ',
#  'LOC108697724': 'C19orf68',
#  'LOC121396230': 'KPCL',
#  'acta2.S': 'ACTA',
#  'atp6v0e2.S': 'VA0E2',
#  'LOC108697876': 'CK2N1',
#  'LOC121396054': 'PINLYP',
#  'ptpn6.S': 'PTN6',
#  'XB5832479.S': 'MPI1B',
#  'rgr.S': 'RGR',
#  'spsb1.S': 'SPSB1',
#  'LOC100036845': 'OVOS',
#  'lrit1.S': 'LRIT1',
#  'cenatac.S': 'CATAC',
#  'zyx.S': 'ZYX',
#  'LOC108697309': 'CC186',
#  'pcdh8l.S': 'PCDH8',
#  'LOC121396430': 'VSIG2',
#  'bsx.S': 'BSH',
#  'XB5897453.S': 'FCGBP',
#  'LOC121396201': 'DMBT1',
#  'LOC121396591': 'CML1',
#  'LOC121396246': 'AATC',
#  'LOC108697936': 'MINK1',
#  'LOC108705051': 'CML1',
#  'sdf4.S': 'CAB45',
#  'LOC108697150': 'OVOS',
#  'LOC121396069': 'COPD',
#  'myoz1.S': 'MYOZ1',
#  'ubash3b.S': 'UBS3B',
#  'LOC108697479': 'NUD13',
#  'slc16a12.S': 'MOT12',
#  'LOC121396086': 'COPD',
#  'LOC108697308': 'ADRB1',
#  'adam12.S': 'ADA12',
#  'LOC108697230': 'SIA4C',
#  'ddost.S': 'OST48',
#  'LOC121396631': 'HMCN1',
#  'rap1gap.S': 'RPGP1',
#  'calhm2.S': 'CAHM2',
#  'XB5913757.S': 'TMM11',
#  'dusp13.S': 'DS13A',
#  'rpl28.S': 'RL28',
#  'LOC121396283': 'HARB1',
#  'upk2.S': 'UPK2',
#  'ing4.S': 'ING4',
#  'LOC108705520': 'PIHD2',
#  'timm8b.S': 'TIM8A',
#  'LOC108697262': 'MYPC2',
#  'pald1.S': 'PALD',
#  'sirt2.S': 'SIR2',
#  'LOC108697499': 'ELOV6',
#  'LOC108697315': 'VMAT2',
#  'tpi1.S': 'TPIS',
#  'c8orf76.S': 'CH076',
#  'sec24c.S': 'SC24C',
#  'LOC108704963': 'ZFY',
#  'aifm2.S': 'FSP1',
#  'mlf2.S': 'MLF2',
#  'XB5876791.S': 'O5AR1',
#  'adk.S': 'ADK',
#  'LOC108697970': 'TR140',
#  'fbxl4.S': 'FBXL4',
#  'LOC108697846': 'TRI62',
#  'MGC115716.S': 'ZN783',
#  'tmem52.S': 'TMM52',
#  'adamts15.S': 'ATS15',
#  'insyn2a.S': 'INSY2',
#  'tecta.1.S': 'TECTA',
#  'bace1.S': 'BACE1',
#  'LOC108697914': 'O5AR1',
#  'fblim1.S': 'FBLI1',
#  'phldb1.S': 'PHLB1',
#  'prrg2.S': 'TMG2',
#  'tmem26.S': 'TMM26',
#  'LOC494843': 'SIG14',
#  'LOC108697249': 'BACH',
#  'ube2s.S': 'UB2SB',
#  'dpcd.S': 'DPCD',
#  'mrpl16.S': 'RM16',
#  'LOC121396123': 'NRAP',
#  'LOC108697391': 'PTPRE',
#  'ccdc155l.S': 'IRAG2',
#  'LOC121396462': 'SIM35',
#  'arhgef19.S': 'ARHGJ',
#  'znf526.S': 'ZN574',
#  'LOC108697776': 'PAX6',
#  'LOC108697373': 'CHSTF',
#  'gprc5cl2.S': 'GPC5C',
#  'LOC108697156': 'OR8H3',
#  'LOC121396592': 'GPR33',
#  'LOC108697542': 'CSTN1',
#  'LOC108697824': 'CCG6',
#  'opn4.S': 'OPN4A',
#  'LOC121396184': 'TMPO',
#  'LOC108703359': 'GRIN2',
#  'LOC108697427': 'TLX1',
#  'angptl7.S': 'ANGL7',
#  'LOC108705053': 'B910',
#  'chek1.S': 'CHK1',
#  'prdx3.S': 'PRDX3',
#  'ddit4.S': 'DDIT4',
#  'LOC108697217': 'CAD23',
#  'LOC108697167': 'OR8H3',
#  'zbtb45.S': 'ZBT45',
#  'LOC108705858': 'KS6A6',
#  'tecta.2.S': 'TECTA',
#  'LOC121396593': 'GPR33',
#  'LOC121396041': 'DIXC1',
#  'glrx3.S': 'GLRX3',
#  'MGC84384': 'LMIP',
#  'mag.S': 'MAG',
#  'MGC68606': 'FRIL',
#  'LOC108697763': 'PO2F2',
#  'LOC121396281': 'TNIK',
#  'atp12a.S': 'AT12A',
#  'kif1b.S': 'KIF1B',
#  'LOC121396227': 'KS6B2',
#  'dusp5.S': 'DUS5',
#  'pitpnc1l.S': 'PITC1',
#  'hes5.10.S': 'HES5',
#  'lmtk3.S': 'LMTK3',
#  'LOC121396554': 'dkk3',
#  'muc5acl.S': 'FCGBP',
#  'LOC121396240': 'LAP2A',
#  'LOC108697839': 'LRC4B',
#  'lipe.S': 'LIPS',
#  'LOC108697402': 'CPEB3',
#  'sik2.S': 'SIK2',
#  'LOC108697641': 'DVL1',
#  'LOC398692': 'GBP7',
#  'pik3ap1.S': 'BCAP',
#  'LOC108697802': 'GYS1',
#  'eif4ebp2.S': '4EBP2',
#  'stn1.S': 'STN1',
#  'LOC121396386': 'KPCD',
#  'oat.S': 'OAT',
#  'st14.S': 'ST14',
#  'iffo1.S': 'IFFO1',
#  'kazn.S': 'KAZRN',
#  'LOC108705487': 'CML1',
#  'ina.S': 'AINX',
#  'mfap2.S': 'MFAP2',
#  'MGC147475.S': 'PACN3',
#  'bcl3.S': 'BCL3',
#  'sc5d.S': 'SC5D',
#  'LOC108697803': 'KI18B',
#  'ncapd2.S': 'CND1',
#  'apoa5.S': 'APOA5',
#  'grik5.S': 'GRIK5',
#  'LOC108697164': 'OR8H1',
#  'LOC108697214': 'ZSWM8',
#  'ikzf5.S': 'IKZF5',
#  'sfrp5.S': 'SFRP5',
#  'pla2g12b.S': 'PG12B',
#  'LOC108697881': 'KCNJ5',
#  'LOC121396159': 'ANKK1',
#  'LOC108697796': 'VWF',
#  'znf581.S': 'ZN581',
#  'LOC121396343': 'NRAP',
#  'LOC108697955': 'ANFC',
#  'LOC108697060': 'FFAR3',
#  'tspan14.S': 'TSN14',
#  'add3.S': 'ADDG',
#  'sufu.S': 'SUFU',
#  'LOC121396342': 'BBIP1',
#  'LOC108697331': 'MFAP5',
#  'LOC108697976': 'B3GN7',
#  'pafah1b2.S': 'PA1B2',
#  'LOC108697840': 'EPHA8',
#  'stk32c.S': 'ST32C',
#  'znf518a.S': 'Z518A',
#  'arcn1.L': 'COPD',
#  'LOC108697253': 'CASR',
#  'adamts14.S': 'ATS14',
#  'dnajc16.S': 'DJC16',
#  'LOC108697191': 'KPCD',
#  'tmem72.S': 'TMM72',
#  'cd79a.S': 'CD79A',
#  'zbtb16.S': 'ZBT16',
#  'LOC121393067': 'C10orf12',
#  'emc1.S': 'EMC1',
#  'ghitm.S': 'GHITM',
#  'LOC108697820': 'KPCG',
#  'LOC108697252': 'V2R26',
#  'ubtd1.S': 'UBTD1',
#  'LOC121396180': 'hamp',
#  'LOC108697444': 'HXK1',
#  'cadm1.S': 'CADM1',
#  'zdhhc16.S': 'ZDH16',
#  'sh2d4b.S': 'SH24B',
#  'LOC108697504': 'UBP54',
#  'vps26b.S': 'V26BB',
#  'rab11fip2.S': 'RFIP2',
#  'trim28.S': 'TIF1B',
#  'LOC108703104': 'PKN2',
#  'kirrel2.S': 'KIRR1',
#  'marchf8.S': 'MARH8',
#  ...}

# %%
adata.obs
# Out:
#                            treatment
# AAACCCAAGCAGCCCT-1-control   control
# AAACCCAAGCATAGGC-1-control   control
# AAACCCAAGCCATCCG-1-control   control
# AAACCCAAGCGTATGG-1-control   control
# AAACCCAAGGCGCTTC-1-control   control
# ...                              ...
# TTTGTTGGTCCACTTC-1-pic           pic
# TTTGTTGGTGGACCTC-1-pic           pic
# TTTGTTGTCCAAGCCG-1-pic           pic
# TTTGTTGTCCATACAG-1-pic           pic
# TTTGTTGTCGCAACAT-1-pic           pic
#
# [42962 rows x 1 columns]

# %%
adata.var
# Out:
#                               gene_ids    feature_types
# LOC108704873              LOC108704873  Gene Expression
# LOC108704861              LOC108704861  Gene Expression
# dok1.L                          dok1.L  Gene Expression
# mrps26.L                      mrps26.L  Gene Expression
# LOC108704862              LOC108704862  Gene Expression
# ...                                ...              ...
# ND6                                ND6  Gene Expression
# unassigned_gene_22  unassigned_gene_22  Gene Expression
# CYTB                              CYTB  Gene Expression
# unassigned_gene_23  unassigned_gene_23  Gene Expression
# unassigned_gene_24  unassigned_gene_24  Gene Expression
#
# [42755 rows x 2 columns]

# %%
adata.var.set_index('gene_ids', inplace=True) 
adata.var['gene_ids'] = adata.var.index

adata.var.drop(columns='feature_types', inplace=True)
adata.var.rename(genes_dict, inplace=True)

# %%
adata.var
# Out:
#                               gene_ids
# gene_ids
# PEPA                      LOC108704873
# PI16                      LOC108704861
# DOK1                            dok1.L
# RT26                          mrps26.L
# M1AP                      LOC108704862
# ...                                ...
# NU6M                               ND6
# unassigned_gene_22  unassigned_gene_22
# CYB                               CYTB
# unassigned_gene_23  unassigned_gene_23
# unassigned_gene_24  unassigned_gene_24
#
# [42755 rows x 1 columns]

# %%
# This code identifies duplicate variable names, iterates through them, and adds suffixes to make them unique from the first occurrence.
# Please make sure to replace adata with your actual AnnData object.

# Keep in mind that Scanpy's functionality may evolve, so it's a good idea to check the documentation or release notes
# for any updates related to making variable names unique starting from the first occurrence in more recent versions of Scanpy.

# Get a Series of variable (gene) names
var_names_series = pd.Series(adata.var_names)

# Identify duplicate variable names
duplicate_var_names = var_names_series[var_names_series.duplicated(keep='first')]

# Iterate through duplicates and add suffixes to make them unique from the first occurrence
for duplicate_name in duplicate_var_names:
    count = 1
    indices = var_names_series[var_names_series == duplicate_name].index
    for idx in indices:
        var_names_series[idx] = f'{duplicate_name}_{count}'
        count += 1

# Update the AnnData object with the unique variable names
adata.var_names = var_names_series.values

adata.var_names
# Out:
# Index(['PEPA_1', 'PI16', 'DOK1', 'RT26', 'M1AP', 'DQX1', 'MMP21_1', 'TLX3_1',
#        'KAZD1_1', 'PCGF1_1',
#        ...
#        'NU4M', 'unassigned_gene_19', 'unassigned_gene_20',
#        'unassigned_gene_21', 'NU5M', 'NU6M', 'unassigned_gene_22', 'CYB',
#        'unassigned_gene_23', 'unassigned_gene_24'],
#       dtype='object', length=42755)

# %% [markdown]
# Creating a raw adata annotated with the metadata created in downstream processing

# %% [markdown]
# ## Genes and cells filtration

# %%
# Shows the genes that yield the highest fraction of counts in each single cell, across all cells.

sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %% [markdown]
# Basic filtering

# %%
adata_copy = adata.copy()

# %%
sc.pp.filter_cells(adata, min_genes=100) 
sc.pp.filter_genes(adata, min_cells=3)
print(adata.shape)
# Out:
# filtered out 89 cells that have less than 100 genes expressed
# filtered out 18183 genes that are detected in less than 3 cells
# (42873, 24572)

# %% [markdown]
# ### Mitochondrial QC and general measures
# Check if genes are annotated as mt by running:
# - GENES= list(adata.var.index[adata.var.index.str.startswith('mt-'.upper())])
# - GENES
#
# In case the genes are not annotated as 'MT-'' (Like in bats), run:
#
# - dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2'...etc}
# - adata.var.rename(dict_replace, inplace = True)

# %%
dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2','COX3':'MT-COX3','ND1':'MT-ND1-1','ND1':'MT-ND1-2','ND2':'MT-ND2',
                'ND3':'MT-ND3','ND4':'MT-ND4','ND5':'MT-ND5','ND6':'MT-ND6','ND4L-1':'MT-ND4L','ATP6':'MT-ATP6','ATP8':'MT-ATP8',
                'CYTB':'MT-CYTB'}
adata.var.rename(dict_replace, inplace=True)
# ONLY MT-ATP6, MT-ND1, MT-ND4L

# %%
adata.var['MT'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'MT'
sc.pp.calculate_qc_metrics(adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts', color='treatment')
sc.pl.scatter(adata, x='total_counts', y='pct_counts_MT', color='treatment')
sc.pl.scatter(adata, x='total_counts', y='n_genes', color='treatment', save=True)
# Out:
# WARNING: saving figure to file figures\scatter.pdf

# %% [markdown]
# Actually do the filtering by slicing the AnnData object - By pct_counts_MT  and by total_counts /n_genes_by_counts or even n_genes

# %%
adata = adata[adata.obs.pct_counts_MT < 20] 
adata = adata[adata.obs.total_counts < 5000, :] # If filtering outliers (<0.1% of cells)

# %% [markdown]
# ### Doublet analysis and filtering

# %%
import scrublet as scr

def scrub(adatas, adata, adata_names):  # based on raw individual samples. 
    print('Before scrublet: ', adata.shape[0])
    doub_index = []
    barcodes = []
    for data,name in zip(adatas,adata_names):
        data.raw = data
        sc.pp.normalize_total(data, target_sum=1e4)
        sc.pp.log1p(data)
        scrub = scr.Scrublet(data.raw.X)
        data.obs['doublet_scores'], data.obs['predicted_doublets'] = scrub.scrub_doublets()
        scrub.plot_histogram()
        print('Doublets' + name + ' :', data.obs[data.obs['doublet_scores'] > 0.25].shape[0])
        barcodes = data.obs[data.obs['doublet_scores'] < 0.25].index.to_list()
        for barcode in barcodes:
            doub_index.append(barcode + '-' + name)

    adata = adata[adata.obs.index.isin(doub_index)]
    print('After scrublet: ', adata.shape[0])
    return adata

# %%
adata = scrub(adatas, adata, data_names)
# Out:
# Before scrublet:  40064
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.79
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.2%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 13.0%
# Elapsed time: 10.7 seconds
# Doubletscontrol : 541
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.56
# Detected doublet rate = 0.7%
# Estimated detectable doublet fraction = 8.6%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 7.7%
# Elapsed time: 13.4 seconds
# Doubletslf : 657
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.80
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 12.4 seconds
# Doubletslps : 606
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.68
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 4.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.4%
# Elapsed time: 6.9 seconds
# Doubletspic : 537
# After scrublet:  38119

# %% [markdown]
# ### Cell cycle scoring
# download Cell cycle txt: https://github.com/scverse/scanpy_usage/blob/master/180209_cell_cycle/data/regev_lab_cell_cycle_genes.txt

# %%
cell_cycle_genes = [x.strip() for x in open(r'/Code/data/single_cell/animals/regev_lab_cell_cycle_genes.txt')]

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]
s_genes = [x for x in s_genes if x in adata.var_names]
g2m_genes = [x for x in g2m_genes if x in adata.var_names]

# %%
adata.var_names
# Out:
# Index(['DOK1', 'RT26', 'DQX1', 'PCGF1_1', 'LOC108704858', 'LOC121401503',
#        'PDCD4_1', 'LOC121401504', 'MOGS', 'WBP1_1',
#        ...
#        'NU4M', 'unassigned_gene_19', 'unassigned_gene_20',
#        'unassigned_gene_21', 'NU5M', 'NU6M', 'unassigned_gene_22', 'CYB',
#        'unassigned_gene_23', 'unassigned_gene_24'],
#       dtype='object', length=24572)

# %%
g2m_genes
# Out:
# ['TOP2A', 'CENPF', 'SMC4', 'BUB1', 'HJURP', 'CDCA3', 'HMMR', 'NEK2', 'CENPA']

# %%
cell_cycle_adata = adata.copy()

sc.pp.normalize_per_cell(cell_cycle_adata, counts_per_cell_after=1e4)
sc.pp.log1p(cell_cycle_adata)
sc.pp.scale(cell_cycle_adata)
sc.tl.score_genes_cell_cycle(cell_cycle_adata, s_genes=s_genes, g2m_genes=g2m_genes)
adata_cc_genes = cell_cycle_adata[:, cell_cycle_genes].copy()
sc.tl.pca(adata_cc_genes)
sc.pl.pca_scatter(adata_cc_genes, color='phase', save=True)
adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()
adata.obs['G2M_score'] = cell_cycle_adata.obs['G2M_score'].copy()
adata.obs['phase'] = cell_cycle_adata.obs['phase'].copy()
# Out:
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# calculating cell cycle phase
# computing score 'S_score'
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     42 total control genes are used. (0:00:07)
# computing score 'G2M_score'
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     56 total control genes are used. (0:00:03)
# -->     'phase', cell cycle phase (adata.obs)
# computing PCA
#     with n_comps=15
#     finished (0:00:00)
#     and added
#     'X_pca', the PCA coordinates (adata.obs)
#     'PC1', 'PC2', ..., the loadings (adata.var)
#     'pca_variance', the variance / eigenvalues (adata.uns)
#     'pca_variance_ratio', the variance ratio (adata.uns)
# WARNING: saving figure to file figures\pca.pdf
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_26328\1917813240.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 38119 × 24572
#     obs: 'treatment', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_MT', 'pct_counts_MT', 'S_score', 'G2M_score', 'phase'
#     var: 'gene_ids', 'n_cells', 'MT', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'treatment_colors'

# %%
adata.var
# Out:
#                               gene_ids  n_cells     MT  n_cells_by_counts  \
# DOK1                            dok1.L     3052  False               3052
# RT26                          mrps26.L     4926  False               4926
# DQX1                            dqx1.L       60  False                 60
# PCGF1_1                        pcgf1.L     1209  False               1209
# LOC108704858              LOC108704858     5922  False               5922
# ...                                ...      ...    ...                ...
# NU6M                               ND6     1105  False               1105
# unassigned_gene_22  unassigned_gene_22        8  False                  8
# CYB                               CYTB    39642  False              39642
# unassigned_gene_23  unassigned_gene_23       43  False                 43
# unassigned_gene_24  unassigned_gene_24       47  False                 47
#
#                     mean_counts  pct_dropout_by_counts  total_counts
# DOK1                   0.079724              92.881301        3418.0
# RT26                   0.137662              88.510251        5902.0
# DQX1                   0.001446              99.860052          62.0
# PCGF1_1                0.029926              97.180043        1283.0
# LOC108704858           0.160544              86.187111        6883.0
# ...                         ...                    ...           ...
# NU6M                   0.027430              97.422620        1176.0
# unassigned_gene_22     0.000187              99.981340           8.0
# CYB                    5.068668               7.536212      217309.0
# unassigned_gene_23     0.001003              99.899704          43.0
# unassigned_gene_24     0.001120              99.890374          48.0
#
# [24572 rows x 7 columns]

# %% [markdown]
# ## Saving adata

# %%
adata.write(r'/Code/data/single_cell/animals/frog/frog_2/laevis/''frog_2_after_qc.h5ad')

# %% [markdown]
# Preparing files to be opened in R studio

# %%
# Preparing files to be opened in R studio

matrix_dense = adata.X.toarray()

# Create a DataFrame from the dense array with observation names as index and variable names as columns
matrix_df = pd.DataFrame(matrix_dense, index=adata.obs_names, columns=adata.var_names)

# Save the DataFrame to a CSV file
matrix_df.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''matrix_new.csv')
print('matrix file is transformed')

#save obs as scv
adata.obs.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''obs_new.csv')
print('obs file is transformed')

# Save variable data to a CSV file
adata.var.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''var_new.csv')
print('var file is transformed')
