# %% [markdown]
# # QC for komodo achinoam
# Using komodo data from the drive

# %% [markdown]
# ## Imports

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import os
import bbknn
from pathlib import Path

# %% [markdown]
# ## Single cell settings

# %%
sc.settings.verbosity = 4
sc.settings.set_figure_params(80)
sc.settings._file_format_figs = 'pdf'
sc.settings.savefigs = False
use_first_n_samples = 0
full_sparse = False
# Out:
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_15072\3661074169.py:2: FutureWarning: The specified parameters ('scanpy',) are no longer positional. Please specify them like `scanpy=80`
#   sc.settings.set_figure_params(80)

# %% [markdown]
# ## QC workflow

# %%
adatas = []
data_names = ['control','lf','lps','pic']
main_path = '/Code/data/single_cell/animals/komodo/komodo_achinoam/'
paths = ['\\control','\\lf','\\lps','\\pic']    #...etc - Folders with matrix, features and barcodes gz files.
for path in paths:
    adata = sc.read_10x_mtx(main_path + path, var_names='gene_symbols', cache=False)    # use gene symbols for the variable names (variables-axis index)
    sc.logging.print_memory_usage()
    print(adata.shape)
    adatas.append(adata)
# Out:
#     reading \Code\data\single_cell\animals\komodo\komodo_achinoam\control\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.47 GB, difference +0.47 GB
# (8618, 18772)
#     reading \Code\data\single_cell\animals\komodo\komodo_achinoam\lf\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.66 GB, difference +0.18 GB
# (6753, 18772)
#     reading \Code\data\single_cell\animals\komodo\komodo_achinoam\lps\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.65 GB, difference -0.01 GB
# (6580, 18772)
#     reading \Code\data\single_cell\animals\komodo\komodo_achinoam\pic\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.81 GB, difference +0.16 GB
# (7198, 18772)

# %%
adata = adatas[0].concatenate(adatas[1:], batch_categories=data_names, batch_key='treatment')

adata
# Out:
# c:\Python\Python310\lib\site-packages\anndata\_core\anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# AnnData object with n_obs × n_vars = 29149 × 18772
#     obs: 'treatment'
#     var: 'gene_ids', 'feature_types'

# %%
genes = pd.read_csv('/Code/data/single_cell/animals/eggnog_croc_chic_komo_turt.csv')
genes.dropna(subset = ['komodo gene id'], inplace=True)

genes_dict = dict(zip(genes['komodo gene id'].astype('str'), genes.eggnog_name.astype('str')))

dict_multi, dict_uni = {}, {}
for d in genes_dict:
    if len(d.split(',')) != 1:
        dict_multi[d] = genes_dict[d]
    else:
        dict_uni[d] =  genes_dict[d]

multi_result_dict = {}

for key_str, value in dict_multi.items():
    # Convert the string key to a set
    key_set = set(key_str.strip("{}").replace("'", "").split(", "))

    # Iterate through the elements in the set and create individual keys
    for element in key_set:
        multi_result_dict[element] = value

genes_dict = {**dict_uni, **multi_result_dict}

genes_dict
# Out:
# {'ENSVKKG00000005575': '26-29-P',
#  'ENSVKKG00000004726': 'A1CF',
#  'ENSVKKG00000017660': 'A4GALT',
#  'ENSVKKG00000007425': 'A4GNT',
#  'ENSVKKG00000003827': 'AAAS',
#  'ENSVKKG00000013082': 'AACS',
#  'ENSVKKG00000016542': 'AADAC',
#  'ENSVKKG00000008569': 'AAED1',
#  'ENSVKKG00000017056': 'AAGAB',
#  'ENSVKKG00000001724': 'AAK1',
#  'ENSVKKG00000005342': 'AAMDC',
#  'ENSVKKG00000001902': 'AAMP',
#  'ENSVKKG00000016082': 'AANAT',
#  'ENSVKKG00000013166': 'AAR2',
#  'ENSVKKG00000011438': 'AARS',
#  'ENSVKKG00000002870': 'AARS2',
#  'ENSVKKG00000016215': 'AARSD1',
#  'ENSVKKG00000018129': 'AASDH',
#  'ENSVKKG00000006942': 'AASDHPPT',
#  'ENSVKKG00000015327': 'AASS',
#  'ENSVKKG00000018231': 'AATF',
#  'ENSVKKG00000016398': 'AATK',
#  'ENSVKKG00000002294': 'ABCA1',
#  'ENSVKKG00000018423': 'ABCA12',
#  'ENSVKKG00000002449': 'ABCA2',
#  'ENSVKKG00000011289': 'ABCA3',
#  'ENSVKKG00000000507': 'ABCA4',
#  'ENSVKKG00000011175': 'ABCA6',
#  'ENSVKKG00000007020': 'ABCA7',
#  'ENSVKKG00000007849': 'ABCA9',
#  'ENSVKKG00000003567': 'ABCB1',
#  'ENSVKKG00000017433': 'ABCB10',
#  'ENSVKKG00000018251': 'ABCB11',
#  'ENSVKKG00000000960': 'ABCB6',
#  'ENSVKKG00000010947': 'ABCB7',
#  'ENSVKKG00000008242': 'ABCB8',
#  'ENSVKKG00000015515': 'ABCB9',
#  'ENSVKKG00000008408': 'ABCC1',
#  'ENSVKKG00000004448': 'ABCC10',
#  'ENSVKKG00000010944': 'ABCC13',
#  'ENSVKKG00000002361': 'ABCC2',
#  'ENSVKKG00000003322': 'ABCC3',
#  'ENSVKKG00000012637': 'ABCC4',
#  'ENSVKKG00000015281': 'ABCC5',
#  'ENSVKKG00000007601': 'ABCC6',
#  'ENSVKKG00000009224': 'ABCC8',
#  'ENSVKKG00000010849': 'ABCD2',
#  'ENSVKKG00000000339': 'ABCD3',
#  'ENSVKKG00000011981': 'ABCD4',
#  'ENSVKKG00000003065': 'ABCE1',
#  'ENSVKKG00000004572': 'ABCF2',
#  'ENSVKKG00000013883': 'ABCF3',
#  'ENSVKKG00000014557': 'ABCG1',
#  'ENSVKKG00000004078': 'ABCG4',
#  'ENSVKKG00000012551': 'ABHD10',
#  'ENSVKKG00000003729': 'ABHD11',
#  'ENSVKKG00000014350': 'ABHD12',
#  'ENSVKKG00000002734': 'ABHD13',
#  'ENSVKKG00000015157': 'ABHD14B',
#  'ENSVKKG00000008129': 'ABHD17A',
#  'ENSVKKG00000004818': 'ABHD17B',
#  'ENSVKKG00000017750': 'ABHD17C',
#  'ENSVKKG00000017826': 'ABHD2',
#  'ENSVKKG00000007576': 'ABHD3',
#  'ENSVKKG00000003220': 'ABHD5',
#  'ENSVKKG00000010430': 'ABHD6',
#  'ENSVKKG00000015734': 'ABHD8',
#  'ENSVKKG00000017868': 'ABI1',
#  'ENSVKKG00000013643': 'ABI2',
#  'ENSVKKG00000002582': 'ABI3',
#  'ENSVKKG00000017235': 'ABI3BP',
#  'ENSVKKG00000005075': 'ABL1',
#  'ENSVKKG00000008987': 'ABL2',
#  'ENSVKKG00000004711': 'ABLIM1',
#  'ENSVKKG00000010211': 'ABLIM2',
#  'ENSVKKG00000013315': 'ABLIM3',
#  'ENSVKKG00000014256': 'ABR',
#  'ENSVKKG00000017358': 'ABRA',
#  'ENSVKKG00000009088': 'ABRACL',
#  'ENSVKKG00000001273': 'ABTB1',
#  'ENSVKKG00000011686': 'ABTB2',
#  'ENSVKKG00000014871': 'ACAA1',
#  'ENSVKKG00000011334': 'ACAA2',
#  'ENSVKKG00000018225': 'ACACA',
#  'ENSVKKG00000010307': 'ACACB',
#  'ENSVKKG00000018052': 'ACAD11',
#  'ENSVKKG00000015472': 'ACAD8',
#  'ENSVKKG00000007578': 'ACAD9',
#  'ENSVKKG00000018502': 'ACADL',
#  'ENSVKKG00000002343': 'ACADM',
#  'ENSVKKG00000009649': 'UNC119B',
#  'ENSVKKG00000007718': 'ACADSB',
#  'ENSVKKG00000013456': 'ACAP1',
#  'ENSVKKG00000008594': 'ACAP2',
#  'ENSVKKG00000013507': 'ACAP3',
#  'ENSVKKG00000006914': 'ACAT1',
#  'ENSVKKG00000017548': 'ACAT2',
#  'ENSVKKG00000015639': 'ACBD3',
#  'ENSVKKG00000012063': 'ACBD4',
#  'ENSVKKG00000017867': 'ACBD5',
#  'ENSVKKG00000005251': 'ACBD6',
#  'ENSVKKG00000003562': 'ACBD7',
#  'ENSVKKG00000016540': 'ACE',
#  'ENSVKKG00000005936': 'ACE2',
#  'ENSVKKG00000008280': 'ACER1',
#  'ENSVKKG00000014745': 'ACER2',
#  'ENSVKKG00000005314': 'ACER3',
#  'ENSVKKG00000014845': 'ACHE',
#  'ENSVKKG00000014732': 'ACIN1',
#  'ENSVKKG00000014033': 'ACJ6',
#  'ENSVKKG00000010095': 'ACKR3',
#  'ENSVKKG00000018053': 'ACKR4',
#  'ENSVKKG00000016311': 'ACLY',
#  'ENSVKKG00000003307': 'ACMSD',
#  'ENSVKKG00000018173': 'ACN9',
#  'ENSVKKG00000009904': 'ACO1',
#  'ENSVKKG00000016895': 'ACO2',
#  'ENSVKKG00000011262': 'ACOT11',
#  'ENSVKKG00000006639': 'ACOT13',
#  'ENSVKKG00000002851': 'ACOT4',
#  'ENSVKKG00000006390': 'ACOT7',
#  'ENSVKKG00000016039': 'ACOX1',
#  'ENSVKKG00000014782': 'ACOX2',
#  'ENSVKKG00000010193': 'ACOX3',
#  'ENSVKKG00000000881': 'ACP1',
#  'ENSVKKG00000016424': 'ACP2',
#  'ENSVKKG00000014017': 'ACP5',
#  'ENSVKKG00000012073': 'ACP6',
#  'ENSVKKG00000017711': 'ACR',
#  'ENSVKKG00000003631': 'ACRBP',
#  'ENSVKKG00000017886': 'ACRC',
#  'ENSVKKG00000007387': 'ACSBG1',
#  'ENSVKKG00000008344': 'ACSBG2',
#  'ENSVKKG00000014476': 'ACSF2',
#  'ENSVKKG00000005812': 'ACSF3',
#  'ENSVKKG00000004551': 'ACSL1',
#  'ENSVKKG00000011511': 'ACSL3',
#  'ENSVKKG00000010069': 'ACSL4',
#  'ENSVKKG00000003899': 'ACSL5',
#  'ENSVKKG00000013800': 'ACSL6',
#  'ENSVKKG00000005480': 'ACSM3',
#  'ENSVKKG00000005525': 'ACSM4',
#  'ENSVKKG00000017083': 'ACSS2',
#  'ENSVKKG00000015805': 'ACSS3',
#  'ENSVKKG00000017431': 'ACTA1',
#  'ENSVKKG00000004994': 'ACTA2',
#  'ENSVKKG00000016390': 'ACTG1',
#  'ENSVKKG00000006955': 'ACTG2',
#  'ENSVKKG00000013130': 'ACTL10',
#  'ENSVKKG00000012359': 'ACTL6A',
#  'ENSVKKG00000013999': 'ACTL6B',
#  'ENSVKKG00000000212': 'ACTN1',
#  'ENSVKKG00000006692': 'ACTN2',
#  'ENSVKKG00000013952': 'ACTN4',
#  'ENSVKKG00000001466': 'ACTR10',
#  'ENSVKKG00000014504': 'ACTR1A',
#  'ENSVKKG00000008156': 'ACTR2',
#  'ENSVKKG00000003292': 'ACTR3',
#  'ENSVKKG00000000534': 'ACTR3B',
#  'ENSVKKG00000012645': 'ACTR5',
#  'ENSVKKG00000010241': 'ACTR6',
#  'ENSVKKG00000009796': 'ACTR8',
#  'ENSVKKG00000016620': 'ACVR1',
#  'ENSVKKG00000005455': 'ACVR1B',
#  'ENSVKKG00000016621': 'ACVR1C',
#  'ENSVKKG00000005716': 'ACVR2A',
#  'ENSVKKG00000015062': 'ACVR2B',
#  'ENSVKKG00000005458': 'ACVRL1',
#  'ENSVKKG00000015162': 'ACY1',
#  'ENSVKKG00000015808': 'ACYP1',
#  'ENSVKKG00000010627': 'ACYP2',
#  'ENSVKKG00000012213': 'ADA',
#  'ENSVKKG00000007611': 'ADAD1',
#  'ENSVKKG00000007595': 'ADAL',
#  'ENSVKKG00000017367': 'ADAM10',
#  'ENSVKKG00000016135': 'ADAM11',
#  'ENSVKKG00000008267': 'ADAM12',
#  'ENSVKKG00000006243': 'ADAM17',
#  'ENSVKKG00000014935': 'ADAM19',
#  'ENSVKKG00000003644': 'ADAM22',
#  'ENSVKKG00000018541': 'ADAM23',
#  'ENSVKKG00000013473': 'ADAM28',
#  'ENSVKKG00000018324': 'ADAM33',
#  'ENSVKKG00000015462': 'ADAM9',
#  'ENSVKKG00000010486': 'ADAMTS1',
#  'ENSVKKG00000003112': 'ADAMTS10',
#  'ENSVKKG00000011502': 'ADAMTS12',
#  'ENSVKKG00000002285': 'ADAMTS13',
#  'ENSVKKG00000003722': 'ADAMTS14',
#  'ENSVKKG00000015490': 'ADAMTS15',
#  'ENSVKKG00000017824': 'ADAMTS17',
#  'ENSVKKG00000014196': 'ADAMTS18',
#  'ENSVKKG00000008086': 'ADAMTS19',
#  'ENSVKKG00000001321': 'ADAMTS2',
#  'ENSVKKG00000000313': 'ADAMTS20',
#  'ENSVKKG00000018363': 'ADAMTS3',
#  'ENSVKKG00000007247': 'ADAMTS4',
#  'ENSVKKG00000010483': 'ADAMTS5',
#  'ENSVKKG00000005178': 'ADAMTS6',
#  'ENSVKKG00000016133': 'ADAMTS7',
#  'ENSVKKG00000015491': 'ADAMTS8',
#  'ENSVKKG00000013689': 'ADAMTS9',
#  'ENSVKKG00000014689': 'ADAMTSL1',
#  'ENSVKKG00000017496': 'ADAMTSL3',
#  'ENSVKKG00000009902': 'ADAR',
#  'ENSVKKG00000013658': 'ADARB1',
#  'ENSVKKG00000013667': 'ADARB2',
#  'ENSVKKG00000014589': 'ADAT1',
#  'ENSVKKG00000009062': 'ADAT2',
#  'ENSVKKG00000016102': 'ADCK1',
#  'ENSVKKG00000003330': 'ADCK2',
#  'ENSVKKG00000015655': 'ADCK3',
#  'ENSVKKG00000017101': 'ADCK5',
#  'ENSVKKG00000010985': 'ADCY1',
#  'ENSVKKG00000013697': 'ADCY10',
#  'ENSVKKG00000004152': 'ADCY2',
#  'ENSVKKG00000001342': 'ADCY3',
#  'ENSVKKG00000013993': 'ADCY5',
#  'ENSVKKG00000003805': 'ADCY6',
#  'ENSVKKG00000003484': 'ADCY7',
#  'ENSVKKG00000004112': 'ADCY8',
#  'ENSVKKG00000008058': 'ADCY9',
#  'ENSVKKG00000000642': 'ADCYAP1',
#  'ENSVKKG00000014518': 'ADCYAP1R1',
#  'ENSVKKG00000008378': 'ADD1',
#  'ENSVKKG00000004884': 'ADD2',
#  'ENSVKKG00000003880': 'ADD3',
#  'ENSVKKG00000000411': 'ADGB',
#  'ENSVKKG00000011183': 'ADH5',
#  'ENSVKKG00000016771': 'ADHFE1',
#  'ENSVKKG00000000141': 'ADI1',
#  'ENSVKKG00000011193': 'ADIPOQ',
#  'ENSVKKG00000008729': 'ADIPOR1',
#  'ENSVKKG00000018575': 'ADIPOR2',
#  'ENSVKKG00000011634': 'ADK',
#  'ENSVKKG00000015002': 'ADM',
#  'ENSVKKG00000015716': 'ADMP',
#  'ENSVKKG00000016433': 'ADNP',
#  'ENSVKKG00000006586': 'ADNP2',
#  'ENSVKKG00000009322': 'ADORA2A',
#  'ENSVKKG00000014253': 'ADORA2B',
#  'ENSVKKG00000009809': 'ADORA3',
#  'ENSVKKG00000007090': 'ADPGK',
#  'ENSVKKG00000009884': 'ADPRHL1',
#  'ENSVKKG00000012747': 'ADPRHL2',
#  'ENSVKKG00000001648': 'ADPRM',
#  'ENSVKKG00000015082': 'ADRA1A',
#  'ENSVKKG00000018356': 'ADRA1B',
#  'ENSVKKG00000003893': 'ADRA2A',
#  'ENSVKKG00000010177': 'ADRA2C',
#  'ENSVKKG00000003915': 'ADRB1',
#  'ENSVKKG00000013320': 'ADRB2',
#  'ENSVKKG00000015109': 'ADRB3',
#  'ENSVKKG00000017049': 'ADRBK1',
#  'ENSVKKG00000017918': 'ADRBK2',
#  'ENSVKKG00000003872': 'ADRM1',
#  'ENSVKKG00000016480': 'ADSL',
#  'ENSVKKG00000005856': 'ADSS',
#  'ENSVKKG00000000203': 'ADSSL1',
#  'ENSVKKG00000015434': 'AEBP1',
#  'ENSVKKG00000014574': 'AEBP2',
#  'ENSVKKG00000017831': 'AEN',
#  'ENSVKKG00000006945': 'AES',
#  'ENSVKKG00000012601': 'AFAP1',
#  'ENSVKKG00000013311': 'AFAP1L1',
#  'ENSVKKG00000003919': 'AFAP1L2',
#  'ENSVKKG00000010747': 'AFF1',
#  'ENSVKKG00000010835': 'AFF2',
#  'ENSVKKG00000006265': 'AFF3',
#  'ENSVKKG00000011838': 'AFF4',
#  'ENSVKKG00000017615': 'AFG3L2',
#  'ENSVKKG00000004553': 'AFMID',
#  'ENSVKKG00000008140': 'AFTPH',
#  'ENSVKKG00000016717': 'AGA',
#  'ENSVKKG00000009703': 'AGAP1',
#  'ENSVKKG00000000544': 'AGBL1',
#  'ENSVKKG00000017186': 'AGBL2',
#  'ENSVKKG00000009964': 'AGBL3',
#  'ENSVKKG00000010492': 'AGBL4',
#  'ENSVKKG00000008417': 'AGBL5',
#  'ENSVKKG00000011833': 'AGFG1',
#  'ENSVKKG00000001300': 'AGGF1',
#  'ENSVKKG00000003376': 'AGK',
#  'ENSVKKG00000007188': 'AGL',
#  'ENSVKKG00000009341': 'AGMAT',
#  'ENSVKKG00000018112': 'AGMO',
#  'ENSVKKG00000011373': 'AGO',
#  'ENSVKKG00000000258': 'AGO1',
#  'ENSVKKG00000014483': 'AGO2',
#  'ENSVKKG00000000044': 'AGO3',
#  'ENSVKKG00000007758': 'AGO4',
#  'ENSVKKG00000013917': 'AGPAT3',
#  'ENSVKKG00000016860': 'AGPAT4',
#  'ENSVKKG00000000459': 'AGPAT5',
#  'ENSVKKG00000015447': 'AGPAT6',
#  'ENSVKKG00000009812': 'AGPAT9',
#  'ENSVKKG00000002044': 'AGPS',
#  'ENSVKKG00000018105': 'AGR2',
#  'ENSVKKG00000018104': 'AGR3',
#  'ENSVKKG00000001607': 'AGRN',
#  'ENSVKKG00000013709': 'AGRP',
#  'ENSVKKG00000017440': 'AGT',
#  'ENSVKKG00000008791': 'AGTPBP1',
#  'ENSVKKG00000015756': 'AGTR1',
#  'ENSVKKG00000010563': 'AGTR2',
#  'ENSVKKG00000001344': 'AGTRAP',
#  'ENSVKKG00000007939': 'AGXT',
#  'ENSVKKG00000000304': 'AGXT2',
#  'ENSVKKG00000000174': 'AHCTF1',
#  'ENSVKKG00000016993': 'AHCY',
#  'ENSVKKG00000005870': 'AHCYL1',
#  'ENSVKKG00000000541': 'AHCYL2',
#  'ENSVKKG00000005569': 'AHDC1',
#  'ENSVKKG00000009133': 'AHI1',
#  'ENSVKKG00000018102': 'AHR',
#  'ENSVKKG00000016084': 'AHSA1',
#  'ENSVKKG00000012302': 'AHSG',
#  'ENSVKKG00000002192': 'AICDA',
#  'ENSVKKG00000015563': 'AIDA',
#  'ENSVKKG00000005064': 'AIF1L',
#  'ENSVKKG00000011951': 'AIFM1',
#  'ENSVKKG00000002804': 'AIFM2',
#  'ENSVKKG00000009064': 'AIG1',
#  'ENSVKKG00000000170': 'AIM1',
#  'ENSVKKG00000005828': 'AIM1L',
#  'ENSVKKG00000010093': 'AIMP1',
#  'ENSVKKG00000007922': 'AIMP2',
#  'ENSVKKG00000017189': 'AIP',
#  'ENSVKKG00000011899': 'AIPL1',
#  'ENSVKKG00000010311': 'AJAP1',
#  'ENSVKKG00000017266': 'AK1',
#  'ENSVKKG00000012026': 'AK3',
#  'ENSVKKG00000010509': 'AK4',
#  'ENSVKKG00000002366': 'AK5',
#  'ENSVKKG00000002952': 'AK6',
#  'ENSVKKG00000003807': 'AK7',
#  'ENSVKKG00000018065': 'AKAP1',
#  'ENSVKKG00000011302': 'AKAP10',
#  'ENSVKKG00000012948': 'AKAP11',
#  'ENSVKKG00000018195': 'AKAP12',
#  'ENSVKKG00000010683': 'AKAP13',
#  'ENSVKKG00000010596': 'PALM2',
#  'ENSVKKG00000000388': 'AKAP5',
#  'ENSVKKG00000012451': 'AKAP6',
#  'ENSVKKG00000010597': 'AKAP7',
#  'ENSVKKG00000002381': 'AKAP8',
#  'ENSVKKG00000002379': 'AKAP8L',
#  'ENSVKKG00000003804': 'AKAP9',
#  'ENSVKKG00000017475': 'AKHR',
#  'ENSVKKG00000009282': 'AKIRIN2',
#  'ENSVKKG00000000294': 'AKR1A1',
#  'ENSVKKG00000010813': 'AKR1B1',
#  'ENSVKKG00000003055': 'AKR1D1',
#  'ENSVKKG00000013034': 'AKR7A2',
#  'ENSVKKG00000000152': 'AKT1',
#  'ENSVKKG00000016698': 'AKT2',
#  'ENSVKKG00000005861': 'AKT3',
#  'ENSVKKG00000014042': 'AKTIP',
#  'ENSVKKG00000003436': 'ALAD',
#  'ENSVKKG00000015194': 'ALAS1',
#  'ENSVKKG00000017220': 'ALCAM',
#  'ENSVKKG00000001656': 'ALDH18A1',
#  'ENSVKKG00000004805': 'ALDH1A1',
#  'ENSVKKG00000017374': 'ALDH1A2',
#  'ENSVKKG00000008654': 'ALDH1A3',
#  'ENSVKKG00000010722': 'ALDH1L2',
#  'ENSVKKG00000008718': 'ALDH2',
#  'ENSVKKG00000011290': 'ALDH3A2',
#  'ENSVKKG00000017162': 'ALDH3B1',
#  'ENSVKKG00000012436': 'ALDH4A1',
#  'ENSVKKG00000006643': 'ALDH5A1',
#  'ENSVKKG00000011977': 'ALDH6A1',
#  'ENSVKKG00000015505': 'ALDH7A1',
#  'ENSVKKG00000010366': 'ALDH8A1',
#  'ENSVKKG00000013790': 'ALDH9A1',
#  'ENSVKKG00000010601': 'ALDOB',
#  'ENSVKKG00000000695': 'ALDOC',
#  'ENSVKKG00000016774': 'ALG1',
#  'ENSVKKG00000000025': 'ALG10',
#  'ENSVKKG00000009180': 'ALG11',
#  'ENSVKKG00000016214': 'ALG12',
#  'ENSVKKG00000010107': 'ALG13',
#  'ENSVKKG00000000257': 'ALG14',
#  'ENSVKKG00000007652': 'ALG2',
#  'ENSVKKG00000011347': 'ALG3',
#  'ENSVKKG00000010429': 'ALG5',
#  'ENSVKKG00000012146': 'ALG6',
#  'ENSVKKG00000005789': 'ALG8',
#  'ENSVKKG00000017984': 'ALK',
#  'ENSVKKG00000016091': 'ALKBH1',
#  'ENSVKKG00000010249': 'ALKBH2',
#  'ENSVKKG00000011841': 'ALKBH3',
#  'ENSVKKG00000016651': 'ALKBH4',
#  'ENSVKKG00000017922': 'ALKBH5',
#  'ENSVKKG00000006928': 'ALKBH8',
#  'ENSVKKG00000018323': 'ALMS1',
#  'ENSVKKG00000014779': 'ALOX5',
#  'ENSVKKG00000006726': 'ALOX5AP',
#  'ENSVKKG00000018661': 'ALOXE3',
#  'ENSVKKG00000000890': 'ALPI',
#  'ENSVKKG00000007133': 'ALPK3',
#  'ENSVKKG00000009283': 'ALPL',
#  'ENSVKKG00000005291': 'ALS2',
#  'ENSVKKG00000014412': 'ALS2CL',
#  'ENSVKKG00000013436': 'ALX1',
#  'ENSVKKG00000011859': 'ALX4',
#  'ENSVKKG00000004699': 'ALYREF',
#  'ENSVKKG00000000050': 'AMACR',
#  'ENSVKKG00000002651': 'AMBP',
#  'ENSVKKG00000011971': 'AMBRA1',
#  'ENSVKKG00000005319': 'AMD1',
#  'ENSVKKG00000013998': 'AMDHD1',
#  'ENSVKKG00000008444': 'AMDHD2',
#  'ENSVKKG00000010129': 'AMER1',
#  'ENSVKKG00000007058': 'AMER2',
#  'ENSVKKG00000001571': 'AMER3',
#  'ENSVKKG00000002973': 'AMFR',
#  'ENSVKKG00000013356': 'AMH',
#  'ENSVKKG00000005905': 'AMIGO1',
#  'ENSVKKG00000014148': 'AMIGO2',
#  'ENSVKKG00000013113': 'AMIGO3',
#  'ENSVKKG00000010073': 'AMMECR1',
#  'ENSVKKG00000013939': 'AMMECR1L',
#  'ENSVKKG00000005256': 'AMN',
#  'ENSVKKG00000013801': 'AMN1',
#  'ENSVKKG00000009632': 'AMOT',
#  'ENSVKKG00000009424': 'AMOTL1',
#  'ENSVKKG00000007407': 'AMOTL2',
#  'ENSVKKG00000013089': 'AMPD1',
#  'ENSVKKG00000005883': 'AMPD2',
#  'ENSVKKG00000015003': 'AMPD3',
#  'ENSVKKG00000007472': 'AMPH',
#  'ENSVKKG00000004668': 'AMZ1',
#  'ENSVKKG00000014223': 'ANAPC1',
#  'ENSVKKG00000003062': 'ANAPC10',
#  'ENSVKKG00000007408': 'ANAPC13',
#  'ENSVKKG00000014687': 'ANAPC15',
#  'ENSVKKG00000003838': 'ANAPC16',
#  'ENSVKKG00000003290': 'ANAPC2',
#  'ENSVKKG00000006429': 'ANAPC4',
#  'ENSVKKG00000015529': 'ANAPC5',
#  'ENSVKKG00000015522': 'ANAPC7',
#  'ENSVKKG00000015866': 'ANGEL1',
#  'ENSVKKG00000000857': 'ANGEL2',
#  'ENSVKKG00000017362': 'ANGPT1',
#  'ENSVKKG00000011762': 'ANGPT4',
#  'ENSVKKG00000011985': 'ANGPTL1',
#  'ENSVKKG00000005137': 'ANGPTL2',
#  'ENSVKKG00000009146': 'ANGPTL5',
#  'ENSVKKG00000013486': 'ANGPTL7',
#  'ENSVKKG00000009374': 'ANK1',
#  'ENSVKKG00000010547': 'ANK2',
#  'ENSVKKG00000008911': 'ANK3',
#  'ENSVKKG00000001509': 'ANKDD1B',
#  'ENSVKKG00000006345': 'ANKEF1',
#  'ENSVKKG00000016691': 'ANKFY1',
#  'ENSVKKG00000002307': 'ANKH',
#  'ENSVKKG00000014652': 'ANKHD1',
#  'ENSVKKG00000016369': 'ANKIB1',
#  'ENSVKKG00000015735': 'ANKLE1',
#  'ENSVKKG00000012279': 'ANKLE2',
#  'ENSVKKG00000011108': 'ANKMY1',
#  'ENSVKKG00000018108': 'ANKMY2',
#  'ENSVKKG00000002716': 'ANKRA2',
#  'ENSVKKG00000005043': 'ANKRD1',
#  'ENSVKKG00000011548': 'ANKRD10',
#  'ENSVKKG00000005837': 'ANKRD11',
#  'ENSVKKG00000017586': 'TWSG1',
#  'ENSVKKG00000014844': 'ANKRD13A',
#  'ENSVKKG00000000941': 'ANKRD13C',
#  'ENSVKKG00000017146': 'ANKRD13D',
#  'ENSVKKG00000000173': 'ANKRD16',
#  'ENSVKKG00000004130': 'ANKRD17',
#  'ENSVKKG00000014280': 'ANKRD2',
#  'ENSVKKG00000004990': 'ANKRD22',
#  'ENSVKKG00000007894': 'ANKRD24',
#  'ENSVKKG00000011541': 'ANKRD27',
#  'ENSVKKG00000014285': 'ANKRD28',
#  'ENSVKKG00000007495': 'ANKRD29',
#  'ENSVKKG00000001596': 'ANKRD31',
#  'ENSVKKG00000007434': 'ANKRD32',
#  'ENSVKKG00000005459': 'ANKRD33',
#  'ENSVKKG00000009222': 'ANKRD39',
#  'ENSVKKG00000002134': 'ANKRD42',
#  'ENSVKKG00000009801': 'ANKRD44',
#  'ENSVKKG00000011047': 'ANKRD46',
#  'ENSVKKG00000009509': 'ANKRD49',
#  'ENSVKKG00000008552': 'ANKRD50',
#  'ENSVKKG00000005338': 'ANKRD52',
#  'ENSVKKG00000006437': 'ANKRD54',
#  'ENSVKKG00000003979': 'ANKRD55',
#  'ENSVKKG00000009416': 'ANKRD6',
#  'ENSVKKG00000007926': 'ANKRD61',
#  'ENSVKKG00000005027': 'ANKRD9',
#  'ENSVKKG00000007372': 'ANKS1A',
#  'ENSVKKG00000010267': 'ANKS1B',
#  'ENSVKKG00000005404': 'ANKS4B',
#  'ENSVKKG00000004080': 'ANKS6',
#  'ENSVKKG00000000945': 'ANKZF1',
#  'ENSVKKG00000007583': 'ANLN',
#  'ENSVKKG00000013914': 'ANO1',
#  'ENSVKKG00000003214': 'ANO10',
#  'ENSVKKG00000001882': 'ANO3',
#  'ENSVKKG00000010231': 'ANO4',
#  'ENSVKKG00000002008': 'ANO5',
#  'ENSVKKG00000014167': 'ANO6',
#  'ENSVKKG00000002744': 'ANO8',
#  'ENSVKKG00000001113': 'ANP32E',
#  'ENSVKKG00000016024': 'ANPEP',
#  'ENSVKKG00000001668': 'ANTXR1',
#  'ENSVKKG00000009693': 'ANTXR2',
#  'ENSVKKG00000004760': 'ANTXRL',
#  'ENSVKKG00000004798': 'ANXA1',
#  'ENSVKKG00000004867': 'ANXA10',
#  'ENSVKKG00000008261': 'ANXA11',
#  'ENSVKKG00000010536': 'ANXA2',
#  'ENSVKKG00000001762': 'ANXA4',
#  'ENSVKKG00000012422': 'ANXA5',
#  'ENSVKKG00000004803': 'ANXA6',
#  'ENSVKKG00000002875': 'ANXA7',
#  'ENSVKKG00000007581': 'AOAH',
#  'ENSVKKG00000008220': 'AOC1',
#  'ENSVKKG00000010511': 'AP1AR',
#  'ENSVKKG00000009269': 'AP1B1',
#  'ENSVKKG00000014582': 'AP1G1',
#  'ENSVKKG00000003713': 'AP1M1',
#  'ENSVKKG00000002114': 'AP1M2',
#  'ENSVKKG00000017895': 'AP1S2',
#  'ENSVKKG00000011517': 'WDFY1',
#  'ENSVKKG00000004470': 'AP2A2',
#  'ENSVKKG00000001854': 'AP2B1',
#  'ENSVKKG00000015278': 'AP2M1',
#  'ENSVKKG00000015052': 'AP2S1',
#  'ENSVKKG00000001162': 'AP3B1',
#  'ENSVKKG00000017554': 'AP3B2',
#  'ENSVKKG00000013272': 'AP3D1',
#  'ENSVKKG00000011633': 'AP3M1',
#  'ENSVKKG00000015215': 'AP3S1',
#  'ENSVKKG00000012713': 'AP4B1',
#  'ENSVKKG00000003463': 'AP4E1',
#  'ENSVKKG00000012364': 'AP4S1',
#  'ENSVKKG00000001424': 'AP5M1',
#  'ENSVKKG00000018303': 'AP5S1',
#  'ENSVKKG00000006710': 'AP5Z1',
#  'ENSVKKG00000013457': 'APAF1',
#  'ENSVKKG00000006095': 'APBA1',
#  'ENSVKKG00000010344': 'APBA2',
#  'ENSVKKG00000012706': 'APBA3',
#  'ENSVKKG00000016790': 'APBB1',
#  'ENSVKKG00000017872': 'APBB1IP',
#  'ENSVKKG00000006962': 'APBB3',
#  'ENSVKKG00000014920': 'APC',
#  'ENSVKKG00000017591': 'APCDD1',
#  'ENSVKKG00000004065': 'APCDD1L',
#  'ENSVKKG00000014221': 'APEH',
#  'ENSVKKG00000011825': 'API5',
#  'ENSVKKG00000011700': 'APIP',
#  'ENSVKKG00000013395': 'APITD1',
#  'ENSVKKG00000008174': 'APLF',
#  'ENSVKKG00000012000': 'APLN',
#  'ENSVKKG00000014665': 'APLNR',
#  'ENSVKKG00000000967': 'APLP2',
#  'ENSVKKG00000010060': 'APMAP',
#  'ENSVKKG00000004638': 'APOA1BP',
#  'ENSVKKG00000010708': 'APOB',
#  'ENSVKKG00000007147': 'APOBEC2',
#  'ENSVKKG00000004678': 'APOBEC4',
#  'ENSVKKG00000008693': 'APOD',
#  'ENSVKKG00000005369': 'APOF',
#  'ENSVKKG00000007805': 'APOH',
#  'ENSVKKG00000009948': 'APOLD1',
#  'ENSVKKG00000005034': 'APOO',
#  'ENSVKKG00000014633': 'APOOL',
#  'ENSVKKG00000005425': 'APOPT1',
#  'ENSVKKG00000017300': 'APOV1',
#  'ENSVKKG00000010488': 'APP',
#  'ENSVKKG00000010674': 'APPBP2',
#  'ENSVKKG00000010282': 'APPL1',
#  'ENSVKKG00000009483': 'APPL2',
#  'ENSVKKG00000014243': 'APRT',
#  'ENSVKKG00000007208': 'APTX',
#  'ENSVKKG00000014849': 'AQP1',
#  'ENSVKKG00000010355': 'AQP10',
#  'ENSVKKG00000007305': 'AQP12B',
#  'ENSVKKG00000015825': 'AQP2',
#  'ENSVKKG00000015989': 'AQP3',
#  'ENSVKKG00000006814': 'AQP4',
#  'ENSVKKG00000015930': 'AQP5',
#  'ENSVKKG00000010447': 'AQP7',
#  'ENSVKKG00000012712': 'AQP8',
#  'ENSVKKG00000017371': 'AQP9',
#  'ENSVKKG00000012227': 'AQR',
#  'ENSVKKG00000009748': 'AR',
#  'ENSVKKG00000007496': 'ARAP2',
#  'ENSVKKG00000014824': 'ARAP3',
#  'ENSVKKG00000016954': 'ARC',
#  'ENSVKKG00000009082': 'ARCN1',
#  'ENSVKKG00000016496': 'AREG',
#  'ENSVKKG00000015715': 'AREL1',
#  'ENSVKKG00000014421': 'ARF1',
#  'ENSVKKG00000010287': 'ARF4',
#  'ENSVKKG00000006587': 'ARF6',
#  'ENSVKKG00000003103': 'ARFGAP1',
#  'ENSVKKG00000016415': 'ARFGAP2',
#  'ENSVKKG00000017662': 'ARFGAP3',
#  'ENSVKKG00000002986': 'ARFGEF1',
#  'ENSVKKG00000003529': 'ARFGEF2',
#  'ENSVKKG00000005778': 'ARFIP1',
#  'ENSVKKG00000016783': 'ARFIP2',
#  'ENSVKKG00000001516': 'ARFRP1',
#  'ENSVKKG00000018483': 'ARG2',
#  'ENSVKKG00000011562': 'ARGLU1',
#  'ENSVKKG00000012002': 'ARHGAP1',
#  'ENSVKKG00000003115': 'ARHGAP10',
#  'ENSVKKG00000012205': 'ARHGAP11A',
#  'ENSVKKG00000017489': 'ARHGAP12',
#  'ENSVKKG00000005687': 'ARHGAP15',
#  'ENSVKKG00000012717': 'ARHGAP17',
#  'ENSVKKG00000010620': 'ARHGAP18',
#  'ENSVKKG00000014289': 'ARHGAP19',
#  'ENSVKKG00000007236': 'ARHGAP20',
#  'ENSVKKG00000017880': 'ARHGAP21',
#  'ENSVKKG00000010449': 'ARHGAP24',
#  'ENSVKKG00000014847': 'ARHGAP25',
#  'ENSVKKG00000011788': 'ARHGAP26',
#  'ENSVKKG00000016149': 'ARHGAP27',
#  'ENSVKKG00000010417': 'ARHGAP28',
#  'ENSVKKG00000000399': 'ARHGAP29',
#  'ENSVKKG00000004905': 'ARHGAP30',
#  'ENSVKKG00000017321': 'ARHGAP31',
#  'ENSVKKG00000002154': 'ARHGAP32',
#  'ENSVKKG00000000066': 'ARHGAP35',
#  'ENSVKKG00000012648': 'ARHGAP40',
#  'ENSVKKG00000001800': 'ARHGAP44',
#  'ENSVKKG00000012450': 'ARHGAP5',
#  'ENSVKKG00000006227': 'ARHGAP6',
#  'ENSVKKG00000017684': 'ARHGAP8',
#  'ENSVKKG00000004695': 'ARHGDIA',
#  'ENSVKKG00000009959': 'ARHGDIB',
#  'ENSVKKG00000005653': 'ARHGEF10',
#  'ENSVKKG00000008342': 'ARHGEF10L',
#  'ENSVKKG00000004237': 'ARHGEF12',
#  'ENSVKKG00000006137': 'ARHGEF16',
#  'ENSVKKG00000003780': 'ARHGEF17',
#  'ENSVKKG00000011439': 'ARHGEF18',
#  'ENSVKKG00000016555': 'ARHGEF26',
#  'ENSVKKG00000002385': 'ARHGEF28',
#  'ENSVKKG00000010229': 'ARHGEF3',
#  'ENSVKKG00000014331': 'ARHGEF33',
#  'ENSVKKG00000013246': 'ARHGEF37',
#  'ENSVKKG00000010086': 'ARHGEF38',
#  'ENSVKKG00000008854': 'ARHGEF39',
#  'ENSVKKG00000001497': 'ARHGEF4',
#  'ENSVKKG00000007804': 'ARHGEF5',
#  'ENSVKKG00000012308': 'ARHGEF6',
#  'ENSVKKG00000011545': 'ARHGEF7',
#  'ENSVKKG00000010131': 'ARHGEF9',
#  'ENSVKKG00000005772': 'ARID1A',
#  'ENSVKKG00000017580': 'ARID1B',
#  'ENSVKKG00000014160': 'ARID2',
#  'ENSVKKG00000002622': 'ARID3B',
#  'ENSVKKG00000001227': 'ARID4A',
#  'ENSVKKG00000017327': 'ARID4B',
#  'ENSVKKG00000008639': 'ARID5A',
#  'ENSVKKG00000016189': 'ARID5B',
#  'ENSVKKG00000007103': 'ARIH1',
#  'ENSVKKG00000015065': 'ARIH2',
#  'ENSVKKG00000010205': 'ARL1',
#  'ENSVKKG00000014996': 'ARL10',
#  'ENSVKKG00000012509': 'ARL13B',
#  'ENSVKKG00000000590': 'ARL14',
#  'ENSVKKG00000001281': 'ARL14EP',
#  'ENSVKKG00000015223': 'ARL14EPL',
#  'ENSVKKG00000001928': 'ARL15',
#  'ENSVKKG00000004585': 'ARL16',
#  'ENSVKKG00000004459': 'ARL2BP',
#  'ENSVKKG00000014512': 'ARL3',
#  'ENSVKKG00000018116': 'ARL4A',
#  'ENSVKKG00000009582': 'ARL4C',
#  'ENSVKKG00000016747': 'ARL5A',
#  'ENSVKKG00000001379': 'ARL5B',
#  'ENSVKKG00000007107': 'ARL6IP1',
#  'ENSVKKG00000015500': 'ARL6IP4',
#  'ENSVKKG00000013132': 'ARL6IP5',
#  'ENSVKKG00000015795': 'ARL8A',
#  'ENSVKKG00000014837': 'ARL8B',
#  'ENSVKKG00000007354': 'ARL9',
#  'ENSVKKG00000003212': 'ARMC1',
#  'ENSVKKG00000018504': 'ARMC10',
#  'ENSVKKG00000005470': 'ARMC2',
#  'ENSVKKG00000000035': 'ARMC3',
#  'ENSVKKG00000017846': 'ARMC4',
#  'ENSVKKG00000011737': 'ARMC6',
#  'ENSVKKG00000013567': 'ARMC7',
#  'ENSVKKG00000007935': 'ARMC8',
#  'ENSVKKG00000003542': 'ARMC9',
#  'ENSVKKG00000004069': 'ARNT',
#  'ENSVKKG00000017751': 'ARNT2',
#  'ENSVKKG00000015048': 'ARNTL',
#  'ENSVKKG00000018436': 'ARNTL2',
#  'ENSVKKG00000006827': 'ARPC1A',
#  'ENSVKKG00000006831': 'ARPC1B',
#  'ENSVKKG00000001907': 'ARPC2',
#  'ENSVKKG00000015521': 'ARPC3',
#  'ENSVKKG00000015141': 'ARPC4',
#  'ENSVKKG00000004680': 'ARPC5',
#  'ENSVKKG00000001786': 'ARPC5L',
#  'ENSVKKG00000018265': 'ARPP19',
#  'ENSVKKG00000007853': 'ARPP21',
#  'ENSVKKG00000010010': 'ARR3',
#  'ENSVKKG00000012416': 'ARRDC1',
#  'ENSVKKG00000011665': 'ARRDC3',
#  'ENSVKKG00000017815': 'ARRDC4',
#  'ENSVKKG00000017712': 'ARSA',
#  'ENSVKKG00000001098': 'ARSB',
#  'ENSVKKG00000007841': 'ARSG',
#  'ENSVKKG00000004770': 'ARSI',
#  'ENSVKKG00000012396': 'ARSJ',
#  'ENSVKKG00000007531': 'ARSK',
#  'ENSVKKG00000003682': 'ARTN',
#  'ENSVKKG00000017444': 'ARV1',
#  'ENSVKKG00000017140': 'ARVCF',
#  'ENSVKKG00000007415': 'ARX',
#  'ENSVKKG00000014759': 'AS3MT',
#  'ENSVKKG00000017343': 'ASAH1',
#  'ENSVKKG00000005012': 'ASAH2',
#  'ENSVKKG00000004107': 'ASAP1',
#  'ENSVKKG00000006250': 'ASAP2',
#  'ENSVKKG00000005632': 'ASAP3',
#  'ENSVKKG00000009572': 'ASB1',
#  'ENSVKKG00000004915': 'ASB10',
#  'ENSVKKG00000005990': 'ASB11',
#  'ENSVKKG00000010127': 'ASB12',
#  'ENSVKKG00000000267': 'ASB13',
#  'ENSVKKG00000010283': 'ASB14',
#  'ENSVKKG00000015358': 'ASB15',
#  'ENSVKKG00000016322': 'ASB16',
#  'ENSVKKG00000009714': 'ASB18',
#  'ENSVKKG00000000540': 'ASB2',
#  'ENSVKKG00000010170': 'ASB3',
#  'ENSVKKG00000018260': 'ASB4',
#  'ENSVKKG00000001476': 'ASB6',
#  'ENSVKKG00000008638': 'ASB7',
#  'ENSVKKG00000005902': 'ASB8',
#  'ENSVKKG00000005995': 'ASB9',
#  'ENSVKKG00000003837': 'ASCC1',
#  'ENSVKKG00000008563': 'ASCC2',
#  'ENSVKKG00000003104': 'ASCC3',
#  'ENSVKKG00000013234': 'ASCL1',
#  'ENSVKKG00000004698': 'ASCL2',
#  'ENSVKKG00000012014': 'ASCL3',
#  'ENSVKKG00000004986': 'ASF1A',
#  'ENSVKKG00000008406': 'ASH1L',
#  'ENSVKKG00000015099': 'ASH2L',
#  'ENSVKKG00000016168': 'ASIC2',
#  'ENSVKKG00000017198': 'ASIC4',
#  'ENSVKKG00000000593': 'ASIC5',
#  'ENSVKKG00000016994': 'ASIP',
#  'ENSVKKG00000005712': 'ASL',
#  'ENSVKKG00000010248': 'ASMTL',
#  'ENSVKKG00000004644': 'ASNA1',
#  'ENSVKKG00000018171': 'ASNS',
#  'ENSVKKG00000002936': 'ASNSD1',
#  'ENSVKKG00000011307': 'ASPA',
#  'ENSVKKG00000004183': 'ASPDH',
#  'ENSVKKG00000003256': 'ASPH',
#  'ENSVKKG00000005148': 'ASPM',
#  'ENSVKKG00000006683': 'ASPN',
#  'ENSVKKG00000004750': 'ASPSCR1',
#  'ENSVKKG00000018732': 'ASRGL1',
#  'ENSVKKG00000005095': 'ASS1',
#  'ENSVKKG00000018031': 'ASTE1',
#  'ENSVKKG00000001167': 'ASTL',
#  'ENSVKKG00000011994': 'ASTN1',
#  'ENSVKKG00000017205': 'ASTN2',
#  'ENSVKKG00000018429': 'ASUN',
#  'ENSVKKG00000010760': 'ASXL1',
#  'ENSVKKG00000008507': 'ASXL2',
#  'ENSVKKG00000006426': 'ASXL3',
#  'ENSVKKG00000014890': 'ASZ1',
#  'ENSVKKG00000004756': 'ATAD1',
#  'ENSVKKG00000000118': 'ATAD2',
#  'ENSVKKG00000010699': 'ATAD2B',
#  'ENSVKKG00000014101': 'ATAD3A',
#  'ENSVKKG00000001777': 'ATAD5',
#  'ENSVKKG00000008386': 'ATCAY',
#  'ENSVKKG00000005822': 'ATE1',
#  'ENSVKKG00000005593': 'ATF1',
#  'ENSVKKG00000001956': 'ATF2',
#  'ENSVKKG00000000008': 'ATF3',
#  'ENSVKKG00000016454': 'ATF4',
#  'ENSVKKG00000012190': 'ATF6',
#  'ENSVKKG00000004348': 'ATF7',
#  'ENSVKKG00000009934': 'ATF7IP',
#  'ENSVKKG00000010077': 'ATG10',
#  'ENSVKKG00000005441': 'ATG101',
#  'ENSVKKG00000015213': 'ATG12',
#  'ENSVKKG00000011995': 'ATG13',
#  'ENSVKKG00000001597': 'ATG14',
#  'ENSVKKG00000013906': 'ATG16L1',
#  'ENSVKKG00000003610': 'ATG2B',
#  'ENSVKKG00000017285': 'ATG3',
#  'ENSVKKG00000010050': 'ATG4A',
#  'ENSVKKG00000010889': 'ATG4B',
#  'ENSVKKG00000012142': 'ATG4C',
#  'ENSVKKG00000000198': 'ATG5',
#  'ENSVKKG00000006758': 'ATG7',
#  'ENSVKKG00000000950': 'ATG9A',
#  'ENSVKKG00000000381': 'ATHL1',
#  'ENSVKKG00000018422': 'ATIC',
#  'ENSVKKG00000006191': 'ATL1',
#  'ENSVKKG00000014346': 'ATL2',
#  'ENSVKKG00000001317': 'ATM',
#  'ENSVKKG00000014210': 'ATMIN',
#  'ENSVKKG00000016247': 'ATOH7',
#  'ENSVKKG00000012901': 'ATOH8',
#  'ENSVKKG00000007927': 'ATOX1',
#  'ENSVKKG00000012837': 'ATP10A',
#  'ENSVKKG00000004964': 'ATP10D',
#  'ENSVKKG00000011533': 'ATP11A',
#  'ENSVKKG00000012330': 'ATP11B',
#  'ENSVKKG00000003141': 'ATP11C',
#  'ENSVKKG00000015465': 'ATP12A',
#  'ENSVKKG00000009047': 'ATP13A1',
#  'ENSVKKG00000010441': 'ATP1A1',
#  'ENSVKKG00000017278': 'ATP1B1',
#  'ENSVKKG00000018703': 'ATP1B2',
#  'ENSVKKG00000011376': 'ATP1B3',
#  'ENSVKKG00000011919': 'ATP1B4',
#  'ENSVKKG00000015523': 'ATP2A2',
#  'ENSVKKG00000014494': 'ATP2A3',
#  'ENSVKKG00000016618': 'ATP2B1',
#  'ENSVKKG00000006693': 'ATP2B2',
#  'ENSVKKG00000010222': 'ATP2B4',
#  'ENSVKKG00000018029': 'ATP2C1',
#  'ENSVKKG00000009866': 'ATP4B',
#  'ENSVKKG00000010704': 'ATP5A1',
#  'ENSVKKG00000005436': 'ATP5B',
#  'ENSVKKG00000009645': 'ATP5C1',
#  'ENSVKKG00000012848': 'ATP5D',
#  'ENSVKKG00000004019': 'ATP5E',
#  'ENSVKKG00000009806': 'ATP5F1',
#  'ENSVKKG00000002551': 'ATP5G1',
#  'ENSVKKG00000013561': 'ATP5H',
#  'ENSVKKG00000001876': 'ATP5I',
#  'ENSVKKG00000010494': 'ATP5J',
#  'ENSVKKG00000006844': 'ATP5J2',
#  'ENSVKKG00000009017': 'ATP5L',
#  'ENSVKKG00000016004': 'ATP5O',
#  'ENSVKKG00000006242': 'ATP5S',
#  'ENSVKKG00000003079': 'ATP6',
#  'ENSVKKG00000010094': 'ATP6AP1L',
#  'ENSVKKG00000001007': 'ATP6AP2',
#  'ENSVKKG00000009597': 'ATP6V0A1',
#  'ENSVKKG00000013418': 'ATP6V0A2',
#  'ENSVKKG00000002180': 'ATP6V0A4',
#  'ENSVKKG00000003655': 'ATP6V0B',
#  'ENSVKKG00000008453': 'ATP6V0C',
#  'ENSVKKG00000013707': 'ATP6V0D1',
#  'ENSVKKG00000000108': 'ATP6V0D2',
#  'ENSVKKG00000011691': 'ATP6V0E1',
#  'ENSVKKG00000013369': 'ATP6V0E2',
#  'ENSVKKG00000018294': 'ATP6V1B1',
#  'ENSVKKG00000015409': 'ATP6V1B2',
#  'ENSVKKG00000014310': 'ATP6V1C1',
#  'ENSVKKG00000005764': 'ATP6V1C2',
#  'ENSVKKG00000018457': 'ATP6V1D',
#  'ENSVKKG00000016742': 'ATP6V1E1',
#  'ENSVKKG00000016567': 'ATP6V1G1',
#  'ENSVKKG00000004970': 'ATP6V1G3',
#  'ENSVKKG00000000686': 'ATP6V1H',
#  'ENSVKKG00000009626': 'ATP7A',
#  'ENSVKKG00000009228': 'ATP7B',
#  'ENSVKKG00000010224': 'ATP8A1',
#  'ENSVKKG00000007048': 'ATP8A2',
#  'ENSVKKG00000011432': 'ATP8B1',
#  'ENSVKKG00000010345': 'ATP8B2',
#  'ENSVKKG00000008132': 'ATP8B3',
#  'ENSVKKG00000016570': 'ATP8B5',
#  'ENSVKKG00000013570': 'ATP9A',
#  'ENSVKKG00000006531': 'ATP9B',
#  'ENSVKKG00000002558': 'ATPAF1',
#  'ENSVKKG00000017926': 'ATPAF2',
#  'ENSVKKG00000007739': 'ATRAID',
#  'ENSVKKG00000006662': 'ATRIP',
#  'ENSVKKG00000018326': 'ATRN',
#  'ENSVKKG00000005531': 'ATRNL1',
#  'ENSVKKG00000001614': 'ATRX',
#  'ENSVKKG00000010612': 'ATXN1',
#  'ENSVKKG00000017736': 'ATXN10',
#  'ENSVKKG00000014581': 'ATXN1L',
#  'ENSVKKG00000002222': 'ATXN2',
#  'ENSVKKG00000000095': 'ATXN3',
#  'ENSVKKG00000013722': 'ATXN7',
#  'ENSVKKG00000018548': 'ATXN7L1',
#  'ENSVKKG00000016324': 'ATXN7L3',
#  'ENSVKKG00000008416': 'AUH',
#  'ENSVKKG00000012592': 'AUP1',
#  'ENSVKKG00000013511': 'AURKA',
#  'ENSVKKG00000014095': 'AURKAIP1',
#  'ENSVKKG00000016834': 'AUTS2',
#  'ENSVKKG00000012171': 'AVEN',
#  'ENSVKKG00000007796': 'AVL9',
#  'ENSVKKG00000018347': 'AVP',
#  'ENSVKKG00000014128': 'AVPR1A',
#  'ENSVKKG00000008835': 'AVPR1B',
#  'ENSVKKG00000010013': 'AWAT2',
#  'ENSVKKG00000008975': 'AXDND1',
#  'ENSVKKG00000000432': 'AXIN1',
#  'ENSVKKG00000007822': 'AXIN2',
#  'ENSVKKG00000005586': 'AZI2',
#  'ENSVKKG00000014308': 'AZIN1',
#  'ENSVKKG00000008040': 'AZIN2',
#  'ENSVKKG00000007213': 'B2M',
#  'ENSVKKG00000000586': 'B3GALNT1',
#  'ENSVKKG00000017323': 'B3GALNT2',
#  'ENSVKKG00000003325': 'B3GALT2',
#  'ENSVKKG00000015399': 'B3GALT5',
#  'ENSVKKG00000006715': 'B3GALTL',
#  'ENSVKKG00000015470': 'B3GAT1',
#  'ENSVKKG00000018729': 'B3GAT2',
#  'ENSVKKG00000007994': 'B3GNT2',
#  'ENSVKKG00000015895': 'B3GNT3',
#  'ENSVKKG00000015571': 'B3GNT4',
#  'ENSVKKG00000012323': 'B3GNT5',
#  'ENSVKKG00000003556': 'B3GNT7',
#  'ENSVKKG00000002951': 'B3GNT9',
#  'ENSVKKG00000001725': 'B3GNTL1',
#  'ENSVKKG00000018584': 'B4GALNT3',
#  'ENSVKKG00000007217': 'B4GALT1',
#  'ENSVKKG00000003649': 'B4GALT2',
#  'ENSVKKG00000000987': 'B4GALT4',
#  'ENSVKKG00000003502': 'B4GALT5',
#  'ENSVKKG00000006469': 'B4GALT6',
#  'ENSVKKG00000015246': 'B4GALT7',
#  'ENSVKKG00000017904': 'B9D1',
#  'ENSVKKG00000012769': 'B9D2',
#  'ENSVKKG00000014314': 'BAALC',
#  'ENSVKKG00000015737': 'BABAM1',
#  'ENSVKKG00000003724': 'BACE1',
#  'ENSVKKG00000015394': 'BACE2',
#  'ENSVKKG00000010464': 'BACH1',
#  'ENSVKKG00000008935': 'BACH2',
#  'ENSVKKG00000007507': 'ZNF830',
#  'ENSVKKG00000018711': 'BAG2',
#  'ENSVKKG00000005702': 'BAG3',
#  'ENSVKKG00000015093': 'BAG4',
#  'ENSVKKG00000005421': 'BAG5',
#  'ENSVKKG00000016391': 'BAHCC1',
#  'ENSVKKG00000011932': 'BAHD1',
#  'ENSVKKG00000006133': 'BAI1',
#  'ENSVKKG00000009554': 'BAI2',
#  'ENSVKKG00000018721': 'BAI3',
#  'ENSVKKG00000016400': 'BAIAP2',
#  'ENSVKKG00000007873': 'BAIAP2L1',
#  'ENSVKKG00000017973': 'BAIAP2L2',
#  'ENSVKKG00000007155': 'BAK1',
#  'ENSVKKG00000017841': 'BAMBI',
#  'ENSVKKG00000009847': 'BANK1',
#  'ENSVKKG00000014122': 'BANP',
#  'ENSVKKG00000015172': 'BAP1',
#  'ENSVKKG00000018424': 'BARD1',
#  'ENSVKKG00000007095': 'BARHL2',
#  'ENSVKKG00000009249': 'BARX1',
#  'ENSVKKG00000002153': 'BARX2',
#  'ENSVKKG00000005512': 'BASP1',
#  'ENSVKKG00000015818': 'BATF',
#  'ENSVKKG00000000009': 'BATF3',
#  'ENSVKKG00000012492': 'BAZ1A',
#  'ENSVKKG00000003674': 'BAZ1B',
#  'ENSVKKG00000005427': 'BAZ2A',
#  'ENSVKKG00000003889': 'BBIP1',
#  'ENSVKKG00000001859': 'BBOX1',
#  'ENSVKKG00000004068': 'BBS10',
#  'ENSVKKG00000007615': 'BBS12',
#  'ENSVKKG00000003740': 'BBS2',
#  'ENSVKKG00000007097': 'BBS4',
#  'ENSVKKG00000018247': 'BBS5',
#  'ENSVKKG00000005661': 'BBS7',
#  'ENSVKKG00000007778': 'BBS9',
#  'ENSVKKG00000017218': 'BBX',
#  'ENSVKKG00000001935': 'BC067074',
#  'ENSVKKG00000004413': 'BCAN',
#  'ENSVKKG00000018558': 'BCAP29',
#  'ENSVKKG00000005066': 'BCAR1',
#  'ENSVKKG00000002171': 'BCAR3',
#  'ENSVKKG00000013521': 'BCAS1',
#  'ENSVKKG00000013087': 'BCAS2',
#  'ENSVKKG00000010719': 'BCAS3',
#  'ENSVKKG00000013582': 'BCAT1',
#  'ENSVKKG00000008248': 'BCCIP',
#  'ENSVKKG00000000322': 'BCHE',
#  'ENSVKKG00000012774': 'BCKDHA',
#  'ENSVKKG00000018760': 'BCKDHB',
#  'ENSVKKG00000006972': 'BCL10',
#  'ENSVKKG00000011128': 'BCL11A',
#  'ENSVKKG00000004468': 'BCL11B',
#  'ENSVKKG00000010303': 'KDSR',
#  'ENSVKKG00000017755': 'BCL2A1',
#  'ENSVKKG00000011715': 'BCL2L1',
#  ...}

# %%
adata.var
# Out:
#                               gene_ids    feature_types
# LPGAT1              ENSVKKG00000000002  Gene Expression
# INTS7               ENSVKKG00000000003  Gene Expression
# DTL                 ENSVKKG00000000004  Gene Expression
# PPP2R5A             ENSVKKG00000000005  Gene Expression
# PACC1               ENSVKKG00000000006  Gene Expression
# ...                                ...              ...
# ENSVKKG00000007640  ENSVKKG00000007640  Gene Expression
# ENSVKKG00000006099  ENSVKKG00000006099  Gene Expression
# ENSVKKG00000006118  ENSVKKG00000006118  Gene Expression
# ENSVKKG00000006119  ENSVKKG00000006119  Gene Expression
# ENSVKKG00000006120  ENSVKKG00000006120  Gene Expression
#
# [18772 rows x 2 columns]

# %%
adata.var.set_index('gene_ids', inplace=True) 
adata.var['gene_ids'] = adata.var.index

adata.var.drop(columns='feature_types', inplace=True)
adata.var.rename(genes_dict, inplace=True)

# %%
adata.var
# Out:
#                               gene_ids
# gene_ids
# LPGAT1              ENSVKKG00000000002
# INTS7               ENSVKKG00000000003
# DTL                 ENSVKKG00000000004
# PPP2R5A             ENSVKKG00000000005
# TMEM206             ENSVKKG00000000006
# ...                                ...
# ENSVKKG00000007640  ENSVKKG00000007640
# VMN2R65             ENSVKKG00000006099
# IGLV3-10            ENSVKKG00000006118
# IGLV5-45            ENSVKKG00000006119
# IGLV5-45            ENSVKKG00000006120
#
# [18772 rows x 1 columns]

# %%
# This code identifies duplicate variable names, iterates through them, and adds suffixes to make them unique from the first occurrence.
# Please make sure to replace adata with your actual AnnData object.

# Keep in mind that Scanpy's functionality may evolve, so it's a good idea to check the documentation or release notes
# for any updates related to making variable names unique starting from the first occurrence in more recent versions of Scanpy.

# Get a Series of variable (gene) names
var_names_series = pd.Series(adata.var_names)

# Identify duplicate variable names
duplicate_var_names = var_names_series[var_names_series.duplicated(keep='first')]

# Iterate through duplicates and add suffixes to make them unique from the first occurrence
for duplicate_name in duplicate_var_names:
    count = 1
    indices = var_names_series[var_names_series == duplicate_name].index
    for idx in indices:
        var_names_series[idx] = f'{duplicate_name}_{count}'
        count += 1

# Update the AnnData object with the unique variable names
adata.var_names = var_names_series.values

adata.var_names
# Out:
# Index(['LPGAT1', 'INTS7', 'DTL', 'PPP2R5A', 'TMEM206', 'NENF', 'ATF3', 'BATF3',
#        'NSL1', 'TATDN3_1',
#        ...
#        'ENSVKKG00000007402', 'ENSVKKG00000003146', 'ENSVKKG00000006769',
#        'FTH1_2', 'PAOX', 'ENSVKKG00000007640', 'VMN2R65_100', 'IGLV3-10_2',
#        'IGLV5-45_3', 'IGLV5-45_4'],
#       dtype='object', length=18772)

# %% [markdown]
# ## Genes and cells filtration

# %% [markdown]
# ### Highly expressed genes ( = top 20 genes)

# %%
sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
sc.pp.filter_cells(adata, min_genes=100) 
sc.pp.filter_genes(adata, min_cells=3)
print(adata.shape)
# Out:
# filtered out 2 cells that have less than 100 genes expressed
# filtered out 5071 genes that are detected in less than 3 cells
# (29147, 13701)

# %% [markdown]
# ### Mitochondrial QC and general measures
# Check if genes are annotated as mt by running:
# - GENES= list(adata.var.index[adata.var.index.str.startswith('mt-'.upper())])
# - GENES
#
# In case the genes are not annotated as 'MT-'' (Like in bats), run:
#
# - dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2'...etc}
# - adata.var.rename(dict_replace, inplace = True)

# %%
dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2','COX3':'MT-COX3','ND1':'MT-ND1-1','ND1':'MT-ND1-2','ND2':'MT-ND2',
                'ND3':'MT-ND3','ND4':'MT-ND4','ND5':'MT-ND5','ND6':'MT-ND6','ND4L-1':'MT-ND4L','ATP6':'MT-ATP6','ATP8':'MT-ATP8',
                'CYTB':'MT-CYTB'}
adata.var.rename(dict_replace, inplace=True)
# ONLY MT-ATP6, MT-ND1, MT-ND4L

# %%
adata.var['MT'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'MT'
sc.pp.calculate_qc_metrics(adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True)

# %% [markdown]
# ### Scatter plots of QC metrics

# %%
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts', color='treatment')
sc.pl.scatter(adata, x='total_counts', y='pct_counts_MT', color='treatment')
sc.pl.scatter(adata, x='total_counts', y='n_genes', color='treatment', save=True)
# Out:
# WARNING: saving figure to file figures\scatter.pdf

# %%
adata = adata[adata.obs.pct_counts_MT < 20] 
adata = adata[adata.obs.total_counts < 5000, :] # If filtering outliers (<0.1% of cells)

# %% [markdown]
# ## Doublet analysis and filtering

# %%
import scrublet as scr

def scrub(adatas, adata, adata_names):  # based on raw individual samples. 
    print('Before scrublet: ', adata.shape[0])
    doub_index = []
    barcodes = []
    for data,name in zip(adatas, adata_names):
        data.raw = data
        sc.pp.normalize_total(data, target_sum=1e4)
        sc.pp.log1p(data)
        scrub = scr.Scrublet(data.raw.X)
        data.obs['doublet_scores'], data.obs['predicted_doublets'] = scrub.scrub_doublets()
        scrub.plot_histogram()
        print('Doublets' + name + ' :', data.obs[data.obs['doublet_scores'] > 0.25].shape[0])
        barcodes = data.obs[data.obs['doublet_scores'] < 0.25].index.to_list()
        for barcode in barcodes:
            doub_index.append(barcode + '-' + name)

    adata = adata[adata.obs.index.isin(doub_index)]
    print('After scrublet: ', adata.shape[0])
    return adata

# %%
adata = scrub(adatas, adata, data_names)
# Out:
# Before scrublet:  21122
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.39
# Detected doublet rate = 1.8%
# Estimated detectable doublet fraction = 59.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.0%
# Elapsed time: 7.1 seconds
# Doubletscontrol : 286
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 1.3%
# Estimated detectable doublet fraction = 58.4%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 2.3%
# Elapsed time: 5.1 seconds
# Doubletslf : 239
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.37
# Detected doublet rate = 1.9%
# Estimated detectable doublet fraction = 53.0%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 3.6%
# Elapsed time: 5.5 seconds
# Doubletslps : 227
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.42
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 57.5%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 2.7%
# Elapsed time: 5.2 seconds
# Doubletspic : 314
# After scrublet:  20470

# %% [markdown]
# ## Cell cycle scoring
# download Cell cycle txt: https://github.com/scverse/scanpy_usage/blob/master/180209_cell_cycle/data/regev_lab_cell_cycle_genes.txt

# %%
cell_cycle_genes = [x.strip() for x in open(r'/Code/data/single_cell/animals/regev_lab_cell_cycle_genes.txt')]

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]
s_genes = [x for x in s_genes if x in adata.var_names]
g2m_genes = [x for x in g2m_genes if x in adata.var_names]

# %%
adata.var_names
# Out:
# Index(['LPGAT1', 'INTS7', 'DTL', 'PPP2R5A', 'TMEM206', 'NENF', 'ATF3', 'BATF3',
#        'NSL1', 'TATDN3_1',
#        ...
#        'SMC2_2', 'C19ORF54', 'ITPKC', 'ENSVKKG00000007401',
#        'ENSVKKG00000003146', 'ENSVKKG00000006769', 'PAOX',
#        'ENSVKKG00000007640', 'IGLV5-45_3', 'IGLV5-45_4'],
#       dtype='object', length=13701)

# %%
g2m_genes
# Out:
# ['HMGB2',
#  'CDK1',
#  'UBE2C',
#  'BIRC5',
#  'TPX2',
#  'NDC80',
#  'CKS2',
#  'NUF2',
#  'CKS1B',
#  'TMPO',
#  'FAM64A',
#  'SMC4',
#  'CCNB2',
#  'CKAP2',
#  'AURKB',
#  'BUB1',
#  'KIF11',
#  'ANP32E',
#  'TUBB4B',
#  'KIF20B',
#  'CDCA3',
#  'HN1',
#  'CDC20',
#  'KIF2C',
#  'RANGAP1',
#  'NCAPD2',
#  'CDCA8',
#  'ECT2',
#  'KIF23',
#  'HMMR',
#  'AURKA',
#  'ANLN',
#  'LBR',
#  'CTCF',
#  'NEK2',
#  'G2E3',
#  'GAS2L3',
#  'CBX5',
#  'CENPA']

# %%
matching_values = adata.var_names.isin(cell_cycle_genes)

matching_values
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
cell_cycle_adata = adata.copy()

sc.pp.normalize_per_cell(cell_cycle_adata, counts_per_cell_after=1e4)
sc.pp.log1p(cell_cycle_adata)
sc.pp.scale(cell_cycle_adata)
sc.tl.score_genes_cell_cycle(cell_cycle_adata, s_genes=s_genes, g2m_genes=g2m_genes)
adata_cc_genes = cell_cycle_adata[:, cell_cycle_genes].copy()
sc.tl.pca(adata_cc_genes)
sc.pl.pca_scatter(adata_cc_genes, color='phase', save=True)
adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()
adata.obs['G2M_score'] = cell_cycle_adata.obs['G2M_score'].copy()
adata.obs['phase'] = cell_cycle_adata.obs['phase'].copy()
# Out:
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# calculating cell cycle phase
# computing score 'S_score'
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     699 total control genes are used. (0:00:01)
# computing score 'G2M_score'
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     737 total control genes are used. (0:00:01)
# -->     'phase', cell cycle phase (adata.obs)
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
#     and added
#     'X_pca', the PCA coordinates (adata.obs)
#     'PC1', 'PC2', ..., the loadings (adata.var)
#     'pca_variance', the variance / eigenvalues (adata.uns)
#     'pca_variance_ratio', the variance ratio (adata.uns)
# WARNING: saving figure to file figures\pca.pdf
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_15072\1917813240.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 20470 × 13701
#     obs: 'treatment', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_MT', 'pct_counts_MT', 'S_score', 'G2M_score', 'phase'
#     var: 'gene_ids', 'n_cells', 'MT', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'treatment_colors'

# %% [markdown]
# ## Saving adata

# %%
adata.write(r'/Code/data/single_cell/animals/komodo/komodo_achinoam/''komodo_achinoam_after_qc.h5ad')

# %% [markdown]
# ## Preparing files to be opened in R studio

# %%
# # Preparing files to be opened in R studio

# matrix_dense = adata.X.toarray()

# # Create a DataFrame from the dense array with observation names as index and variable names as columns
# matrix_df = pd.DataFrame(matrix_dense, index=adata.obs_names, columns=adata.var_names)

# # Save the DataFrame to a CSV file
# matrix_df.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''matrix_new.csv')
# print('matrix file is transformed')

# #save obs as scv
# adata.obs.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''obs_new.csv')
# print('obs file is transformed')

# # Save variable data to a CSV file
# adata.var.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''var_new.csv')
# print('var file is transformed')
