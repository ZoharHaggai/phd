# %% [markdown]
# # QC for turtle 1 (Stephan) - painted turtle genome

# %% [markdown]
# ## Imports

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import os
import bbknn
from pathlib import Path

# %% [markdown]
# ## Single cell settings

# %%
sc.settings.verbosity = 4
sc.settings.set_figure_params(80)
sc.settings._file_format_figs = 'pdf'
sc.settings.savefigs = False
use_first_n_samples = 0
full_sparse = False
# Out:
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_25140\3661074169.py:2: FutureWarning: The specified parameters ('scanpy',) are no longer positional. Please specify them like `scanpy=80`
#   sc.settings.set_figure_params(80)

# %% [markdown]
# ## QC workflow

# %%
adatas = []
data_names = ['control','lps','pic']    #No lf treatment for turtle_1
main_path = '/Code/data/single_cell/animals/turtle/turtle_1/'
paths = ['\\control','\\lps','\\pic']    #...etc - Folders with matrix, features and barcodes gz files.
for path in paths:
    adata = sc.read_10x_mtx(main_path + path, var_names='gene_symbols', cache=False)    # use gene symbols for the variable names (variables-axis index)
    sc.logging.print_memory_usage()
    print(adata.shape)
    adatas.append(adata)
# Out:
#     reading \Code\data\single_cell\animals\turtle\turtle_1\control\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.29 GB, difference +0.29 GB
# (4045, 26817)
#     reading \Code\data\single_cell\animals\turtle\turtle_1\lps\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.33 GB, difference +0.03 GB
# (3652, 26817)
#     reading \Code\data\single_cell\animals\turtle\turtle_1\pic\matrix.mtx.gz
# --> This might be very slow. Consider passing `cache=True`, which enables much faster reading from a cache file.
# Memory usage: current 0.33 GB, difference +0.01 GB
# (4681, 26817)

# %%
# os.getcwd()

# %%
adata = adatas[0].concatenate(adatas[1:], batch_categories=data_names, batch_key='treatment')

# adata
# Out:
# c:\Python\Python310\lib\site-packages\anndata\_core\anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(

# %%
genes = pd.read_csv('/Code/data/single_cell/animals/eggnog_croc_chic_komo_turt.csv')
genes.dropna(subset = ['turtle gene id'], inplace=True)

genes_dict = dict(zip(genes['turtle gene id'].astype('str'), genes.eggnog_name.astype('str')))

dict_multi, dict_uni = {}, {}
for d in genes_dict:
    if len(d.split(',')) != 1:
        dict_multi[d] = genes_dict[d]
    else:
        dict_uni[d] =  genes_dict[d]

multi_result_dict = {}

for key_str, value in dict_multi.items():
    # Convert the string key to a set
    key_set = set(key_str.strip("{}").replace("'", "").split(", "))

    # Iterate through the elements in the set and create individual keys
    for element in key_set:
        multi_result_dict[element] = value

genes_dict = {**dict_uni, **multi_result_dict}

genes_dict
# Out:
# {'ENSCPBG00000026464': 'A1CF',
#  'ENSCPBG00000025172': 'A4GALT',
#  'ENSCPBG00000001788': 'AAAS',
#  'ENSCPBG00000024879': 'AACS',
#  'ENSCPBG00000018813': 'AADAC',
#  'ENSCPBG00000005459': 'AAED1',
#  'ENSCPBG00000025560': 'AAGAB',
#  'ENSCPBG00000027793': 'AAMDC',
#  'ENSCPBG00000013283': 'AAMP',
#  'ENSCPBG00000028003': 'AANAT',
#  'ENSCPBG00000018203': 'AAR2',
#  'ENSCPBG00000002995': 'AARS',
#  'ENSCPBG00000025329': 'AARS2',
#  'ENSCPBG00000016295': 'AARSD1',
#  'ENSCPBG00000025116': 'AASDH',
#  'ENSCPBG00000000192': 'AASDHPPT',
#  'ENSCPBG00000008417': 'AASS',
#  'ENSCPBG00000009608': 'AATF',
#  'ENSCPBG00000010476': 'AATK',
#  'ENSCPBG00000026638': 'ABAT',
#  'ENSCPBG00000020497': 'ABCA1',
#  'ENSCPBG00000015417': 'ABCA12',
#  'ENSCPBG00000016499': 'ABCA13',
#  'ENSCPBG00000010737': 'ABCA2',
#  'ENSCPBG00000000183': 'ABCA3',
#  'ENSCPBG00000017387': 'ABCA4',
#  'ENSCPBG00000010213': 'ABCA5',
#  'ENSCPBG00000021237': 'ABCB1',
#  'ENSCPBG00000006163': 'ABCB10',
#  'ENSCPBG00000006998': 'ABCB11',
#  'ENSCPBG00000014879': 'ABCB7',
#  'ENSCPBG00000012251': 'ABCB8',
#  'ENSCPBG00000025979': 'ABCB9',
#  'ENSCPBG00000020208': 'ABCC1',
#  'ENSCPBG00000025164': 'ABCC10',
#  'ENSCPBG00000028341': 'ABCC13',
#  'ENSCPBG00000012273': 'ABCC2',
#  'ENSCPBG00000028200': 'ABCC3',
#  'ENSCPBG00000023494': 'ABCC4',
#  'ENSCPBG00000015585': 'ABCC5',
#  'ENSCPBG00000019854': 'ABCC6',
#  'ENSCPBG00000017576': 'ABCC8',
#  'ENSCPBG00000009242': 'ABCC9',
#  'ENSCPBG00000010664': 'ABCD2',
#  'ENSCPBG00000017384': 'ABCD3',
#  'ENSCPBG00000026224': 'ABCD4',
#  'ENSCPBG00000027506': 'ABCE1',
#  'ENSCPBG00000012186': 'ABCF2',
#  'ENSCPBG00000015581': 'ABCF3',
#  'ENSCPBG00000012934': 'ABCG1',
#  'ENSCPBG00000007843': 'ABCG4',
#  'ENSCPBG00000005404': 'ABCG5',
#  'ENSCPBG00000005417': 'ABCG8',
#  'ENSCPBG00000015894': 'ABHD11',
#  'ENSCPBG00000017703': 'ABHD12',
#  'ENSCPBG00000021123': 'ABHD12B',
#  'ENSCPBG00000016545': 'ABHD14A',
#  'ENSCPBG00000016548': 'ABHD14B',
#  'ENSCPBG00000018468': 'ABHD17A',
#  'ENSCPBG00000020103': 'ABHD17B',
#  'ENSCPBG00000007666': 'ABHD17C',
#  'ENSCPBG00000017685': 'ABHD2',
#  'ENSCPBG00000027604': 'ABHD3',
#  'ENSCPBG00000022755': 'ABHD5',
#  'ENSCPBG00000014251': 'ABHD6',
#  'ENSCPBG00000012422': 'ABHD8',
#  'ENSCPBG00000015830': 'ABI1',
#  'ENSCPBG00000008865': 'ABI2',
#  'ENSCPBG00000027308': 'ABI3',
#  'ENSCPBG00000004109': 'ABI3BP',
#  'ENSCPBG00000022624': 'ABL1',
#  'ENSCPBG00000014503': 'ABL2',
#  'ENSCPBG00000003143': 'ABLIM1',
#  'ENSCPBG00000023275': 'ABLIM2',
#  'ENSCPBG00000007739': 'ABLIM3',
#  'ENSCPBG00000020035': 'ABR',
#  'ENSCPBG00000000685': 'ABRA',
#  'ENSCPBG00000017193': 'ABRACL',
#  'ENSCPBG00000014379': 'ABTB1',
#  'ENSCPBG00000018494': 'ACAA1',
#  'ENSCPBG00000025630': 'ACAA2',
#  'ENSCPBG00000009636': 'ACACA',
#  'ENSCPBG00000008093': 'ACACB',
#  'ENSCPBG00000023029': 'ACAD11',
#  'ENSCPBG00000017781': 'ACAD8',
#  'ENSCPBG00000001155': 'ACAD9',
#  'ENSCPBG00000025491': 'ACADL',
#  'ENSCPBG00000017035': 'ACADM',
#  'ENSCPBG00000011308': 'ACADS',
#  'ENSCPBG00000028097': 'ACADSB',
#  'ENSCPBG00000017775': 'ACAN',
#  'ENSCPBG00000022194': 'ACAP1',
#  'ENSCPBG00000022283': 'ACAP3',
#  'ENSCPBG00000018563': 'ACAT1',
#  'ENSCPBG00000004088': 'ACAT2',
#  'ENSCPBG00000011972': 'ACBD3',
#  'ENSCPBG00000008864': 'ACBD4',
#  'ENSCPBG00000015832': 'ACBD5',
#  'ENSCPBG00000025770': 'ACBD6',
#  'ENSCPBG00000012580': 'ACCS',
#  'ENSCPBG00000026990': 'ACE',
#  'ENSCPBG00000012731': 'ACE2',
#  'ENSCPBG00000011158': 'ACER1',
#  'ENSCPBG00000018962': 'ACER2',
#  'ENSCPBG00000027726': 'ACER3',
#  'ENSCPBG00000013012': 'ACHE',
#  'ENSCPBG00000026078': 'ACIN1',
#  'ENSCPBG00000003986': 'ACKR2',
#  'ENSCPBG00000022793': 'ACKR3',
#  'ENSCPBG00000023046': 'ACKR4',
#  'ENSCPBG00000006669': 'ACLY',
#  'ENSCPBG00000010217': 'ACMSD',
#  'ENSCPBG00000024400': 'ACN9',
#  'ENSCPBG00000008077': 'ACO1',
#  'ENSCPBG00000020545': 'ACO2',
#  'ENSCPBG00000003530': 'ACOT11',
#  'ENSCPBG00000010812': 'ACOT12',
#  'ENSCPBG00000006544': 'ACOT13',
#  'ENSCPBG00000010835': 'ACOT4',
#  'ENSCPBG00000016178': 'ACOT7',
#  'ENSCPBG00000027256': 'ACOT8',
#  'ENSCPBG00000006727': 'ACOT9',
#  'ENSCPBG00000028038': 'ACOX1',
#  'ENSCPBG00000003787': 'ACOX2',
#  'ENSCPBG00000024852': 'ACOX3',
#  'ENSCPBG00000021798': 'ACP1',
#  'ENSCPBG00000015503': 'ACP2',
#  'ENSCPBG00000023952': 'ACP5',
#  'ENSCPBG00000006216': 'ACP6',
#  'ENSCPBG00000022865': 'ACPP',
#  'ENSCPBG00000027712': 'ACRBP',
#  'ENSCPBG00000016565': 'ACRC',
#  'ENSCPBG00000024238': 'ACSBG1',
#  'ENSCPBG00000011150': 'ACSBG2',
#  'ENSCPBG00000028182': 'ACSF2',
#  'ENSCPBG00000023427': 'ACSF3',
#  'ENSCPBG00000008456': 'ACSL1',
#  'ENSCPBG00000019360': 'ACSL3',
#  'ENSCPBG00000000569': 'ACSL4',
#  'ENSCPBG00000005116': 'ACSL5',
#  'ENSCPBG00000025128': 'ACSL6',
#  'ENSCPBG00000019058': 'ACSM3',
#  'ENSCPBG00000018129': 'ACSM4',
#  'ENSCPBG00000018128': 'ACSM5',
#  'ENSCPBG00000019337': 'ACSS2',
#  'ENSCPBG00000000071': 'ACSS3',
#  'ENSCPBG00000006129': 'ACTA1',
#  'ENSCPBG00000026499': 'ACTA2',
#  'ENSCPBG00000003149': 'ACTG2',
#  'ENSCPBG00000016243': 'ACTL10',
#  'ENSCPBG00000026932': 'ACTL6A',
#  'ENSCPBG00000022244': 'ACTL6B',
#  'ENSCPBG00000021544': 'ACTN1',
#  'ENSCPBG00000004168': 'ACTN2',
#  'ENSCPBG00000018719': 'ACTN4',
#  'ENSCPBG00000024806': 'ACTR10',
#  'ENSCPBG00000003255': 'ACTR1A',
#  'ENSCPBG00000013248': 'ACTR2',
#  'ENSCPBG00000010170': 'ACTR3',
#  'ENSCPBG00000018243': 'ACTR3B',
#  'ENSCPBG00000018183': 'ACTR5',
#  'ENSCPBG00000004488': 'ACTR6',
#  'ENSCPBG00000021427': 'ACTR8',
#  'ENSCPBG00000026496': 'ACVR1',
#  'ENSCPBG00000019469': 'ACVR1B',
#  'ENSCPBG00000026513': 'ACVR1C',
#  'ENSCPBG00000025780': 'ACVR2A',
#  'ENSCPBG00000018300': 'ACVR2B',
#  'ENSCPBG00000019466': 'ACVRL1',
#  'ENSCPBG00000016540': 'ACY1',
#  'ENSCPBG00000026240': 'ACYP1',
#  'ENSCPBG00000024656': 'ADAD1',
#  'ENSCPBG00000010776': 'ADAL',
#  'ENSCPBG00000008918': 'ADAM11',
#  'ENSCPBG00000028042': 'ADAM12',
#  'ENSCPBG00000025629': 'ADAM15',
#  'ENSCPBG00000014063': 'ADAM17',
#  'ENSCPBG00000021249': 'ADAM22',
#  'ENSCPBG00000019586': 'ADAM23',
#  'ENSCPBG00000002623': 'ADAM28',
#  'ENSCPBG00000024521': 'ADAM33',
#  'ENSCPBG00000011615': 'ADAM8',
#  'ENSCPBG00000004827': 'ADAM9',
#  'ENSCPBG00000026815': 'ADAMTS1',
#  'ENSCPBG00000011174': 'ADAMTS10',
#  'ENSCPBG00000013170': 'ADAMTS12',
#  'ENSCPBG00000025909': 'ADAMTS14',
#  'ENSCPBG00000026857': 'ADAMTS15',
#  'ENSCPBG00000019583': 'ADAMTS17',
#  'ENSCPBG00000009520': 'ADAMTS18',
#  'ENSCPBG00000020290': 'ADAMTS19',
#  'ENSCPBG00000008971': 'ADAMTS2',
#  'ENSCPBG00000015412': 'ADAMTS20',
#  'ENSCPBG00000019552': 'ADAMTS3',
#  'ENSCPBG00000009246': 'ADAMTS4',
#  'ENSCPBG00000026837': 'ADAMTS6',
#  'ENSCPBG00000025373': 'ADAMTS7',
#  'ENSCPBG00000026860': 'ADAMTS8',
#  'ENSCPBG00000018927': 'ADAMTSL1',
#  'ENSCPBG00000017620': 'ADAMTSL3',
#  'ENSCPBG00000012355': 'ADAMTSL5',
#  'ENSCPBG00000004739': 'ADAP2',
#  'ENSCPBG00000024639': 'ADAR',
#  'ENSCPBG00000004191': 'ADARB1',
#  'ENSCPBG00000017055': 'ADARB2',
#  'ENSCPBG00000026967': 'ADAT1',
#  'ENSCPBG00000017163': 'ADAT2',
#  'ENSCPBG00000026334': 'ADCK1',
#  'ENSCPBG00000011871': 'ADCK2',
#  'ENSCPBG00000018907': 'ADCK5',
#  'ENSCPBG00000016626': 'ADCY1',
#  'ENSCPBG00000003662': 'ADCY10',
#  'ENSCPBG00000005301': 'ADCY2',
#  'ENSCPBG00000022281': 'ADCY3',
#  'ENSCPBG00000013781': 'ADCY5',
#  'ENSCPBG00000019978': 'ADCY6',
#  'ENSCPBG00000015953': 'ADCY7',
#  'ENSCPBG00000020454': 'ADCY8',
#  'ENSCPBG00000026366': 'ADCY9',
#  'ENSCPBG00000027547': 'ADCYAP1',
#  'ENSCPBG00000004400': 'ADCYAP1R1',
#  'ENSCPBG00000003740': 'ADD2',
#  'ENSCPBG00000012833': 'ADD3',
#  'ENSCPBG00000016665': 'ADGB',
#  'ENSCPBG00000016220': 'ADH5',
#  'ENSCPBG00000021371': 'ADHFE1',
#  'ENSCPBG00000021621': 'ADI1',
#  'ENSCPBG00000019218': 'ADIPOQ',
#  'ENSCPBG00000012604': 'ADIPOR1',
#  'ENSCPBG00000027429': 'ADIPOR2',
#  'ENSCPBG00000012703': 'ADK',
#  'ENSCPBG00000023639': 'ADM',
#  'ENSCPBG00000017074': 'ADMP',
#  'ENSCPBG00000015610': 'ADNP',
#  'ENSCPBG00000006445': 'ADNP2',
#  'ENSCPBG00000010079': 'ADORA1',
#  'ENSCPBG00000002134': 'ADORA2A',
#  'ENSCPBG00000020029': 'ADORA2B',
#  'ENSCPBG00000021261': 'ADORA3',
#  'ENSCPBG00000006389': 'ADPGK',
#  'ENSCPBG00000019806': 'ADPRHL1',
#  'ENSCPBG00000018548': 'ADPRHL2',
#  'ENSCPBG00000027762': 'ADPRM',
#  'ENSCPBG00000002911': 'ADRA1A',
#  'ENSCPBG00000008010': 'ADRA1B',
#  'ENSCPBG00000024606': 'ADRA1D',
#  'ENSCPBG00000012851': 'ADRA2A',
#  'ENSCPBG00000010972': 'ADRA2B',
#  'ENSCPBG00000025056': 'ADRA2C',
#  'ENSCPBG00000004231': 'ADRB1',
#  'ENSCPBG00000007688': 'ADRB2',
#  'ENSCPBG00000005773': 'ADRB3',
#  'ENSCPBG00000000461': 'ADRBK1',
#  'ENSCPBG00000021586': 'ADRBK2',
#  'ENSCPBG00000027092': 'ADRM1',
#  'ENSCPBG00000022923': 'ADSL',
#  'ENSCPBG00000008911': 'ADSS',
#  'ENSCPBG00000020185': 'ADSSL1',
#  'ENSCPBG00000001383': 'AEBP1',
#  'ENSCPBG00000022682': 'AEBP2',
#  'ENSCPBG00000017884': 'ISG20',
#  'ENSCPBG00000010838': 'AES',
#  'ENSCPBG00000023272': 'AFAP1',
#  'ENSCPBG00000007799': 'AFAP1L1',
#  'ENSCPBG00000003653': 'AFAP1L2',
#  'ENSCPBG00000005382': 'AFF1',
#  'ENSCPBG00000020831': 'AFF2',
#  'ENSCPBG00000007277': 'AFF3',
#  'ENSCPBG00000011375': 'AFMID',
#  'ENSCPBG00000013222': 'AFTPH',
#  'ENSCPBG00000003373': 'AGA',
#  'ENSCPBG00000023256': 'AGAP1',
#  'ENSCPBG00000012203': 'AGAP3',
#  'ENSCPBG00000017937': 'AGBL1',
#  'ENSCPBG00000005853': 'AGBL3',
#  'ENSCPBG00000005761': 'AGBL5',
#  'ENSCPBG00000019516': 'AGFG1',
#  'ENSCPBG00000001764': 'AGGF1',
#  'ENSCPBG00000011764': 'AGK',
#  'ENSCPBG00000026690': 'AGL',
#  'ENSCPBG00000021836': 'AGMO',
#  'ENSCPBG00000018594': 'AGO1',
#  'ENSCPBG00000019183': 'AGO2',
#  'ENSCPBG00000018583': 'AGO3',
#  'ENSCPBG00000018602': 'AGO4',
#  'ENSCPBG00000012266': 'AGPAT2',
#  'ENSCPBG00000018276': 'AGPAT3',
#  'ENSCPBG00000000721': 'AGPAT4',
#  'ENSCPBG00000022025': 'AGPAT5',
#  'ENSCPBG00000002848': 'AGPAT6',
#  'ENSCPBG00000007766': 'AGPAT9',
#  'ENSCPBG00000003348': 'AGPS',
#  'ENSCPBG00000021880': 'AGR2',
#  'ENSCPBG00000021881': 'AGR3',
#  'ENSCPBG00000022148': 'AGRN',
#  'ENSCPBG00000015629': 'AGRP',
#  'ENSCPBG00000006219': 'AGT',
#  'ENSCPBG00000005173': 'AGTPBP1',
#  'ENSCPBG00000011883': 'AGTR1',
#  'ENSCPBG00000016768': 'AGTR2',
#  'ENSCPBG00000021983': 'AGTRAP',
#  'ENSCPBG00000014445': 'AGXT',
#  'ENSCPBG00000021316': 'AGXT2',
#  'ENSCPBG00000017000': 'AHCTF1',
#  'ENSCPBG00000018709': 'AHCY',
#  'ENSCPBG00000001538': 'AHCYL1',
#  'ENSCPBG00000017527': 'AHCYL2',
#  'ENSCPBG00000024880': 'AHDC1',
#  'ENSCPBG00000017619': 'AHI1',
#  'ENSCPBG00000020396': 'AHNAK2',
#  'ENSCPBG00000021882': 'AHR',
#  'ENSCPBG00000016894': 'AHR-1',
#  'ENSCPBG00000001668': 'AHRR',
#  'ENSCPBG00000026319': 'AHSA1',
#  'ENSCPBG00000001309': 'AHSG',
#  'ENSCPBG00000014337': 'AICDA',
#  'ENSCPBG00000012444': 'AIDA',
#  'ENSCPBG00000012035': 'AIFM1',
#  'ENSCPBG00000025938': 'AIFM2',
#  'ENSCPBG00000017164': 'AIG1',
#  'ENSCPBG00000004238': 'AIM1',
#  'ENSCPBG00000025018': 'AIM1L',
#  'ENSCPBG00000004055': 'AIMP1',
#  'ENSCPBG00000019964': 'AIMP2',
#  'ENSCPBG00000015740': 'AIP',
#  'ENSCPBG00000019387': 'AJAP1',
#  'ENSCPBG00000025228': 'AK1',
#  'ENSCPBG00000010985': 'AK2',
#  'ENSCPBG00000025480': 'AK3',
#  'ENSCPBG00000001084': 'AK4',
#  'ENSCPBG00000017010': 'AK5',
#  'ENSCPBG00000010913': 'AK6',
#  'ENSCPBG00000024122': 'AK7',
#  'ENSCPBG00000018086': 'AK8',
#  'ENSCPBG00000006382': 'AK9',
#  'ENSCPBG00000010075': 'AKAP1',
#  'ENSCPBG00000015811': 'AKAP10',
#  'ENSCPBG00000013579': 'AKAP11',
#  'ENSCPBG00000016538': 'AKAP12',
#  'ENSCPBG00000017990': 'AKAP13',
#  'ENSCPBG00000020677': 'AKAP14',
#  'ENSCPBG00000009593': 'AKAP2',
#  'ENSCPBG00000022348': 'AKAP5',
#  'ENSCPBG00000026181': 'AKAP6',
#  'ENSCPBG00000018259': 'AKAP7',
#  'ENSCPBG00000020818': 'AKAP8',
#  'ENSCPBG00000020814': 'AKAP8L',
#  'ENSCPBG00000021625': 'AKAP9',
#  'ENSCPBG00000019906': 'AKIRIN2',
#  'ENSCPBG00000006473': 'AKNA',
#  'ENSCPBG00000028296': 'AKNAD1',
#  'ENSCPBG00000005428': 'AKR1A1',
#  'ENSCPBG00000028234': 'AKR1B1',
#  'ENSCPBG00000012026': 'AKR1D1',
#  'ENSCPBG00000023563': 'AKR7A2',
#  'ENSCPBG00000020183': 'AKT1',
#  'ENSCPBG00000019766': 'AKT2',
#  'ENSCPBG00000008877': 'AKT3',
#  'ENSCPBG00000012207': 'AKTIP',
#  'ENSCPBG00000019233': 'ALAD',
#  'ENSCPBG00000013516': 'ALB',
#  'ENSCPBG00000004575': 'ALCAM',
#  'ENSCPBG00000012393': 'ALDH18A1',
#  'ENSCPBG00000020095': 'ALDH1A1',
#  'ENSCPBG00000004982': 'ALDH1A2',
#  'ENSCPBG00000019604': 'ALDH1A3',
#  'ENSCPBG00000023220': 'ALDH1L2',
#  'ENSCPBG00000003596': 'ALDH2',
#  'ENSCPBG00000015806': 'ALDH3A2',
#  'ENSCPBG00000022994': 'ALDH4A1',
#  'ENSCPBG00000006721': 'ALDH5A1',
#  'ENSCPBG00000026218': 'ALDH6A1',
#  'ENSCPBG00000010823': 'ALDH7A1',
#  'ENSCPBG00000017640': 'ALDH8A1',
#  'ENSCPBG00000014763': 'ALDH9A1',
#  'ENSCPBG00000009512': 'ALDOB',
#  'ENSCPBG00000020330': 'ALDOC',
#  'ENSCPBG00000026603': 'ALG1',
#  'ENSCPBG00000011611': 'ALG10',
#  'ENSCPBG00000000366': 'ALG11',
#  'ENSCPBG00000021329': 'ALG12',
#  'ENSCPBG00000017090': 'ALG13',
#  'ENSCPBG00000017377': 'ALG14',
#  'ENSCPBG00000000831': 'ALG2',
#  'ENSCPBG00000015576': 'ALG3',
#  'ENSCPBG00000003180': 'ALG5',
#  'ENSCPBG00000014218': 'ALG6',
#  'ENSCPBG00000027799': 'ALG8',
#  'ENSCPBG00000001001': 'ALK',
#  'ENSCPBG00000026326': 'ALKBH1',
#  'ENSCPBG00000006832': 'ALKBH2',
#  'ENSCPBG00000012575': 'ALKBH3',
#  'ENSCPBG00000027772': 'ALKBH4',
#  'ENSCPBG00000020984': 'ALKBH5',
#  'ENSCPBG00000018611': 'ALKBH8',
#  'ENSCPBG00000024520': 'ALMS1',
#  'ENSCPBG00000006117': 'ALOX5',
#  'ENSCPBG00000020426': 'ALOX5AP',
#  'ENSCPBG00000016403': 'ALPI',
#  'ENSCPBG00000004794': 'ALPK1',
#  'ENSCPBG00000024146': 'ALPK2',
#  'ENSCPBG00000005939': 'ALPK3',
#  'ENSCPBG00000008863': 'ALPL',
#  'ENSCPBG00000011591': 'ALS2',
#  'ENSCPBG00000001553': 'ALS2CL',
#  'ENSCPBG00000000083': 'ALX1',
#  'ENSCPBG00000001587': 'ALX3',
#  'ENSCPBG00000012590': 'ALX4',
#  'ENSCPBG00000021298': 'AMACR',
#  'ENSCPBG00000019147': 'AMBP',
#  'ENSCPBG00000012667': 'AMBRA1',
#  'ENSCPBG00000006492': 'AMD1',
#  'ENSCPBG00000001992': 'AMDHD1',
#  'ENSCPBG00000022167': 'AMDHD2',
#  'ENSCPBG00000020548': 'AMER2',
#  'ENSCPBG00000011978': 'AMFR',
#  'ENSCPBG00000018574': 'AMH',
#  'ENSCPBG00000012587': 'AMIGO1',
#  'ENSCPBG00000010994': 'AMIGO3',
#  'ENSCPBG00000000476': 'AMMECR1',
#  'ENSCPBG00000019135': 'AMMECR1L',
#  'ENSCPBG00000019497': 'AMN',
#  'ENSCPBG00000016808': 'AMN1',
#  'ENSCPBG00000017081': 'AMOT',
#  'ENSCPBG00000024034': 'AMOTL1',
#  'ENSCPBG00000000153': 'AMOTL2',
#  'ENSCPBG00000016467': 'AMPD1',
#  'ENSCPBG00000012597': 'AMPD2',
#  'ENSCPBG00000023642': 'AMPD3',
#  'ENSCPBG00000024907': 'AMPH',
#  'ENSCPBG00000020728': 'AMZ1',
#  'ENSCPBG00000005698': 'ANAPC1',
#  'ENSCPBG00000027509': 'ANAPC10',
#  'ENSCPBG00000011495': 'ANAPC11',
#  'ENSCPBG00000000166': 'ANAPC13',
#  'ENSCPBG00000004116': 'ANAPC15',
#  'ENSCPBG00000025877': 'ANAPC16',
#  'ENSCPBG00000000861': 'ANAPC2',
#  'ENSCPBG00000027964': 'ANAPC4',
#  'ENSCPBG00000026036': 'CAMKK2',
#  'ENSCPBG00000026024': 'ANAPC7',
#  'ENSCPBG00000026277': 'ANGEL1',
#  'ENSCPBG00000013091': 'ANGEL2',
#  'ENSCPBG00000000642': 'ANGPT1',
#  'ENSCPBG00000027622': 'ANGPT4',
#  'ENSCPBG00000014508': 'ANGPTL1',
#  'ENSCPBG00000000267': 'ANGPTL2',
#  'ENSCPBG00000014200': 'ANGPTL3',
#  'ENSCPBG00000017058': 'ANGPTL4',
#  'ENSCPBG00000027415': 'ANGPTL5',
#  'ENSCPBG00000022002': 'ANGPTL7',
#  'ENSCPBG00000003089': 'ANK1',
#  'ENSCPBG00000019650': 'ANKDD1A',
#  'ENSCPBG00000023341': 'ANKEF1',
#  'ENSCPBG00000027722': 'ANKFY1',
#  'ENSCPBG00000028358': 'ANKH',
#  'ENSCPBG00000007377': 'ANKHD1',
#  'ENSCPBG00000021573': 'ANKIB1',
#  'ENSCPBG00000008929': 'ANKK1',
#  'ENSCPBG00000012416': 'ANKLE1',
#  'ENSCPBG00000016992': 'ANKLE2',
#  'ENSCPBG00000019191': 'ANKMY1',
#  'ENSCPBG00000021864': 'ANKMY2',
#  'ENSCPBG00000000509': 'ANKRA2',
#  'ENSCPBG00000026520': 'ANKRD1',
#  'ENSCPBG00000005903': 'ANKRD10',
#  'ENSCPBG00000023386': 'ANKRD11',
#  'ENSCPBG00000028379': 'ANKRD12',
#  'ENSCPBG00000021568': 'ANKRD13A',
#  'ENSCPBG00000020097': 'ANKRD13B',
#  'ENSCPBG00000022457': 'ANKRD13C',
#  'ENSCPBG00000009323': 'ANKRD13D',
#  'ENSCPBG00000019249': 'ANKRD16',
#  'ENSCPBG00000019561': 'ANKRD17',
#  'ENSCPBG00000011964': 'ANKRD2',
#  'ENSCPBG00000026497': 'ANKRD22',
#  'ENSCPBG00000016194': 'ANKRD27',
#  'ENSCPBG00000022533': 'ANKRD28',
#  'ENSCPBG00000027240': 'ANKRD29',
#  'ENSCPBG00000000893': 'ANKRD31',
#  'ENSCPBG00000028371': 'ANKRD33B',
#  'ENSCPBG00000024952': 'ANKRD34C',
#  'ENSCPBG00000023213': 'ANKRD39',
#  'ENSCPBG00000006830': 'ANKRD42',
#  'ENSCPBG00000021897': 'ANKRD44',
#  'ENSCPBG00000005795': 'ANKRD46',
#  'ENSCPBG00000024024': 'ANKRD49',
#  'ENSCPBG00000024610': 'ANKRD50',
#  'ENSCPBG00000013771': 'ANKRD52',
#  'ENSCPBG00000023051': 'ANKRD54',
#  'ENSCPBG00000005635': 'ANKRD55',
#  'ENSCPBG00000019933': 'ANKRD6',
#  'ENSCPBG00000019961': 'ANKRD61',
#  'ENSCPBG00000021658': 'ANKRD66',
#  'ENSCPBG00000019536': 'ANKRD9',
#  'ENSCPBG00000027158': 'ANKS1A',
#  'ENSCPBG00000004377': 'ANKS1B',
#  'ENSCPBG00000019259': 'ANKS4B',
#  'ENSCPBG00000000336': 'ANKS6',
#  'ENSCPBG00000013159': 'ANKZF1',
#  'ENSCPBG00000024972': 'ANLN',
#  'ENSCPBG00000011970': 'ANO1',
#  'ENSCPBG00000022761': 'ANO10',
#  'ENSCPBG00000008040': 'ANO2',
#  'ENSCPBG00000028019': 'ANO3',
#  'ENSCPBG00000004697': 'ANO4',
#  'ENSCPBG00000028008': 'ANO5',
#  'ENSCPBG00000015350': 'ANO6',
#  'ENSCPBG00000012431': 'ANO8',
#  'ENSCPBG00000025519': 'ANP32A',
#  'ENSCPBG00000011159': 'ANP32B',
#  'ENSCPBG00000008122': 'ANP32E',
#  'ENSCPBG00000024929': 'ANPEP',
#  'ENSCPBG00000003314': 'ANTXR1',
#  'ENSCPBG00000008113': 'ANTXR2',
#  'ENSCPBG00000012762': 'ANTXRL',
#  'ENSCPBG00000020089': 'ANXA1',
#  'ENSCPBG00000012707': 'ANXA10',
#  'ENSCPBG00000025589': 'ANXA11',
#  'ENSCPBG00000020644': 'ANXA13',
#  'ENSCPBG00000017143': 'ANXA2',
#  'ENSCPBG00000003449': 'ANXA4',
#  'ENSCPBG00000024727': 'ANXA5',
#  'ENSCPBG00000010126': 'ANXA6',
#  'ENSCPBG00000024309': 'ANXA7',
#  'ENSCPBG00000002788': 'ANXA8',
#  'ENSCPBG00000024977': 'AOAH',
#  'ENSCPBG00000012265': 'AOC1',
#  'ENSCPBG00000004767': 'AP1AR',
#  'ENSCPBG00000001952': 'AP1B1',
#  'ENSCPBG00000026992': 'AP1G1',
#  'ENSCPBG00000015037': 'AP1M1',
#  'ENSCPBG00000005150': 'AP1M2',
#  'ENSCPBG00000012681': 'AP1S2',
#  'ENSCPBG00000007767': 'AP2A2',
#  'ENSCPBG00000027826': 'AP2B1',
#  'ENSCPBG00000015582': 'AP2M1',
#  'ENSCPBG00000005245': 'AP2S1',
#  'ENSCPBG00000004265': 'AP3B1',
#  'ENSCPBG00000006215': 'AP3B2',
#  'ENSCPBG00000018531': 'AP3D1',
#  'ENSCPBG00000012701': 'AP3M1',
#  'ENSCPBG00000004404': 'AP3M2',
#  'ENSCPBG00000001702': 'AP3S1',
#  'ENSCPBG00000015447': 'AP4B1',
#  'ENSCPBG00000027852': 'AP4E1',
#  'ENSCPBG00000025936': 'AP4S1',
#  'ENSCPBG00000024799': 'AP5M1',
#  'ENSCPBG00000020762': 'AP5Z1',
#  'ENSCPBG00000004307': 'APAF1',
#  'ENSCPBG00000025317': 'APBA1',
#  'ENSCPBG00000010888': 'APBA2',
#  'ENSCPBG00000017105': 'APBA3',
#  'ENSCPBG00000006400': 'APBB1',
#  'ENSCPBG00000015827': 'APBB1IP',
#  'ENSCPBG00000007598': 'APBB3',
#  'ENSCPBG00000013905': 'APC',
#  'ENSCPBG00000028386': 'APCDD1',
#  'ENSCPBG00000023924': 'APCDD1L',
#  'ENSCPBG00000011033': 'APEH',
#  'ENSCPBG00000018632': 'APELA',
#  'ENSCPBG00000012564': 'API5',
#  'ENSCPBG00000012530': 'APIP',
#  'ENSCPBG00000022041': 'CENPS-CORT',
#  'ENSCPBG00000001088': 'APLF',
#  'ENSCPBG00000011991': 'APLN',
#  'ENSCPBG00000016804': 'APLNR',
#  'ENSCPBG00000026889': 'APLP2',
#  'ENSCPBG00000011383': 'APMAP',
#  'ENSCPBG00000020301': 'APOA1',
#  'ENSCPBG00000025800': 'APOA1BP',
#  'ENSCPBG00000020299': 'APOA4',
#  'ENSCPBG00000019999': 'APOB',
#  'ENSCPBG00000017469': 'APOBEC2',
#  'ENSCPBG00000015714': 'APOBEC4',
#  'ENSCPBG00000011306': 'APOD',
#  'ENSCPBG00000014040': 'APOF',
#  'ENSCPBG00000009606': 'APOH',
#  'ENSCPBG00000020970': 'APOLD1',
#  'ENSCPBG00000006759': 'APOO',
#  'ENSCPBG00000014469': 'APOOL',
#  'ENSCPBG00000020283': 'APOPT1',
#  'ENSCPBG00000013858': 'APOV1',
#  'ENSCPBG00000009466': 'APPBP2',
#  'ENSCPBG00000012336': 'APPL1',
#  'ENSCPBG00000023209': 'APPL2',
#  'ENSCPBG00000023446': 'APRT',
#  'ENSCPBG00000023973': 'APTX',
#  'ENSCPBG00000004489': 'AQP1',
#  'ENSCPBG00000027790': 'AQP11',
#  'ENSCPBG00000021392': 'AQP12B',
#  'ENSCPBG00000017910': 'AQP2',
#  'ENSCPBG00000005857': 'AQP3',
#  'ENSCPBG00000021077': 'AQP4',
#  'ENSCPBG00000017907': 'AQP5',
#  'ENSCPBG00000005856': 'AQP7',
#  'ENSCPBG00000004992': 'AQP9',
#  'ENSCPBG00000023856': 'AQR',
#  'ENSCPBG00000007235': 'AR',
#  'ENSCPBG00000013841': 'ARAP2',
#  'ENSCPBG00000008435': 'ARAP3',
#  'ENSCPBG00000019078': 'ARC',
#  'ENSCPBG00000021312': 'ARCN1',
#  'ENSCPBG00000013495': 'AREG',
#  'ENSCPBG00000026230': 'AREL1',
#  'ENSCPBG00000001732': 'ARF1',
#  'ENSCPBG00000012354': 'ARF4',
#  'ENSCPBG00000023360': 'ARF6',
#  'ENSCPBG00000027189': 'ARFGAP1',
#  'ENSCPBG00000015479': 'ARFGAP2',
#  'ENSCPBG00000025177': 'ARFGAP3',
#  'ENSCPBG00000013885': 'ARFGEF1',
#  'ENSCPBG00000025789': 'ARFIP1',
#  'ENSCPBG00000015351': 'ARFIP2',
#  'ENSCPBG00000014731': 'ARFRP1',
#  'ENSCPBG00000006304': 'ARG2',
#  'ENSCPBG00000023295': 'ARGLU1',
#  'ENSCPBG00000012676': 'ARHGAP1',
#  'ENSCPBG00000027372': 'ARHGAP10',
#  'ENSCPBG00000000864': 'ARHGAP11A',
#  'ENSCPBG00000015937': 'ARHGAP12',
#  'ENSCPBG00000000440': 'ARHGAP15',
#  'ENSCPBG00000001643': 'ARHGAP17',
#  'ENSCPBG00000018305': 'ARHGAP18',
#  'ENSCPBG00000011924': 'ARHGAP19',
#  'ENSCPBG00000020941': 'ARHGAP20',
#  'ENSCPBG00000015343': 'ARHGAP21',
#  'ENSCPBG00000012787': 'ARHGAP22',
#  'ENSCPBG00000005490': 'ARHGAP24',
#  'ENSCPBG00000003140': 'ARHGAP25',
#  'ENSCPBG00000016598': 'ARHGAP26',
#  'ENSCPBG00000009035': 'PLEKHM1',
#  'ENSCPBG00000006810': 'ARHGAP28',
#  'ENSCPBG00000017386': 'ARHGAP29',
#  'ENSCPBG00000009161': 'ARHGAP30',
#  'ENSCPBG00000002832': 'ARHGAP31',
#  'ENSCPBG00000026933': 'ARHGAP32',
#  'ENSCPBG00000005254': 'ARHGAP35',
#  'ENSCPBG00000012127': 'ARHGAP36',
#  'ENSCPBG00000018185': 'ARHGAP40',
#  'ENSCPBG00000027408': 'ARHGAP42',
#  'ENSCPBG00000027894': 'ARHGAP44',
#  'ENSCPBG00000026180': 'ARHGAP5',
#  'ENSCPBG00000021345': 'ARHGAP6',
#  'ENSCPBG00000024338': 'ARHGAP8',
#  'ENSCPBG00000011492': 'ARHGDIA',
#  'ENSCPBG00000005865': 'ARHGDIB',
#  'ENSCPBG00000005155': 'ARHGDIG',
#  'ENSCPBG00000021849': 'ARHGEF10',
#  'ENSCPBG00000010013': 'ARHGEF10L',
#  'ENSCPBG00000026367': 'ARHGEF11',
#  'ENSCPBG00000008441': 'ARHGEF12',
#  'ENSCPBG00000021495': 'ARHGEF16',
#  'ENSCPBG00000010450': 'ARHGEF17',
#  'ENSCPBG00000012967': 'ARHGEF18',
#  'ENSCPBG00000018793': 'ARHGEF26',
#  'ENSCPBG00000000588': 'ARHGEF28',
#  'ENSCPBG00000010191': 'ARHGEF3',
#  'ENSCPBG00000023587': 'ARHGEF33',
#  'ENSCPBG00000007872': 'ARHGEF37',
#  'ENSCPBG00000003893': 'ARHGEF38',
#  'ENSCPBG00000000480': 'ARHGEF39',
#  'ENSCPBG00000019155': 'ARHGEF4',
#  'ENSCPBG00000007961': 'ARHGEF5',
#  'ENSCPBG00000026103': 'ARHGEF6',
#  'ENSCPBG00000019002': 'ARHGEF7',
#  'ENSCPBG00000002427': 'ARHGEF9',
#  'ENSCPBG00000024979': 'ARID1A',
#  'ENSCPBG00000016297': 'ARID1B',
#  'ENSCPBG00000015339': 'ARID2',
#  'ENSCPBG00000024217': 'ARID3B',
#  'ENSCPBG00000024815': 'ARID4A',
#  'ENSCPBG00000004501': 'ARID4B',
#  'ENSCPBG00000023170': 'ARID5A',
#  'ENSCPBG00000015418': 'ARID5B',
#  'ENSCPBG00000006369': 'ARIH1',
#  'ENSCPBG00000003938': 'ARIH2',
#  'ENSCPBG00000004906': 'ARL1',
#  'ENSCPBG00000022651': 'ARL10',
#  'ENSCPBG00000008579': 'ARL11',
#  'ENSCPBG00000005599': 'ARL13B',
#  'ENSCPBG00000018327': 'ARL14',
#  'ENSCPBG00000011685': 'ARL14EP',
#  'ENSCPBG00000001897': 'ARL14EPL',
#  'ENSCPBG00000007476': 'ARL15',
#  'ENSCPBG00000011391': 'ARL16',
#  'ENSCPBG00000000201': 'ARL2BP',
#  'ENSCPBG00000002364': 'ARL3',
#  'ENSCPBG00000024707': 'ARL4C',
#  'ENSCPBG00000026331': 'ARL5A',
#  'ENSCPBG00000015064': 'ARL5B',
#  'ENSCPBG00000005852': 'ARL6',
#  'ENSCPBG00000010262': 'ARL6IP1',
#  'ENSCPBG00000025976': 'ARL6IP4',
#  'ENSCPBG00000000384': 'ARL6IP5',
#  'ENSCPBG00000010155': 'ARL8A',
#  'ENSCPBG00000014937': 'ARL8B',
#  'ENSCPBG00000015019': 'ARL9',
#  'ENSCPBG00000021391': 'ARMC1',
#  'ENSCPBG00000014934': 'ARMC10',
#  'ENSCPBG00000006308': 'ARMC2',
#  'ENSCPBG00000015227': 'ARMC3',
#  'ENSCPBG00000015843': 'ARMC4',
#  'ENSCPBG00000012485': 'ARMC6',
#  'ENSCPBG00000028122': 'ARMC7',
#  'ENSCPBG00000016460': 'ARMC9',
#  'ENSCPBG00000008682': 'ARNT',
#  'ENSCPBG00000007652': 'ARNT2',
#  'ENSCPBG00000016418': 'ARNTL',
#  'ENSCPBG00000023135': 'ARNTL2',
#  'ENSCPBG00000020854': 'ARPC1A',
#  'ENSCPBG00000020858': 'ARPC1B',
#  'ENSCPBG00000013289': 'ARPC2',
#  'ENSCPBG00000026022': 'ARPC3',
#  'ENSCPBG00000008842': 'ARPC4',
#  'ENSCPBG00000015716': 'ARPC5',
#  'ENSCPBG00000028146': 'ARPC5L',
#  'ENSCPBG00000028081': 'ARPP19',
#  'ENSCPBG00000013513': 'ARPP21',
#  'ENSCPBG00000014349': 'ARR3',
#  'ENSCPBG00000023966': 'ARRDC1',
#  'ENSCPBG00000012959': 'ARRDC2',
#  'ENSCPBG00000010539': 'ARRDC3',
#  'ENSCPBG00000019526': 'ARRDC4',
#  'ENSCPBG00000011707': 'ARSA',
#  'ENSCPBG00000027666': 'ARSB',
#  'ENSCPBG00000009682': 'ARSG',
#  'ENSCPBG00000010077': 'ARSI',
#  'ENSCPBG00000024782': 'ARSJ',
#  'ENSCPBG00000000470': 'ARSK',
#  'ENSCPBG00000001378': 'ART1',
#  'ENSCPBG00000005884': 'ART4',
#  'ENSCPBG00000003453': 'ARTN',
#  'ENSCPBG00000006267': 'ARV1',
#  'ENSCPBG00000010719': 'ARVCF',
#  'ENSCPBG00000006119': 'ARX',
#  'ENSCPBG00000024496': 'AS3MT',
#  'ENSCPBG00000009215': 'ASAH1',
#  'ENSCPBG00000026465': 'ASAH2',
#  'ENSCPBG00000014081': 'ASAP2',
#  'ENSCPBG00000011209': 'ASAP3',
#  'ENSCPBG00000025369': 'ASB1',
#  'ENSCPBG00000012197': 'ASB10',
#  'ENSCPBG00000015708': 'ASB11',
#  'ENSCPBG00000002501': 'ASB12',
#  'ENSCPBG00000019236': 'ASB13',
#  'ENSCPBG00000012338': 'ASB14',
#  'ENSCPBG00000020670': 'ASB15',
#  'ENSCPBG00000026704': 'ASB16',
#  'ENSCPBG00000022867': 'ASB18',
#  'ENSCPBG00000008938': 'ASB2',
#  'ENSCPBG00000012756': 'ASB3',
#  'ENSCPBG00000024411': 'ASB4',
#  'ENSCPBG00000003322': 'ASB5',
#  'ENSCPBG00000022744': 'ASB6',
#  'ENSCPBG00000019600': 'ASB7',
#  'ENSCPBG00000019733': 'ASB8',
#  'ENSCPBG00000015709': 'ASB9',
#  'ENSCPBG00000025878': 'ASCC1',
#  'ENSCPBG00000007719': 'ASCC2',
#  'ENSCPBG00000003881': 'ASCC3',
#  'ENSCPBG00000008090': 'ASCL1',
#  'ENSCPBG00000007357': 'ASCL2',
#  'ENSCPBG00000022805': 'ASCL3',
#  'ENSCPBG00000018809': 'ASF1A',
#  'ENSCPBG00000005867': 'ASH2L',
#  'ENSCPBG00000013500': 'ASIC2',
#  'ENSCPBG00000012235': 'ASIC3',
#  'ENSCPBG00000009293': 'ASIC5',
#  'ENSCPBG00000019156': 'ASIP',
#  'ENSCPBG00000014859': 'ASL',
#  'ENSCPBG00000007426': 'ASMTL',
#  'ENSCPBG00000023903': 'ASNA1',
#  'ENSCPBG00000024398': 'ASNS',
#  'ENSCPBG00000020450': 'ASNSD1',
#  'ENSCPBG00000015816': 'ASPA',
#  'ENSCPBG00000010953': 'ASPDH',
#  'ENSCPBG00000020202': 'ASPG',
#  'ENSCPBG00000021423': 'ASPH',
#  'ENSCPBG00000028268': 'ASPM',
#  'ENSCPBG00000018465': 'ASPN',
#  'ENSCPBG00000011514': 'ASPSCR1',
#  'ENSCPBG00000018142': 'ASRGL1',
#  'ENSCPBG00000022650': 'ASS1',
#  'ENSCPBG00000022843': 'ASTE1',
#  'ENSCPBG00000012603': 'ASTL',
#  'ENSCPBG00000014562': 'ASTN1',
#  'ENSCPBG00000006339': 'ASTN2',
#  'ENSCPBG00000023095': 'ASUN',
#  'ENSCPBG00000027473': 'ASXL1',
#  'ENSCPBG00000010779': 'ASXL2',
#  'ENSCPBG00000020982': 'ASXL3',
#  'ENSCPBG00000007263': 'ASZ1',
#  'ENSCPBG00000026471': 'ATAD1',
#  'ENSCPBG00000020667': 'ATAD2',
#  'ENSCPBG00000020023': 'ATAD2B',
#  'ENSCPBG00000022917': 'ATAD3A',
#  'ENSCPBG00000004712': 'ATAD5',
#  'ENSCPBG00000011131': 'ATCAY',
#  'ENSCPBG00000019418': 'ATF1',
#  'ENSCPBG00000003739': 'ATF2',
#  'ENSCPBG00000010168': 'ATF3',
#  'ENSCPBG00000022964': 'ATF4',
#  'ENSCPBG00000010852': 'ATF6',
#  'ENSCPBG00000000581': 'ATF7',
#  'ENSCPBG00000020944': 'ATF7IP',
#  'ENSCPBG00000019481': 'ATG101',
#  'ENSCPBG00000001689': 'ATG12',
#  'ENSCPBG00000012673': 'ATG13',
#  'ENSCPBG00000020090': 'ATG14',
#  'ENSCPBG00000024319': 'ATG16L1',
#  'ENSCPBG00000024115': 'ATG2B',
#  'ENSCPBG00000003393': 'ATG3',
#  'ENSCPBG00000000890': 'ATG4A',
#  'ENSCPBG00000002176': 'ATG4B',
#  'ENSCPBG00000014206': 'ATG4C',
#  'ENSCPBG00000004179': 'ATG5',
#  'ENSCPBG00000000334': 'ATG7',
#  'ENSCPBG00000013160': 'ATG9A',
#  'ENSCPBG00000011396': 'ATHL1',
#  'ENSCPBG00000026422': 'ATIC',
#  'ENSCPBG00000021641': 'ATL1',
#  'ENSCPBG00000021709': 'ATM',
#  'ENSCPBG00000023988': 'ATMIN',
#  'ENSCPBG00000019562': 'ATOH7',
#  'ENSCPBG00000001027': 'ATOH8',
#  'ENSCPBG00000010201': 'ATOX1',
#  'ENSCPBG00000004793': 'ATP10A',
#  'ENSCPBG00000008070': 'ATP10B',
#  'ENSCPBG00000027872': 'ATP10D',
#  'ENSCPBG00000019044': 'ATP11A',
#  'ENSCPBG00000000373': 'ATP11B',
#  'ENSCPBG00000016932': 'ATP11C',
#  'ENSCPBG00000015067': 'ATP12A',
#  'ENSCPBG00000014270': 'ATP13A1',
#  'ENSCPBG00000010662': 'ATP13A2',
#  'ENSCPBG00000015933': 'ATP13A3',
#  'ENSCPBG00000016883': 'ATP13A4',
#  'ENSCPBG00000016903': 'ATP13A5',
#  'ENSCPBG00000002472': 'ATP1A1',
#  'ENSCPBG00000003701': 'ATP1B1',
#  'ENSCPBG00000022159': 'ATP1B2',
#  'ENSCPBG00000002160': 'ATP1B3',
#  'ENSCPBG00000012818': 'ATP1B4',
#  'ENSCPBG00000026028': 'ATP2A2',
#  'ENSCPBG00000027736': 'ATP2A3',
#  'ENSCPBG00000000196': 'ATP2B1',
#  'ENSCPBG00000000579': 'ATP2B2',
#  'ENSCPBG00000017417': 'ATP2B4',
#  'ENSCPBG00000022839': 'ATP2C1',
#  'ENSCPBG00000013974': 'ATP4B',
#  'ENSCPBG00000025716': 'ATP5A1',
#  'ENSCPBG00000019796': 'ATP5C1',
#  'ENSCPBG00000022922': 'ATP5D',
#  'ENSCPBG00000027009': 'ATP5E',
#  'ENSCPBG00000021263': 'ATP5F1',
#  'ENSCPBG00000027327': 'ATP5G1',
#  'ENSCPBG00000026810': 'ATP5J',
#  'ENSCPBG00000020871': 'ATP5J2',
#  'ENSCPBG00000005337': 'ATP5O',
#  'ENSCPBG00000023368': 'ATP5S',
#  'ENSCPBG00000000023': 'ATP6',
#  'ENSCPBG00000010740': 'ATP6AP1L',
#  'ENSCPBG00000007981': 'ATP6AP2',
#  'ENSCPBG00000016551': 'ATP6V0A1',
#  'ENSCPBG00000025956': 'ATP6V0A2',
#  'ENSCPBG00000013362': 'ATP6V0A4',
#  'ENSCPBG00000022165': 'ATP6V0C',
#  'ENSCPBG00000009584': 'ATP6V0D2',
#  'ENSCPBG00000007589': 'ATP6V0E1',
#  'ENSCPBG00000012242': 'ATP6V0E2',
#  'ENSCPBG00000019887': 'ATP6V1B1',
#  'ENSCPBG00000000443': 'ATP6V1B2',
#  'ENSCPBG00000026065': 'ATP6V1C1',
#  'ENSCPBG00000014032': 'ATP6V1C2',
#  'ENSCPBG00000006371': 'ATP6V1D',
#  'ENSCPBG00000028220': 'ATP6V1E1',
#  'ENSCPBG00000006443': 'ATP6V1G1',
#  'ENSCPBG00000028278': 'ATP6V1G3',
#  'ENSCPBG00000005131': 'ATP6V1H',
#  'ENSCPBG00000017072': 'ATP7A',
#  'ENSCPBG00000000022': 'ATP8',
#  'ENSCPBG00000025631': 'ATP8A1',
#  'ENSCPBG00000020518': 'ATP8A2',
#  'ENSCPBG00000025509': 'ATP8B1',
#  'ENSCPBG00000024657': 'ATP8B2',
#  'ENSCPBG00000018487': 'ATP8B3',
#  'ENSCPBG00000024078': 'ATP8B5',
#  'ENSCPBG00000014994': 'ATP9A',
#  'ENSCPBG00000003736': 'ATP9B',
#  'ENSCPBG00000008995': 'ATPAF1',
#  'ENSCPBG00000020963': 'ATPAF2',
#  'ENSCPBG00000008903': 'ATR',
#  'ENSCPBG00000009060': 'ATRAID',
#  'ENSCPBG00000018445': 'ATRIP',
#  'ENSCPBG00000024528': 'ATRN',
#  'ENSCPBG00000002851': 'ATRNL1',
#  'ENSCPBG00000015014': 'ATRX',
#  'ENSCPBG00000022373': 'ATXN1',
#  'ENSCPBG00000024301': 'ATXN10',
#  'ENSCPBG00000027000': 'ATXN1L',
#  'ENSCPBG00000003465': 'ATXN2',
#  'ENSCPBG00000008743': 'ATXN3',
#  'ENSCPBG00000026836': 'ATXN7',
#  'ENSCPBG00000001167': 'ATXN7L1',
#  'ENSCPBG00000026701': 'ATXN7L3',
#  'ENSCPBG00000020352': 'AUH',
#  'ENSCPBG00000024684': 'AUP1',
#  'ENSCPBG00000015040': 'AURKA',
#  'ENSCPBG00000022899': 'AURKAIP1',
#  'ENSCPBG00000014913': 'AUTS2',
#  'ENSCPBG00000024716': 'AVEN',
#  'ENSCPBG00000013688': 'AVL9',
#  'ENSCPBG00000024565': 'AVP',
#  'ENSCPBG00000000790': 'AVPR1A',
#  'ENSCPBG00000001806': 'AVPR1B',
#  'ENSCPBG00000014371': 'AWAT2',
#  'ENSCPBG00000025834': 'AXDND1',
#  'ENSCPBG00000005201': 'AXIN1',
#  'ENSCPBG00000009651': 'AXIN2',
#  'ENSCPBG00000022663': 'AZI2',
#  'ENSCPBG00000026068': 'AZIN1',
#  'ENSCPBG00000010982': 'AZIN2',
#  'ENSCPBG00000006165': 'B2M',
#  'ENSCPBG00000018325': 'B3GALNT1',
#  'ENSCPBG00000004334': 'B3GALNT2',
#  'ENSCPBG00000007088': 'B3GALT1',
#  'ENSCPBG00000010582': 'B3GALT2',
#  'ENSCPBG00000012433': 'B3GALT5',
#  'ENSCPBG00000020407': 'B3GALTL',
#  'ENSCPBG00000017731': 'B3GAT1',
#  'ENSCPBG00000009448': 'B3GNT2',
#  'ENSCPBG00000012384': 'B3GNT3',
#  'ENSCPBG00000026094': 'B3GNT4',
#  'ENSCPBG00000000887': 'B3GNT5',
#  'ENSCPBG00000016449': 'B3GNT7',
#  'ENSCPBG00000012000': 'B3GNT9',
#  'ENSCPBG00000027912': 'B3GNTL1',
#  'ENSCPBG00000027337': 'B4GALNT3',
#  'ENSCPBG00000024359': 'B4GALT1',
#  'ENSCPBG00000003534': 'B4GALT2',
#  'ENSCPBG00000002710': 'B4GALT4',
#  'ENSCPBG00000015592': 'B4GALT5',
#  'ENSCPBG00000021024': 'B4GALT6',
#  'ENSCPBG00000022112': 'B4GALT7',
#  'ENSCPBG00000021040': 'B9D1',
#  'ENSCPBG00000026063': 'BAALC',
#  'ENSCPBG00000012410': 'BABAM1',
#  'ENSCPBG00000020486': 'BACE1',
#  'ENSCPBG00000012845': 'BACE2',
#  'ENSCPBG00000006636': 'BACH1',
#  'ENSCPBG00000020234': 'BACH2',
#  'ENSCPBG00000000816': 'BAG1',
#  'ENSCPBG00000022638': 'BAG2',
#  'ENSCPBG00000001092': 'BAG3',
#  'ENSCPBG00000006574': 'BAG4',
#  'ENSCPBG00000020285': 'BAG5',
#  'ENSCPBG00000010417': 'BAHCC1',
#  'ENSCPBG00000013725': 'BAHD1',
#  'ENSCPBG00000019081': 'BAI1',
#  'ENSCPBG00000019038': 'BAI2',
#  'ENSCPBG00000024170': 'BAI3',
#  'ENSCPBG00000010487': 'BAIAP2',
#  'ENSCPBG00000020006': 'BAIAP2L1',
#  'ENSCPBG00000023026': 'BAIAP2L2',
#  'ENSCPBG00000025057': 'BAK1',
#  'ENSCPBG00000015863': 'BAMBI',
#  'ENSCPBG00000023429': 'BANF1',
#  'ENSCPBG00000016404': 'BANK1',
#  'ENSCPBG00000023508': 'BANP',
#  'ENSCPBG00000016525': 'BAP1',
#  'ENSCPBG00000004972': 'BARD1',
#  'ENSCPBG00000021217': 'BARHL1',
#  'ENSCPBG00000015683': 'BARHL2',
#  'ENSCPBG00000019725': 'BARX1',
#  'ENSCPBG00000026928': 'BARX2',
#  'ENSCPBG00000021106': 'BASP1',
#  'ENSCPBG00000026252': 'BATF',
#  'ENSCPBG00000010172': 'BATF3',
#  'ENSCPBG00000026193': 'BAZ1A',
#  'ENSCPBG00000009675': 'BAZ1B',
#  'ENSCPBG00000026480': 'BAZ2B',
#  'ENSCPBG00000012847': 'BBIP1',
#  'ENSCPBG00000028028': 'BBOX1',
#  'ENSCPBG00000018096': 'BBS10',
#  'ENSCPBG00000024648': 'BBS12',
#  'ENSCPBG00000011968': 'BBS2',
#  'ENSCPBG00000006376': 'BBS4',
#  'ENSCPBG00000006702': 'BBS5',
#  'ENSCPBG00000024711': 'BBS7',
#  'ENSCPBG00000013705': 'BBS9',
#  'ENSCPBG00000004643': 'BBX',
#  'ENSCPBG00000014526': 'BC026585',
#  'ENSCPBG00000026570': 'BC067074',
#  'ENSCPBG00000026274': 'BCAN',
#  'ENSCPBG00000000844': 'BCAP29',
#  'ENSCPBG00000007354': 'BCAR1',
#  'ENSCPBG00000017396': 'BCAR3',
#  'ENSCPBG00000015016': 'BCAS1',
#  'ENSCPBG00000016450': 'BCAS2',
#  ...}

# %%
adata.var
# Out:
#                               gene_ids    feature_types
# PLEKHB1             ENSCPBG00000000040  Gene Expression
# RAB6A               ENSCPBG00000000041  Gene Expression
# ENSCPBG00000000042  ENSCPBG00000000042  Gene Expression
# MRPL48              ENSCPBG00000000043  Gene Expression
# COA4                ENSCPBG00000000044  Gene Expression
# ...                                ...              ...
# ENSCPBG00000004592  ENSCPBG00000004592  Gene Expression
# ENSCPBG00000004601  ENSCPBG00000004601  Gene Expression
# ENSCPBG00000004610  ENSCPBG00000004610  Gene Expression
# ENSCPBG00000004637  ENSCPBG00000004637  Gene Expression
# ENSCPBG00000004627  ENSCPBG00000004627  Gene Expression
#
# [26817 rows x 2 columns]

# %%
adata.var.set_index('gene_ids', inplace=True) 
adata.var['gene_ids'] = adata.var.index

adata.var.drop(columns='feature_types', inplace=True)
adata.var.rename(genes_dict, inplace=True)

# %%
adata.var
# Out:
#                               gene_ids
# gene_ids
# PLEKHB1             ENSCPBG00000000040
# RAB6A               ENSCPBG00000000041
# ENSCPBG00000000042  ENSCPBG00000000042
# MRPL48              ENSCPBG00000000043
# COA4                ENSCPBG00000000044
# ...                                ...
# ENSCPBG00000004592  ENSCPBG00000004592
# ENSCPBG00000004601  ENSCPBG00000004601
# ENSCPBG00000004610  ENSCPBG00000004610
# ENSCPBG00000004637  ENSCPBG00000004637
# ACTB                ENSCPBG00000004627
#
# [26817 rows x 1 columns]

# %%
# This code identifies duplicate variable names, iterates through them, and adds suffixes to make them unique from the first occurrence.
# Please make sure to replace adata with your actual AnnData object.

# Keep in mind that Scanpy's functionality may evolve, so it's a good idea to check the documentation or release notes
# for any updates related to making variable names unique starting from the first occurrence in more recent versions of Scanpy.

# Get a Series of variable (gene) names
var_names_series = pd.Series(adata.var_names)

# Identify duplicate variable names
duplicate_var_names = var_names_series[var_names_series.duplicated(keep='first')]

# Iterate through duplicates and add suffixes to make them unique from the first occurrence
for duplicate_name in duplicate_var_names:
    count = 1
    indices = var_names_series[var_names_series == duplicate_name].index
    for idx in indices:
        var_names_series[idx] = f'{duplicate_name}_{count}'
        count += 1

# Update the AnnData object with the unique variable names
adata.var_names = var_names_series.values

adata.var_names
# Out:
# Index(['PLEKHB1', 'RAB6A', 'ENSCPBG00000000042', 'MRPL48', 'COA4', 'PAAF1',
#        'DNAJB13', 'UCP2', 'UCP3', 'C2CD3',
#        ...
#        'ENSCPBG00000004509', 'ENSCPBG00000004538', 'ENSCPBG00000004306',
#        'ENSCPBG00000004583', 'RAB13_2', 'ENSCPBG00000004592',
#        'ENSCPBG00000004601', 'ENSCPBG00000004610', 'ENSCPBG00000004637',
#        'ACTB_2'],
#       dtype='object', length=26817)

# %% [markdown]
# ## Genes and cells filtration

# %%
# adata = sc.read(r"C:\Users\TzachiHNB5\Desktop\reptiles\turtle\turtle_raw_with_metadata.h5ad")

# %%
# adata.obs['inter_species_ann'] = adata.obs['ce']

# %%
# meta = pd.read_csv('turtle_meta.csv',index_col=0)
# meta

# %%
# adata = adata[meta.index]

# %%
adata.obs
# Out:
#                            treatment
# AAACCCACAAGGGCAT-1-control   control
# AAACCCACAGACCAAG-1-control   control
# AAACCCACAGAGATGC-1-control   control
# AAACGAAGTCTTCTAT-1-control   control
# AAACGAAGTGAATTAG-1-control   control
# ...                              ...
# TTTGGTTGTTCGGGTC-1-pic           pic
# TTTGGTTTCGCTACAA-1-pic           pic
# TTTGTTGAGACTAAGT-1-pic           pic
# TTTGTTGGTCACCGAC-1-pic           pic
# TTTGTTGGTCTAATCG-1-pic           pic
#
# [12378 rows x 1 columns]

# %%
adata.var
# Out:
#                               gene_ids
# PLEKHB1             ENSCPBG00000000040
# RAB6A               ENSCPBG00000000041
# ENSCPBG00000000042  ENSCPBG00000000042
# MRPL48              ENSCPBG00000000043
# COA4                ENSCPBG00000000044
# ...                                ...
# ENSCPBG00000004592  ENSCPBG00000004592
# ENSCPBG00000004601  ENSCPBG00000004601
# ENSCPBG00000004610  ENSCPBG00000004610
# ENSCPBG00000004637  ENSCPBG00000004637
# ACTB_2              ENSCPBG00000004627
#
# [26817 rows x 1 columns]

# %%
# adata.obs.drop(columns = ['leiden'],inplace=True)

# %%
# adata.write('turtle_raw_with_metadata.h5ad')

# %% [markdown]
# ### Highly expressed genes ( = top 20 genes)

# %%
sc.pl.highest_expr_genes(adata, n_top=20)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
adata_copy = adata.copy()

# %%
sc.pp.filter_cells(adata, min_genes=100) 
sc.pp.filter_genes(adata, min_cells=3)
print(adata.shape)
# Out:
# filtered out 115 cells that have less than 100 genes expressed
# filtered out 13391 genes that are detected in less than 3 cells
# (12263, 13426)

# %% [markdown]
# ### Mitochondrial QC and general measures

# %% [markdown]
# Check if genes are annotated as mt by running:
# - GENES= list(adata.var.index[adata.var.index.str.startswith('mt-'.upper())])
# - GENES
#
# In case the genes are not annotated as 'MT-'' (Like in bats), run:
#
# - dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2'...etc}
# - adata.var.rename(dict_replace, inplace = True)

# %%
dict_replace = {'COX1':'MT-COX1','COX2':'MT-COX2','COX3':'MT-COX3','ND1':'MT-ND1-1','ND1':'MT-ND1-2','ND2':'MT-ND2',
                'ND3':'MT-ND3','ND4':'MT-ND4','ND5':'MT-ND5','ND6':'MT-ND6','ND4L-1':'MT-ND4L','ATP6':'MT-ATP6','ATP8':'MT-ATP8',
                'CYTB':'MT-CYTB'}
adata.var.rename(dict_replace, inplace=True)
# ONLY MT-ATP6, MT-ND1, MT-ND4L

# %%
adata.var['MT'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'MT'
sc.pp.calculate_qc_metrics(adata, qc_vars=['MT'], percent_top=None, log1p=False, inplace=True)

# %%
adata.var
# Out:
#                               gene_ids  n_cells     MT  n_cells_by_counts  \
# PLEKHB1             ENSCPBG00000000040       23  False                 23
# RAB6A               ENSCPBG00000000041      157  False                157
# ENSCPBG00000000042  ENSCPBG00000000042       39  False                 39
# MRPL48              ENSCPBG00000000043      223  False                223
# COA4                ENSCPBG00000000044       23  False                 23
# ...                                ...      ...    ...                ...
# ENSCPBG00000004447  ENSCPBG00000004447        4  False                  4
# ENSCPBG00000004499  ENSCPBG00000004499       14  False                 14
# ENSCPBG00000004538  ENSCPBG00000004538        9  False                  9
# ENSCPBG00000004637  ENSCPBG00000004637    10765  False              10765
# ACTB_2              ENSCPBG00000004627      181  False                181
#
#                     mean_counts  pct_dropout_by_counts  total_counts
# PLEKHB1                0.002039              99.812444          25.0
# RAB6A                  0.013047              98.719726         160.0
# ENSCPBG00000000042     0.003343              99.681970          41.0
# MRPL48                 0.018837              98.181522         231.0
# COA4                   0.001876              99.812444          23.0
# ...                         ...                    ...           ...
# ENSCPBG00000004447     0.000326              99.967382           4.0
# ENSCPBG00000004499     0.001142              99.885835          14.0
# ENSCPBG00000004538     0.000734              99.926608           9.0
# ENSCPBG00000004637     4.168556              12.215608       51119.0
# ACTB_2                 0.015168              98.524015         186.0
#
# [13426 rows x 7 columns]

# %%
sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True)

# %% [markdown]
# ### Scatter plots of QC metrics

# %%
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts', color='treatment')
sc.pl.scatter(adata, x='total_counts', y='pct_counts_MT', color='treatment')
sc.pl.scatter(adata, x='total_counts', y='n_genes', color='treatment', save=True)
# Out:
# WARNING: saving figure to file figures\scatter.pdf

# %%
adata = adata[adata.obs.pct_counts_MT < 20] 
adata = adata[adata.obs.total_counts < 5000, :] # If filtering outliers (<0.1% of cells)

# %% [markdown]
# ## Doublet analysis and filtering

# %%
import scrublet as scr

def scrub(adatas,adata,adata_names): # based on raw individual samples. 
    print('Before scrublet: ', adata.shape[0])
    doub_index =[]
    barcodes =[]
    for data,name in zip(adatas,adata_names):
        data.raw = data
        sc.pp.normalize_total(data, target_sum=1e4)
        sc.pp.log1p(data)
        scrub = scr.Scrublet(data.raw.X)
        data.obs['doublet_scores'], data.obs['predicted_doublets'] = scrub.scrub_doublets()
        scrub.plot_histogram()
        print('Doublets'+name +' :',data.obs[data.obs['doublet_scores'] >0.25].shape[0])
        barcodes = data.obs[data.obs['doublet_scores'] <0.25].index.to_list()
        for barcode in barcodes:
            doub_index.append(barcode+'-'+name)
    
    adata = adata[adata.obs.index.isin(doub_index)]
    print('After scrublet: ',adata.shape[0])
    return adata

# %%
adata = scrub(adatas, adata, data_names)
# Out:
# Before scrublet:  12203
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# Simulating doublets...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.70
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 3.1 seconds
# Doubletscontrol : 142
# normalizing counts per cell
#     finished (0:00:00)
# Preprocessing...
# Simulating doublets...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 0.0%
# Elapsed time: 2.3 seconds
# Doubletslps : 119
# normalizing counts per cell
#     finished ({time_passed})
# Preprocessing...
# Simulating doublets...
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:239: RuntimeWarning: invalid value encountered in log
#   gLog = lambda input: np.log(input[1] * np.exp(-input[0]) + input[2])
# c:\Python\Python310\lib\site-packages\scrublet\helper_functions.py:252: RuntimeWarning: invalid value encountered in sqrt
#   CV_input = np.sqrt(b);
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.50
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 10.0%
# 	Estimated  = 33.3%
# Elapsed time: 2.9 seconds
# Doubletspic : 67
# After scrublet:  11877

# %% [markdown]
# ## Cell cycle scoring
# download Cell cycle txt: https://github.com/scverse/scanpy_usage/blob/master/180209_cell_cycle/data/regev_lab_cell_cycle_genes.txt

# %%
cell_cycle_genes = [x.strip() for x in open(r'/Code/data/single_cell/animals/regev_lab_cell_cycle_genes.txt')]

s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]
s_genes = [x for x in s_genes if x in adata.var_names]
g2m_genes = [x for x in g2m_genes if x in adata.var_names]

# %%
cell_cycle_adata = adata.copy()

sc.pp.normalize_per_cell(cell_cycle_adata, counts_per_cell_after=1e4)
sc.pp.log1p(cell_cycle_adata)
sc.pp.scale(cell_cycle_adata)
sc.tl.score_genes_cell_cycle(cell_cycle_adata, s_genes=s_genes, g2m_genes=g2m_genes)
adata_cc_genes = cell_cycle_adata[:, cell_cycle_genes].copy()
sc.tl.pca(adata_cc_genes)
sc.pl.pca_scatter(adata_cc_genes, color='phase', save=True)
adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()
adata.obs['G2M_score'] = cell_cycle_adata.obs['G2M_score'].copy()
adata.obs['phase'] = cell_cycle_adata.obs['phase'].copy()
# Out:
# normalizing by total count per cell
#     finished (0:00:00): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# calculating cell cycle phase
# computing score 'S_score'
#     finished: added
#     'S_score', score of gene set (adata.obs).
#     657 total control genes are used. (0:00:00)
# computing score 'G2M_score'
#     finished: added
#     'G2M_score', score of gene set (adata.obs).
#     757 total control genes are used. (0:00:00)
# -->     'phase', cell cycle phase (adata.obs)
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
#     and added
#     'X_pca', the PCA coordinates (adata.obs)
#     'PC1', 'PC2', ..., the loadings (adata.var)
#     'pca_variance', the variance / eigenvalues (adata.uns)
#     'pca_variance_ratio', the variance ratio (adata.uns)
# WARNING: saving figure to file figures\pca.pdf
# C:\Users\TzachiHNB2\AppData\Local\Temp\ipykernel_25140\1917813240.py:10: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['S_score'] = cell_cycle_adata.obs['S_score'].copy()

# %% [markdown]
# ## Saving adata

# %%
adata.write(r'/Code/data/single_cell/animals/turtle/turtle_1/''turtle_1_after_qc.h5ad')

# %% [markdown]
# ## Preparing files to be opened in R studio

# %%
matrix_dense = adata.X.toarray()

# Create a DataFrame from the dense array with observation names as index and variable names as columns
matrix_df = pd.DataFrame(matrix_dense, index=adata.obs_names, columns=adata.var_names)

# Save the DataFrame to a CSV file
matrix_df.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''matrix_new.csv')
print('matrix file is transformed')

#save obs as scv
adata.obs.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''obs_new.csv')
print('obs file is transformed')

# Save variable data to a CSV file
adata.var.to_csv(r'/Code/data/single_cell/animals/turtle/turtle_3/''var_new.csv')
print('var file is transformed')
